# %% [markdown]
# # 03  Combined the Disney Films List with IMDB Data

# %% [markdown]
# ## 03.01 Imports

# %% [markdown]
# ### 03.01.01 Python Imports

# %%
import gzip
import pandas as pd

# %% [markdown]
# ### 03.01.02 IMDB Rating and Vote Data

# %%
rt=gzip.open('../Other Source Data/IMDB/title.ratings.tsv.gz','rb')
df_ratings = pd.read_csv(rt,sep='\t', low_memory=False)
df_ratings.head()
# Index	tconst	averageRating	numVotes
# 0	tt0000001	5.7	1868
# 1	tt0000002	5.9	247
# 2	tt0000003	6.5	1640
# 3	tt0000004	5.8	159
# 4	tt0000005	6.2	2463
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1868
# 1  tt0000002            5.9       247
# 2  tt0000003            6.5      1640
# 3  tt0000004            5.8       159
# 4  tt0000005            6.2      2463

# %% [markdown]
# ### 03.01.03 Import Feature Films

# %%
Disney_IMDB = pd.read_csv('../Bens_Data/Combined_IMDB_Disney_453.csv')
Disney_IMDB.head()
# Out:
#    Unnamed: 0                         title     tconst titleType  \
# 0           0                101 Dalmatians  tt0115433     movie
# 1           5                102 Dalmatians  tt0211181     movie
# 2          10  20,000 Leagues Under the Sea  tt0046672     movie
# 3          24                  A Bug's Life  tt0120623     movie
# 4          74             A Christmas Carol  tt1067106     movie
#
#                    primaryTitle                 originalTitle  isAdult  \
# 0                101 Dalmatians                101 Dalmatians        0
# 1                102 Dalmatians                102 Dalmatians        0
# 2  20,000 Leagues Under the Sea  20,000 Leagues Under the Sea        0
# 3                  A Bug's Life                  A Bug's Life        0
# 4             A Christmas Carol             A Christmas Carol        0
#
#    startYear endYear runtimeMinutes                      genres  \
# 0       1996      \N            103      Adventure,Comedy,Crime
# 1       2000      \N            100     Adventure,Comedy,Family
# 2       1954      \N            127      Adventure,Drama,Family
# 3       1998      \N             95  Adventure,Animation,Comedy
# 4       2009      \N             96  Adventure,Animation,Comedy
#
#                    lower_title _merge
# 0               101 dalmatians   both
# 1               102 dalmatians   both
# 2  20000 leagues under the sea   both
# 3                  a bugs life   both
# 4            a christmas carol   both

# %%
Disney_IMDB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      453 non-null    int64
#  1   title           453 non-null    object
#  2   tconst          453 non-null    object
#  3   titleType       453 non-null    object
#  4   primaryTitle    453 non-null    object
#  5   originalTitle   453 non-null    object
#  6   isAdult         453 non-null    int64
#  7   startYear       453 non-null    int64
#  8   endYear         453 non-null    object
#  9   runtimeMinutes  453 non-null    object
#  10  genres          453 non-null    object
#  11  lower_title     453 non-null    object
#  12  _merge          453 non-null    object
# dtypes: int64(3), object(10)
# memory usage: 46.1+ KB

# %% [markdown]
# ## 03.02 Clean Up Feature Films

# %%
#drop unnamed 0
Disney_IMDB = Disney_IMDB.rename(columns={'Unnamed: 0': 'orig_index','title': 'DFL_title'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35712/1498515086.py in <module>
#       1 #drop unnamed 0
# ----> 2 Disney_IMDB = Disney_IMDB.rename(columns={'Unnamed: 0': 'orig_index','title': 'DFL_title'})
#
# NameError: name 'Disney_IMDB' is not defined

# %%
Disney_IMDB['endYear'].value_counts()
# Out:
# \N    453
# Name: endYear, dtype: int64

# %%
# drop endYear since we aren't working any series
Disney_IMDB.drop(columns=['_merge','isAdult','endYear' ], inplace=True)

# %% [markdown]
# Pulling in the film rating from IMDB

# %% [markdown]
# ## 03.03 Combine Feature Films and Ratings

# %%
Disney_IMDB = pd.merge(Disney_IMDB ,                 # left df
                          df_ratings,                  # right df
                          how="left",                 # left join
                          left_on='tconst',            # left column
                          right_on='tconst',    # right column
                          indicator = True,           # indicates source of each row
                          #validate = "one_to_many"    # alerts us of the relationship from left to right, incase there are dups
        )

# %% [markdown]
# ## 03.04 Explore Combined Feature Films and Ratings

# %% [markdown]
# ### 03.04.01 Clean those missing Ratings and Votes

# %%
Disney_IMDB['_merge'].value_counts()
# Out:
# both          442
# left_only      11
# right_only      0
# Name: _merge, dtype: int64

# %% [markdown]
# 11 a missing ratings.  Let's take a closer look at those.

# %%
Disney_IMDB[Disney_IMDB['_merge'] == 'left_only']
# Out:
#      orig_index                                    DFL_title      tconst  \
# 79         1607  Doctor Strange in the Multiverse of Madness   tt9419884
# 125        2250                                        Holes  tt15507514
# 139        2535                             Inspector Gadget  tt11069282
# 154        2957                                 Let it Shine   tt7932304
# 156        2965                                    Lightyear  tt10298810
# 159        2971                                Lilo & Stitch  tt11655566
# 199        3380                            National Treasure   tt8292728
# 209        3431                                       Oceans   tt1171257
# 232        3771                                        Polly   tt1924347
# 385        5547                The Secret of The Magic Gourd   tt6476724
# 397        5602                       The Sword in the Stone   tt4872762
#
#     titleType                                 primaryTitle  \
# 79      movie  Doctor Strange in the Multiverse of Madness
# 125     movie                                        Holes
# 139     movie                             Inspector Gadget
# 154     movie                                 Let It Shine
# 156     movie                                    Lightyear
# 159     movie                                Lilo & Stitch
# 199     movie                            National Treasure
# 209     movie                                       Oceans
# 232     movie                                        Polly
# 385     movie                The Secret of the Magic Gourd
# 397     movie                       The Sword in the Stone
#
#                                    originalTitle  startYear runtimeMinutes  \
# 79   Doctor Strange in the Multiverse of Madness       2022             \N
# 125                                        Holes       2021             79
# 139                             Inspector Gadget       2026             \N
# 154                                 Let It Shine       2018             98
# 156                                    Lightyear       2022             \N
# 159                                Lilo & Stitch       2024             85
# 199                                      Gui bao       1983             96
# 209                                       Oceans       1971             \N
# 232                                        Polly       2010             50
# 385                           Bao hu lu de bi mi       1963             68
# 397                       The Sword in the Stone       2024             \N
#
#                          genres                                  lower_title  \
# 79     Action,Adventure,Fantasy  doctor strange in the multiverse of madness
# 125                 Documentary                                        holes
# 139     Action,Adventure,Comedy                             inspector gadget
# 154                      Family                                 let it shine
# 156  Action,Adventure,Animation                                    lightyear
# 159     Action,Adventure,Comedy                                 lilo  stitch
# 199                       Drama                            national treasure
# 209           Documentary,Sport                                       oceans
# 232                      Horror                                        polly
# 385        Comedy,Drama,Fantasy                the secret of the magic gourd
# 397     Action,Adventure,Family                       the sword in the stone
#
#      averageRating  numVotes     _merge
# 79             NaN       NaN  left_only
# 125            NaN       NaN  left_only
# 139            NaN       NaN  left_only
# 154            NaN       NaN  left_only
# 156            NaN       NaN  left_only
# 159            NaN       NaN  left_only
# 199            NaN       NaN  left_only
# 209            NaN       NaN  left_only
# 232            NaN       NaN  left_only
# 385            NaN       NaN  left_only
# 397            NaN       NaN  left_only

# %%
# This film has not yet been released (expected May 2022) tt9419884
Disney_IMDB[Disney_IMDB['lower_title'].str.contains("doctor strange in the multiverse of madness")]
# Out:
#     orig_index                                    DFL_title     tconst  \
# 79        1607  Doctor Strange in the Multiverse of Madness  tt9419884
#
#    titleType                                 primaryTitle  \
# 79     movie  Doctor Strange in the Multiverse of Madness
#
#                                   originalTitle  startYear runtimeMinutes  \
# 79  Doctor Strange in the Multiverse of Madness       2022             \N
#
#                       genres                                  lower_title  \
# 79  Action,Adventure,Fantasy  doctor strange in the multiverse of madness
#
#     averageRating  numVotes     _merge
# 79            NaN       NaN  left_only

# %%
Disney_IMDB.drop(Disney_IMDB[Disney_IMDB['tconst'] == "tt9419884"].index, inplace = True)

# %%
# Duplicate missed in the previous file.  tt15507514 should habe been dropped. 
Disney_IMDB[Disney_IMDB['lower_title'].str.contains("holes")]
# Out:
#      orig_index DFL_title      tconst titleType primaryTitle originalTitle  \
# 124        2244     Holes   tt0311289     movie        Holes         Holes
# 125        2250     Holes  tt15507514     movie        Holes         Holes
#
#      startYear runtimeMinutes                  genres lower_title  \
# 124       2003            117  Adventure,Comedy,Drama       holes
# 125       2021             79             Documentary       holes
#
#      averageRating  numVotes     _merge
# 124            7.0   85609.0       both
# 125            NaN       NaN  left_only

# %%
Disney_IMDB.drop(Disney_IMDB[Disney_IMDB['tconst'] == "tt15507514"].index, inplace = True)

# %%
# tt11069282 This film has not yet been released (expected 2026) tt11069282 should habe been dropped. 
Disney_IMDB[Disney_IMDB['lower_title'].str.contains("inspector gadget")]
# Out:
#      orig_index         DFL_title      tconst titleType      primaryTitle  \
# 138        2532  Inspector Gadget   tt0141369     movie  Inspector Gadget
# 139        2535  Inspector Gadget  tt11069282     movie  Inspector Gadget
#
#         originalTitle  startYear runtimeMinutes                   genres  \
# 138  Inspector Gadget       1999             78  Action,Adventure,Comedy
# 139  Inspector Gadget       2026             \N  Action,Adventure,Comedy
#
#           lower_title  averageRating  numVotes     _merge
# 138  inspector gadget            4.1   47777.0       both
# 139  inspector gadget            NaN       NaN  left_only

# %%
Disney_IMDB.drop(Disney_IMDB[Disney_IMDB['tconst'] == "tt11069282"].index, inplace = True)

# %%
# Error misdded in the previous file. This is not a Disney Movie.  The Disney film, tt2165933, was actually a TV movie. So neither of these should be in the list.
Disney_IMDB[Disney_IMDB['lower_title'].str.contains("let it shine")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35712/3230851664.py in <module>
#       1 # Error misdded in the previous file. This is not a Disney Movie.  The Disney film, tt2165933, was actually a TV movie. So neither of these should be in the list.
# ----> 2 Disney_IMDB[Disney_IMDB['lower_title'].str.contains("let it shine")]
#
# NameError: name 'Disney_IMDB' is not defined

# %%
Disney_IMDB.drop(Disney_IMDB[Disney_IMDB['tconst'] == "tt7932304"].index, inplace = True)

# %%
# This film has not yet been released (expected June 2022) tt10298810
Disney_IMDB[Disney_IMDB['lower_title'].str.contains("lightyear")]
# Out:
#      orig_index  DFL_title      tconst titleType primaryTitle originalTitle  \
# 156        2965  Lightyear  tt10298810     movie    Lightyear     Lightyear
#
#      startYear runtimeMinutes                      genres lower_title  \
# 156       2022             \N  Action,Adventure,Animation   lightyear
#
#      averageRating  numVotes     _merge
# 156            NaN       NaN  left_only

# %%
Disney_IMDB.drop(Disney_IMDB[Disney_IMDB['tconst'] == "tt10298810"].index, inplace = True)

# %%
# This film has not yet been released (expected 2024) tt11655566
Disney_IMDB[Disney_IMDB['lower_title'].str.contains("lilo")]
# Out:
#      orig_index      DFL_title      tconst titleType   primaryTitle  \
# 158        2968  Lilo & Stitch   tt0275847     movie  Lilo & Stitch
# 159        2971  Lilo & Stitch  tt11655566     movie  Lilo & Stitch
#
#      originalTitle  startYear runtimeMinutes                      genres  \
# 158  Lilo & Stitch       2002             85  Adventure,Animation,Comedy
# 159  Lilo & Stitch       2024             85     Action,Adventure,Comedy
#
#       lower_title  averageRating  numVotes     _merge
# 158  lilo  stitch            7.3  183336.0       both
# 159  lilo  stitch            NaN       NaN  left_only

# %%
Disney_IMDB.drop(Disney_IMDB[Disney_IMDB['tconst'] == "tt11655566"].index, inplace = True)

# %%
# tt8292728 is not a Disney title and should be dropped
Disney_IMDB[Disney_IMDB['lower_title'].str.contains("national")]
# Out:
#      orig_index                           DFL_title     tconst titleType  \
# 198        3366                   National Treasure  tt0368891     movie
# 199        3380                   National Treasure  tt8292728     movie
# 200        3382  National Treasure: Book of Secrets  tt0465234     movie
#
#                            primaryTitle                       originalTitle  \
# 198                   National Treasure                   National Treasure
# 199                   National Treasure                             Gui bao
# 200  National Treasure: Book of Secrets  National Treasure: Book of Secrets
#
#      startYear runtimeMinutes                    genres  \
# 198       2004            131  Action,Adventure,Mystery
# 199       1983             96                     Drama
# 200       2007            124  Action,Adventure,Mystery
#
#                            lower_title  averageRating  numVotes     _merge
# 198                  national treasure            6.9  323124.0       both
# 199                  national treasure            NaN       NaN  left_only
# 200  national treasure book of secrets            6.5  231520.0       both

# %%
Disney_IMDB.drop(Disney_IMDB[Disney_IMDB['tconst'] == "tt8292728"].index, inplace = True)

# %%
# tt1171257 is not a Disney movie
Disney_IMDB[Disney_IMDB['lower_title'].str.contains("oceans")]
# Out:
#      orig_index DFL_title     tconst titleType primaryTitle originalTitle  \
# 208        3425    Oceans  tt0765128     movie       Oceans        Océans
# 209        3431    Oceans  tt1171257     movie       Oceans        Oceans
#
#      startYear runtimeMinutes             genres lower_title  averageRating  \
# 208       2009            104        Documentary      oceans            7.7
# 209       1971             \N  Documentary,Sport      oceans            NaN
#
#      numVotes     _merge
# 208    9609.0       both
# 209       NaN  left_only

# %%
Disney_IMDB.drop(Disney_IMDB[Disney_IMDB['tconst'] == "tt1171257"].index, inplace = True)

# %%
# tt1924347 was a TV movie, and should have been excluded
Disney_IMDB[Disney_IMDB['lower_title'].str.contains("polly")]
# Out:
#      orig_index  DFL_title     tconst titleType primaryTitle originalTitle  \
# 232        3771      Polly  tt1924347     movie        Polly         Polly
# 233        3788  Pollyanna  tt0054195     movie    Pollyanna     Pollyanna
#
#      startYear runtimeMinutes               genres lower_title  averageRating  \
# 232       2010             50               Horror       polly            NaN
# 233       1960            134  Comedy,Drama,Family   pollyanna            7.4
#
#      numVotes     _merge
# 232       NaN  left_only
# 233   10132.0       both

# %%
Disney_IMDB.drop(Disney_IMDB[Disney_IMDB['tconst'] == "tt1924347"].index, inplace = True)
Disney_IMDB.drop(Disney_IMDB[Disney_IMDB['orig_index'] == "3787"].index, inplace = True)

# %%
# Error made in the previous file.  tt6476724 should habe been dropped.
Disney_IMDB[Disney_IMDB['lower_title'].str.contains("the secret of the magic gourd")]
# Out:
#      orig_index                      DFL_title     tconst titleType  \
# 384        5546  The Secret of The Magic Gourd  tt0496386     movie
# 385        5547  The Secret of The Magic Gourd  tt6476724     movie
#
#                       primaryTitle       originalTitle  startYear  \
# 384  The Secret of the Magic Gourd  Bao hu lu de mi mi       2007
# 385  The Secret of the Magic Gourd  Bao hu lu de bi mi       1963
#
#     runtimeMinutes                genres                    lower_title  \
# 384             84          Drama,Family  the secret of the magic gourd
# 385             68  Comedy,Drama,Fantasy  the secret of the magic gourd
#
#      averageRating  numVotes     _merge
# 384            5.1     707.0       both
# 385            NaN       NaN  left_only

# %%
Disney_IMDB.drop(Disney_IMDB[Disney_IMDB['tconst'] == "tt6476724"].index, inplace = True)

# %%
# This film has not yet been released (expected 2024) tt4872762
Disney_IMDB[Disney_IMDB['lower_title'].str.contains("the sword in the stone")]
# Out:
#      orig_index               DFL_title     tconst titleType  \
# 396        5597  The Sword in the Stone  tt0057546     movie
# 397        5602  The Sword in the Stone  tt4872762     movie
#
#                primaryTitle           originalTitle  startYear runtimeMinutes  \
# 396  The Sword in the Stone  The Sword in the Stone       1963             79
# 397  The Sword in the Stone  The Sword in the Stone       2024             \N
#
#                          genres             lower_title  averageRating  \
# 396  Adventure,Animation,Comedy  the sword in the stone            7.2
# 397     Action,Adventure,Family  the sword in the stone            NaN
#
#      numVotes     _merge
# 396   95874.0       both
# 397       NaN  left_only

# %%
Disney_IMDB.drop(Disney_IMDB[Disney_IMDB['tconst'] == "tt4872762"].index, inplace = True)

# %%
Disney_IMDB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 442 entries, 0 to 452
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   orig_index      442 non-null    int64
#  1   DFL_title       442 non-null    object
#  2   tconst          442 non-null    object
#  3   titleType       442 non-null    object
#  4   primaryTitle    442 non-null    object
#  5   originalTitle   442 non-null    object
#  6   startYear       442 non-null    int64
#  7   runtimeMinutes  442 non-null    object
#  8   genres          442 non-null    object
#  9   lower_title     442 non-null    object
#  10  averageRating   442 non-null    float64
#  11  numVotes        442 non-null    float64
#  12  _merge          442 non-null    category
# dtypes: category(1), float64(2), int64(2), object(8)
# memory usage: 45.5+ KB

# %%
Disney_IMDB['titleType'].value_counts()
# Out:
# movie    442
# Name: titleType, dtype: int64

# %% [markdown]
# We've removed errors, duplcates, and removed anything that was not a feature release.  That leaves us with 442 Disney Movies. This is the data we will use to scrape IMDB for additional features.

# %% [markdown]
# ## 03.05 Export Features Films

# %%
Disney_IMDB.to_csv('../Bens_Data/Updated_IMDB_Disney_442.csv')
