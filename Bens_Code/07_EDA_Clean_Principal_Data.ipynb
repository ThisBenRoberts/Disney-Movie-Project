# %% [markdown]
# # 07 EDA and Clean Principals Data

# %% [markdown]
# ## 07.01 Imports

# %% [markdown]
# ### 07.01.01 Python Imports

# %%
import pandas as pd
import numpy as np
import re
import datetime

# %% [markdown]
# ### 07.01.02 Import Principal History Data

# %%
principals_history = pd.read_csv('../Bens_Data/directors_writers_combined_history_updated.csv')
principals_history.drop(columns=['Unnamed: 0','_merge'], inplace=True)

# %%
principals_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7765 entries, 0 to 7764
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          7765 non-null   object
#  1   titleType       7765 non-null   object
#  2   primaryTitle    7765 non-null   object
#  3   startYear       7765 non-null   object
#  4   runtimeMinutes  7765 non-null   object
#  5   genres          7765 non-null   object
#  6   newurl          7765 non-null   object
#  7   mpaarating      7765 non-null   object
#  8   rlsdt           7765 non-null   object
#  9   budget          7765 non-null   object
#  10  wordlwide       7765 non-null   object
#  11  averageRating   6003 non-null   float64
#  12  numVotes        6003 non-null   float64
# dtypes: float64(2), object(11)
# memory usage: 788.8+ KB

# %% [markdown]
# To demonstrate or include a principal's trackrecord as part of our model, we're going to focus on the start year (so that get ratings for previous projects), genre (so we can get ratings for similar projects), average rating, and numvotes. We will attempt to use the rlsdat when we can but it might prove too dificult.  We also have too much missing data from the budget and worldwide columns to use those for now.

# %% [markdown]
# ## 07.02 Average Ratings

# %% [markdown]
# we'll remove any missing the averageRating and/or numVotes. We're not going to attempt to guess or impute the ratings or number of votes.  We're just going to remove those that are missing.

# %%
principals_history.head(10)
# Out:
#        tconst titleType                             primaryTitle startYear  \
# 0   tt0113403     movie                       A Midwinter's Tale      1995
# 1   tt0450972     movie                           As You Like It      2006
# 2   tt0475331     movie                          The Magic Flute      2006
# 3   tt0800369     movie                                     Thor      2011
# 4  tt11229040     movie                 Untitled Bee Gees Biopic      2022
# 5  tt12789558     movie                                  Belfast      2021
# 6   tt1661199     movie                               Cinderella      2015
# 7   tt3089630     movie                             Artemis Fowl      2020
# 8   tt5226844     movie  Branagh Theatre Live: The Winter's Tale      2015
# 9   tt5943392     movie   Branagh Theatre Live: Romeo and Juliet      2016
#
#   runtimeMinutes                    genres  \
# 0             99                    Comedy
# 1            127      Comedy,Drama,Romance
# 2            135     Drama,Musical,Romance
# 3            115  Action,Adventure,Fantasy
# 4             \N     Biography,Drama,Music
# 5             98   Biography,Drama,History
# 6            105    Adventure,Drama,Family
# 7             95  Adventure,Family,Fantasy
# 8            180                     Drama
# 9            165                   Romance
#
#                                   newurl mpaarating  \
# 0   https://www.imdb.com/title/tt0113403          R
# 1   https://www.imdb.com/title/tt0450972         PG
# 2   https://www.imdb.com/title/tt0475331      error
# 3   https://www.imdb.com/title/tt0800369      PG-13
# 4  https://www.imdb.com/title/tt11229040      error
# 5  https://www.imdb.com/title/tt12789558      PG-13
# 6   https://www.imdb.com/title/tt1661199         PG
# 7   https://www.imdb.com/title/tt3089630         PG
# 8   https://www.imdb.com/title/tt5226844      error
# 9   https://www.imdb.com/title/tt5943392      error
#
#                                  rlsdt                    budget  \
# 0    February 16, 1996 (United States)                     error
# 1  September 21, 2007 (United Kingdom)                     error
# 2           December 13, 2006 (France)   $27,000,000 (estimated)
# 3          May 6, 2011 (United States)  $150,000,000 (estimated)
# 4                                error                     error
# 5    November 12, 2021 (United States)                     error
# 6       March 13, 2015 (United States)   $95,000,000 (estimated)
# 7        June 12, 2020 (United States)                     error
# 8     December 4, 2019 (United States)                     error
# 9            November 18, 2016 (Japan)                     error
#
#       wordlwide  averageRating  numVotes
# 0      $469,571            7.2    2577.0
# 1      $563,162            6.1    3354.0
# 2    $2,000,853            6.5    1236.0
# 3  $449,326,618            7.0  810857.0
# 4         error            NaN       NaN
# 5   $46,922,870            7.3   44239.0
# 6  $542,358,331            6.9  173300.0
# 7         error            4.2   27155.0
# 8      $141,143            7.8     269.0
# 9    $1,191,021            8.2     377.0

# %%
principals_history['averageRating'].isnull().sum(), principals_history['numVotes'].isnull().sum()
# Out:
# (1762, 1762)

# %%
principals_history.drop(principals_history[principals_history['averageRating'].isnull()].index, inplace = True)

# %%
principals_history['averageRating'].isnull().sum(), principals_history['numVotes'].isnull().sum()
# Out:
# (0, 0)

# %% [markdown]
# ## 07.03 Start Year

# %%
principals_history['startYear'].isnull().sum(), principals_history['startYear'].str.startswith('\\N').sum()
# Out:
# (0, 0)

# %% [markdown]
# ## 07.04 Genres

# %% [markdown]
# We're not going to attempt to guess or impute the genres.  However, we would like to use them if at all possible. Any genre data that is missing will be filled with "unknown". We will do some vectorization on these columns later so that we can try to get track records for similar categories when building our final model.

# %%
principals_history['genres'].isnull().sum(), principals_history['genres'].str.startswith('\\N').sum()
# Out:
# (0, 47)

# %%
principals_history['genres'].value_counts()
# Out:
# Drama                         434
# Comedy                        353
# Adventure,Animation,Comedy    199
# Western                       186
# Comedy,Romance                147
#                              ...
# Action,History,Western          1
# War,Western                     1
# Adventure,Musical,War           1
# Adventure,Mystery,War           1
# Biography,Drama,Western         1
# Name: genres, Length: 485, dtype: int64

# %%
principals_history[principals_history['genres'].str.startswith('\\N')]
# Out:
#           tconst titleType                                       primaryTitle  \
# 572    tt2546296     movie  The 2006 Academy Award Nominated Short Films: ...
# 1746   tt0102098     movie                               Im Kreise der Lieben
# 2107   tt2776272     movie                 Cigars: The Heart and Soul of Cuba
# 2329   tt0219611     movie                                       Cosmo's Tale
# 2888   tt0022049     movie     The Land of Oz, a Sequel to the 'Wizard of Oz'
# 3025   tt0127905     movie                                Store forventninger
# 3111   tt0070025     movie                                The Devil's Elixirs
# 3126   tt1686881     movie                                            Juwelen
# 3202   tt0259478     movie                               Oru Thayin Sabhatham
# 3223   tt1369559     movie                                    Raja Nanna Raja
# 3226   tt1427154     movie                                          Vani Rani
# 3228   tt1477039     movie                                        Nalla Neram
# 3291   tt0071584     movie                        Grote Klaas en kleine Klaas
# 3486   tt0082957     movie                                       Puente aéreo
# 3756   tt0196828     movie                        Party Games for Adults Only
# 4091   tt1833536     movie  The Bolshoi Ballet: Live From Moscow - Don Qui...
# 4113   tt0133802     movie                                   The Girl of Gold
# 4640   tt0012344     movie                                               Kean
# 4720   tt0193856     movie                               La dame de Monsoreau
# 4726   tt0211675     movie                                 I tre moschettieri
# 4745   tt0480971     movie                                  Chicot the Jester
# 4761  tt13298942     movie  Le comte de Monte-Cristo: 1ère époque 'La trah...
# 4762  tt13298950     movie  Le comte de Monte-Cristo: 2ème époque 'La veng...
# 4956   tt0048053     movie                                Familia provisional
# 5189   tt0170810     movie          Passion and Romance: Windows of the Heart
# 5212   tt0168017     movie                                           Joy Ride
# 5354   tt0009720     movie                         Les travailleurs de la mer
# 5396   tt0260015     movie                                 Plight of the Poor
# 5419   tt2798094     movie   The Bolshoi Ballet: Live From Moscow - Esmeralda
# 5606   tt0170236     movie                                             Maggie
# 5710   tt0057250     movie                            Liebe will gelernt sein
# 5719   tt0192689     movie                         Toscanito y los detectives
# 6217   tt0059507     movie                      Nihon Kyokaku-den: Naniwa-hen
# 6218   tt0060755     movie                              Duel at Kaminari Gate
# 6247   tt0324207     movie                                Teppôdama no bigaku
# 6263   tt5420604     movie                        Yogiri yo kon'ya mo arigatô
# 6334   tt0056935     movie                                         Cinderella
# 6357   tt1233517     movie                           La belle au bois dormant
# 6377   tt0089659     movie                                          Die Nacht
# 6527   tt0245792     movie                                 Breach of Contract
# 6574   tt0015044     movie                                          Comedians
# 6756   tt0024362     movie                                   Mother and Child
# 6775   tt0041564     movie                                       Die Kuckucks
# 6878   tt0255299     movie                                  Karutha Rathrikal
# 6916   tt0134796     movie                                The Lost Manuscript
# 7219   tt3751258     movie                        Les Naufragés du Fol Espoir
# 7395   tt1381278     movie         It Was Great, But I Was Ready to Come Home
#
#      startYear runtimeMinutes genres                                 newurl  \
# 572       2007             45     \N   https://www.imdb.com/title/tt2546296
# 1746      1991             79     \N   https://www.imdb.com/title/tt0102098
# 2107      2011             51     \N   https://www.imdb.com/title/tt2776272
# 2329      1998             \N     \N   https://www.imdb.com/title/tt0219611
# 2888      1932             \N     \N   https://www.imdb.com/title/tt0022049
# 3025      1922             \N     \N   https://www.imdb.com/title/tt0127905
# 3111      1973             96     \N   https://www.imdb.com/title/tt0070025
# 3126      1930             \N     \N   https://www.imdb.com/title/tt1686881
# 3202      1987             \N     \N   https://www.imdb.com/title/tt0259478
# 3223      1976            133     \N   https://www.imdb.com/title/tt1369559
# 3226      1974            138     \N   https://www.imdb.com/title/tt1427154
# 3228      1972            163     \N   https://www.imdb.com/title/tt1477039
# 3291      1974             \N     \N   https://www.imdb.com/title/tt0071584
# 3486      1981            100     \N   https://www.imdb.com/title/tt0082957
# 3756      1984            103     \N   https://www.imdb.com/title/tt0196828
# 4091      2011             \N     \N   https://www.imdb.com/title/tt1833536
# 4113      1925             \N     \N   https://www.imdb.com/title/tt0133802
# 4640      1921             \N     \N   https://www.imdb.com/title/tt0012344
# 4720      1923             \N     \N   https://www.imdb.com/title/tt0193856
# 4726      1909             \N     \N   https://www.imdb.com/title/tt0211675
# 4745      1913             \N     \N   https://www.imdb.com/title/tt0480971
# 4761      1955             99     \N  https://www.imdb.com/title/tt13298942
# 4762      1955             89     \N  https://www.imdb.com/title/tt13298950
# 4956      1958             97     \N   https://www.imdb.com/title/tt0048053
# 5189      1997             \N     \N   https://www.imdb.com/title/tt0170810
# 5212      1935             78     \N   https://www.imdb.com/title/tt0168017
# 5354      1918             \N     \N   https://www.imdb.com/title/tt0009720
# 5396      1950            197     \N   https://www.imdb.com/title/tt0260015
# 5419      2011             \N     \N   https://www.imdb.com/title/tt2798094
# 5606      1989             86     \N   https://www.imdb.com/title/tt0170236
# 5710      1963             93     \N   https://www.imdb.com/title/tt0057250
# 5719      1950             76     \N   https://www.imdb.com/title/tt0192689
# 6217      1965             98     \N   https://www.imdb.com/title/tt0059507
# 6218      1966             99     \N   https://www.imdb.com/title/tt0060755
# 6247      1973            100     \N   https://www.imdb.com/title/tt0324207
# 6263      1967             93     \N   https://www.imdb.com/title/tt5420604
# 6334      1963             \N     \N   https://www.imdb.com/title/tt0056935
# 6357      1922             \N     \N   https://www.imdb.com/title/tt1233517
# 6377      1985            367     \N   https://www.imdb.com/title/tt0089659
# 6527      1982             \N     \N   https://www.imdb.com/title/tt0245792
# 6574      1925             \N     \N   https://www.imdb.com/title/tt0015044
# 6756      1934            121     \N   https://www.imdb.com/title/tt0024362
# 6775      1949             93     \N   https://www.imdb.com/title/tt0041564
# 6878      1967             \N     \N   https://www.imdb.com/title/tt0255299
# 6916      1974             45     \N   https://www.imdb.com/title/tt0134796
# 7219      2014            180     \N   https://www.imdb.com/title/tt3751258
# 7395      2009             61     \N   https://www.imdb.com/title/tt1381278
#
#      mpaarating                               rlsdt budget wordlwide  \
# 572       error   February 16, 2007 (United States)  error     error
# 1746      error         December 12, 1991 (Germany)  error     error
# 2107  Not Rated       December 2011 (United States)  error     error
# 2329      error                               error  error     error
# 2888      error       February 1932 (United States)  error     error
# 3025      error           August 28, 1922 (Denmark)  error     error
# 3111      error      April 6, 1973 (Czechoslovakia)  error     error
# 3126      error              May 30, 1930 (Austria)  error     error
# 3202      error                               error  error     error
# 3223  Not Rated                               error  error     error
# 3226      error              April 12, 1974 (India)  error     error
# 3228  Not Rated                               error  error     error
# 3291      error                               error  error     error
# 3486      error           December 21, 1981 (Spain)  error     error
# 3756      error                               error  error     error
# 4091      error       March 6, 2011 (United States)  error     error
# 4113      error   February 16, 1925 (United States)  error     error
# 4640      error              June 5, 1922 (Denmark)  error     error
# 4720      error             April 27, 1923 (France)  error     error
# 4726      error                  March 1909 (Italy)  error     error
# 4745      error          April 1914 (United States)  error     error
# 4761      error           January 14, 1955 (France)  error     error
# 4762      error           January 14, 1955 (France)  error     error
# 4956      error               March 3, 1958 (Spain)  error     error
# 5189      error                               error  error     error
# 5212      error  December 16, 1935 (United Kingdom)  error     error
# 5354      error              March 3, 1918 (France)  error     error
# 5396      error            November 9, 1950 (India)  error     error
# 5419      error             October 9, 2011 (Italy)  error     error
# 5606      error          October 2, 1989 (Bulgaria)  error     error
# 5710      error    February 27, 1963 (West Germany)  error     error
# 5719      error                               error  error     error
# 6217      error            January 30, 1965 (Japan)  error     error
# 6218      error          September 17, 1966 (Japan)  error     error
# 6247      error           February 10, 1973 (Japan)  error     error
# 6263      error              March 11, 1967 (Japan)  error     error
# 6334      error               1963 (United Kingdom)  error     error
# 6357      error                               error  error     error
# 6377      error          May 8, 1985 (West Germany)  error     error
# 6527      error                               error  error     error
# 6574      error        April 23, 1925 (Netherlands)  error     error
# 6756      error   November 29, 1934 (United States)  error     error
# 6775      error             April 8, 1949 (Germany)  error     error
# 6878      error                               error  error     error
# 6916      error                               error  error     error
# 7219      error            August 7, 2014 (Germany)  error     error
# 7395      error       March 2, 2014 (United States)  error     error
#
#       averageRating  numVotes
# 572             5.9      29.0
# 1746            6.9      18.0
# 2107            7.4       7.0
# 2329            6.9      16.0
# 2888            6.8      21.0
# 3025            6.1      12.0
# 3111            6.0      23.0
# 3126            6.4      13.0
# 3202            5.6      13.0
# 3223            8.7      48.0
# 3226            7.0      21.0
# 3228            7.1      37.0
# 3291            5.5       9.0
# 3486            4.1      20.0
# 3756            5.0      39.0
# 4091            7.9       9.0
# 4113            6.8      17.0
# 4640            5.9      15.0
# 4720            5.1      18.0
# 4726            3.9      17.0
# 4745            5.3      10.0
# 4761            7.6      17.0
# 4762            7.6      16.0
# 4956            6.8       7.0
# 5189            4.8      29.0
# 5212            5.0      16.0
# 5354            6.8      12.0
# 5396            7.1      10.0
# 5419            8.2       6.0
# 5606            6.9      18.0
# 5710            6.8      29.0
# 5719            7.6       8.0
# 6217            6.2      14.0
# 6218            7.1       8.0
# 6247            7.1      38.0
# 6263            6.4       8.0
# 6334            5.6      16.0
# 6357            6.1      11.0
# 6377            8.4      41.0
# 6527            6.6      31.0
# 6574            6.8      15.0
# 6756            3.2      13.0
# 6775            6.5      13.0
# 6878            6.7      11.0
# 6916            6.8      14.0
# 7219            7.9      10.0
# 7395            4.6      28.0

# %%
principals_history.loc[(principals_history['genres'].str.startswith('\\N')), 'genres'] = 'unknown'

# %%
principals_history['genres'].isnull().sum(), principals_history['genres'].str.startswith('\\N').sum()
# Out:
# (0, 0)

# %% [markdown]
# ## 07.05 Run Time

# %%
principals_history[principals_history['runtimeMinutes'].str.startswith('\\N')]
# Out:
#          tconst titleType              primaryTitle startYear runtimeMinutes  \
# 223   tt0429478     movie                 3-D Rocks      2005             \N
# 407   tt1954412     movie           Someone Like Me      2012             \N
# 1072  tt2710534     movie              Arrive Alive      1990             \N
# 1239  tt0300227     movie  Het mysterie van het lam      1987             \N
# 1261  tt0499608     movie                   Tranced      2010             \N
# ...         ...       ...                       ...       ...            ...
# 7675  tt0427626     movie                Ang panday      1980             \N
# 7676  tt0428937     movie             Ang panday IV      1984             \N
# 7677  tt0436659     movie      Pagbabalik ng panday      1981             \N
# 7702  tt1305840     movie                Aloo Chaat      2009             \N
# 7703  tt8115900     movie              The Bad Guys      2022             \N
#
#                           genres                                newurl  \
# 223                  Documentary  https://www.imdb.com/title/tt0429478
# 407                        Drama  https://www.imdb.com/title/tt1954412
# 1072       Action,Comedy,Mystery  https://www.imdb.com/title/tt2710534
# 1239                   Animation  https://www.imdb.com/title/tt0300227
# 1261       Drama,Fantasy,Romance  https://www.imdb.com/title/tt0499608
# ...                          ...                                   ...
# 7675       Action,Fantasy,Horror  https://www.imdb.com/title/tt0427626
# 7676    Action,Adventure,Fantasy  https://www.imdb.com/title/tt0428937
# 7677    Action,Adventure,Fantasy  https://www.imdb.com/title/tt0436659
# 7702        Comedy,Drama,Romance  https://www.imdb.com/title/tt1305840
# 7703  Adventure,Animation,Comedy  https://www.imdb.com/title/tt8115900
#
#      mpaarating                            rlsdt                  budget  \
# 223       error                            error                   error
# 407       error      March 1, 2012 (Switzerland)                   error
# 1072      error             1990 (United States)                   error
# 1239      error                            error                   error
# 1261      error             2010 (United States)  $4,000,000 (estimated)
# ...         ...                              ...                     ...
# 7675      error  December 25, 1980 (Philippines)                   error
# 7676      error  December 25, 1984 (Philippines)                   error
# 7677      error  December 25, 1981 (Philippines)                   error
# 7702      error           March 20, 2009 (India)                   error
# 7703         PG   April 22, 2022 (United States)                   error
#
#         wordlwide  averageRating  numVotes
# 223         error            7.4      27.0
# 407         error            7.1     144.0
# 1072        error            5.8      11.0
# 1239        error            5.4       8.0
# 1261        error            5.4      49.0
# ...           ...            ...       ...
# 7675        error            4.5      82.0
# 7676        error            5.4      14.0
# 7677        error            4.7      21.0
# 7702   $1,213,516            5.9     932.0
# 7703  $29,584,292            7.1     318.0
#
# [157 rows x 13 columns]

# %% [markdown]
# There remains 157 films without run times.  After spot checking a few, some were made, some were never released, some were released but not in the States.  Some border on pornography.   We may or may not use movies of similar runtimes, so we're just going to leave the data in here for now.

# %%
principals_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6003 entries, 0 to 7756
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          6003 non-null   object
#  1   titleType       6003 non-null   object
#  2   primaryTitle    6003 non-null   object
#  3   startYear       6003 non-null   object
#  4   runtimeMinutes  6003 non-null   object
#  5   genres          6003 non-null   object
#  6   newurl          6003 non-null   object
#  7   mpaarating      6003 non-null   object
#  8   rlsdt           6003 non-null   object
#  9   budget          6003 non-null   object
#  10  wordlwide       6003 non-null   object
#  11  averageRating   6003 non-null   float64
#  12  numVotes        6003 non-null   float64
# dtypes: float64(2), object(11)
# memory usage: 656.6+ KB

# %% [markdown]
# ## 07.06 Budget and Worldwide Revenue

# %% [markdown]
# Budget and Worldwide should be numbers, not object.  Let's figure out what's going on.

# %%
principals_history['budget'].isnull().sum(), principals_history['budget'].str.startswith('\\N').sum(), principals_history['budget'].str.contains('error').sum()
# Out:
# (0, 0, 3835)

# %%
principals_history['wordlwide'].isnull().sum(), principals_history['wordlwide'].str.startswith('\\N').sum(), principals_history['wordlwide'].str.contains('error').sum()
# Out:
# (0, 0, 3813)

# %%
principals_history['wordlwide'].value_counts()
# Out:
# error           3813
# $469,571           1
# $186,797,986       1
# $369,884,651       1
# $17,492,014        1
#                 ...
# $51,024,243        1
# $69,319,426        1
# $76,347,426        1
# $44,095,996        1
# $62,856,743        1
# Name: wordlwide, Length: 2191, dtype: int64

# %% [markdown]
# It looks like 'error' is the only thing preventing 'wordlwide' from being reconginzed as a number.

# %%
principals_history['wordlwide'].head(60)
# Out:
# 0           $469,571
# 1           $563,162
# 2         $2,000,853
# 3       $449,326,618
# 5        $46,922,870
# 6       $542,358,331
# 7              error
# 8           $141,143
# 9         $1,191,021
# 10             error
# 11       $78,371,200
# 12      $131,060,248
# 13       $90,000,098
# 14      $520,881,154
# 15      $378,882,411
# 16    $2,201,647,264
# 17       $27,570,076
# 18    $2,847,379,794
# 25       $21,095,638
# 26       $69,821,334
# 27       $85,313,124
# 28       $36,611,610
# 29       $57,269,863
# 30      $126,297,830
# 31      $152,368,585
# 32      $137,783,840
# 33       $48,424,341
# 34      $355,237,933
# 35      $309,492,681
# 36       $35,242,897
# 37      $345,823,032
# 38      $316,791,257
# 39       $38,364,277
# 40      $108,539,911
# 41      $760,006,945
# 42      $485,930,816
# 43       $27,426,335
# 48       $93,920,758
# 49       $69,721,966
# 51       $96,983,009
# 52             error
# 53       $12,283,966
# 54      $220,021,259
# 55      $392,924,807
# 58             error
# 59        $8,083,942
# 61            $3,414
# 62           $23,557
# 63       $26,023,860
# 64       $30,979,816
# 65        $8,618,766
# 66       $14,561,425
# 67        $4,184,990
# 68        $3,703,548
# 69        $6,416,569
# 70       $20,271,129
# 71        $4,046,144
# 72             error
# 73       $15,431,177
# 74             error
# Name: wordlwide, dtype: object

# %%
principals_history['wordlwide'].tail(60)
# Out:
# 7597    $414,351,546
# 7603    $410,902,662
# 7606    $125,897,478
# 7609     $28,748,076
# 7611           error
# 7612           error
# 7613           error
# 7614           error
# 7615           error
# 7616           error
# 7617           error
# 7618           error
# 7619           error
# 7621     $11,229,399
# 7622           error
# 7634    $433,477,601
# 7638    $235,956,898
# 7641     $96,942,115
# 7642     $95,017,038
# 7650        $291,742
# 7653         $68,643
# 7655           error
# 7657           error
# 7665        $499,649
# 7666         $17,722
# 7667           error
# 7668           error
# 7669      $2,408,629
# 7670           error
# 7672           error
# 7673           error
# 7674           error
# 7675           error
# 7676           error
# 7677           error
# 7679           error
# 7685           error
# 7692     $64,626,786
# 7693    $400,671,789
# 7695    $303,144,152
# 7700    $409,231,607
# 7702      $1,213,516
# 7703     $29,584,292
# 7704           error
# 7705    $214,215,889
# 7707        $114,603
# 7713     $59,945,012
# 7715           error
# 7716           error
# 7717           error
# 7720    $274,650,803
# 7734           error
# 7737    $104,391,623
# 7738    $374,583,879
# 7740     $10,079,201
# 7745           error
# 7750      $9,074,749
# 7751     $10,421,847
# 7754      $1,561,698
# 7756     $62,856,743
# Name: wordlwide, dtype: object

# %% [markdown]
# Similarly, it looks like 'error' and the trailing '(estimated)' are preventing 'budget' from being reconginzed as a number.

# %%
principals_history['budget'].head(60)
# Out:
# 0                        error
# 1                        error
# 2      $27,000,000 (estimated)
# 3     $150,000,000 (estimated)
# 5                        error
# 6      $95,000,000 (estimated)
# 7                        error
# 8                        error
# 9                        error
# 10        $145,786 (estimated)
# 11      $6,400,000 (estimated)
# 12     $18,500,000 (estimated)
# 13     $70,000,000 (estimated)
# 14    $102,000,000 (estimated)
# 15    $115,000,000 (estimated)
# 16    $200,000,000 (estimated)
# 17     $13,000,000 (estimated)
# 18    $237,000,000 (estimated)
# 25      $8,100,000 (estimated)
# 26     $11,000,000 (estimated)
# 27     $17,500,000 (estimated)
# 28     $18,000,000 (estimated)
# 29     $35,000,000 (estimated)
# 30     $20,000,000 (estimated)
# 31     $40,000,000 (estimated)
# 32     $60,000,000 (estimated)
# 33      $6,000,000 (estimated)
# 34     $52,000,000 (estimated)
# 35     $80,000,000 (estimated)
# 36     $80,000,000 (estimated)
# 37    $123,000,000 (estimated)
# 38     $58,000,000 (estimated)
# 39     $60,000,000 (estimated)
# 40     $88,000,000 (estimated)
# 41    $125,000,000 (estimated)
# 42    $150,000,000 (estimated)
# 43     $25,000,000 (estimated)
# 48    $100,000,000 (estimated)
# 49     $70,000,000 (estimated)
# 51     $38,000,000 (estimated)
# 52                       error
# 53                       error
# 54     $75,000,000 (estimated)
# 55    $275,000,000 (estimated)
# 58     $45,000,000 (estimated)
# 59                       error
# 61                       error
# 62         $10,000 (estimated)
# 63      $5,000,000 (estimated)
# 64     $40,000,000 (estimated)
# 65      $6,000,000 (estimated)
# 66      $9,500,000 (estimated)
# 67     $10,000,000 (estimated)
# 68     $15,000,000 (estimated)
# 69     $10,000,000 (estimated)
# 70     $15,000,000 (estimated)
# 71                       error
# 72                       error
# 73     $26,000,000 (estimated)
# 74            $400 (estimated)
# Name: budget, dtype: object

# %%
principals_history['budget'].tail(60)
# Out:
# 7597     $81,000,000 (estimated)
# 7603    $104,000,000 (estimated)
# 7606                       error
# 7609     €22,000,000 (estimated)
# 7611                       error
# 7612                       error
# 7613                       error
# 7614                       error
# 7615                       error
# 7616                       error
# 7617                       error
# 7618                       error
# 7619                       error
# 7621                       error
# 7622                       error
# 7634    $150,000,000 (estimated)
# 7638     $25,000,000 (estimated)
# 7641     $20,000,000 (estimated)
# 7642     $21,000,000 (estimated)
# 7650      $7,000,000 (estimated)
# 7653                       error
# 7655                       error
# 7657                       error
# 7665                       error
# 7666                       error
# 7667                       error
# 7668                       error
# 7669                       error
# 7670                       error
# 7672                       error
# 7673                       error
# 7674                       error
# 7675                       error
# 7676                       error
# 7677                       error
# 7679                       error
# 7685                       error
# 7692     $30,000,000 (estimated)
# 7693    $165,000,000 (estimated)
# 7695    $110,000,000 (estimated)
# 7700    $125,000,000 (estimated)
# 7702                       error
# 7703                       error
# 7704                       error
# 7705     $50,000,000 (estimated)
# 7707                       error
# 7713     $35,000,000 (estimated)
# 7715                       error
# 7716                       error
# 7717                       error
# 7720     $94,000,000 (estimated)
# 7734                       error
# 7737     $60,000,000 (estimated)
# 7738     $75,000,000 (estimated)
# 7740     $40,000,000 (estimated)
# 7745     $16,937,665 (estimated)
# 7750      $8,000,000 (estimated)
# 7751      $4,900,000 (estimated)
# 7754      $8,000,000 (estimated)
# 7756     $20,000,000 (estimated)
# Name: budget, dtype: object

# %% [markdown]
# If we removed the (esitmated), and wrote the formula so that it skipped 'error', we could still get ROI for some 2,000 films.

# %%
principals_history.head()
# Out:
#        tconst titleType        primaryTitle startYear runtimeMinutes  \
# 0   tt0113403     movie  A Midwinter's Tale      1995             99
# 1   tt0450972     movie      As You Like It      2006            127
# 2   tt0475331     movie     The Magic Flute      2006            135
# 3   tt0800369     movie                Thor      2011            115
# 5  tt12789558     movie             Belfast      2021             98
#
#                      genres                                 newurl mpaarating  \
# 0                    Comedy   https://www.imdb.com/title/tt0113403          R
# 1      Comedy,Drama,Romance   https://www.imdb.com/title/tt0450972         PG
# 2     Drama,Musical,Romance   https://www.imdb.com/title/tt0475331      error
# 3  Action,Adventure,Fantasy   https://www.imdb.com/title/tt0800369      PG-13
# 5   Biography,Drama,History  https://www.imdb.com/title/tt12789558      PG-13
#
#                                  rlsdt                    budget  \
# 0    February 16, 1996 (United States)                     error
# 1  September 21, 2007 (United Kingdom)                     error
# 2           December 13, 2006 (France)   $27,000,000 (estimated)
# 3          May 6, 2011 (United States)  $150,000,000 (estimated)
# 5    November 12, 2021 (United States)                     error
#
#       wordlwide  averageRating  numVotes
# 0      $469,571            7.2    2577.0
# 1      $563,162            6.1    3354.0
# 2    $2,000,853            6.5    1236.0
# 3  $449,326,618            7.0  810857.0
# 5   $46,922,870            7.3   44239.0

# %%
principals_history['budget'].head(50)
# Out:
# 0                        error
# 1                        error
# 2      $27,000,000 (estimated)
# 3     $150,000,000 (estimated)
# 5                        error
# 6      $95,000,000 (estimated)
# 7                        error
# 8                        error
# 9                        error
# 10        $145,786 (estimated)
# 11      $6,400,000 (estimated)
# 12     $18,500,000 (estimated)
# 13     $70,000,000 (estimated)
# 14    $102,000,000 (estimated)
# 15    $115,000,000 (estimated)
# 16    $200,000,000 (estimated)
# 17     $13,000,000 (estimated)
# 18    $237,000,000 (estimated)
# 25      $8,100,000 (estimated)
# 26     $11,000,000 (estimated)
# 27     $17,500,000 (estimated)
# 28     $18,000,000 (estimated)
# 29     $35,000,000 (estimated)
# 30     $20,000,000 (estimated)
# 31     $40,000,000 (estimated)
# 32     $60,000,000 (estimated)
# 33      $6,000,000 (estimated)
# 34     $52,000,000 (estimated)
# 35     $80,000,000 (estimated)
# 36     $80,000,000 (estimated)
# 37    $123,000,000 (estimated)
# 38     $58,000,000 (estimated)
# 39     $60,000,000 (estimated)
# 40     $88,000,000 (estimated)
# 41    $125,000,000 (estimated)
# 42    $150,000,000 (estimated)
# 43     $25,000,000 (estimated)
# 48    $100,000,000 (estimated)
# 49     $70,000,000 (estimated)
# 51     $38,000,000 (estimated)
# 52                       error
# 53                       error
# 54     $75,000,000 (estimated)
# 55    $275,000,000 (estimated)
# 58     $45,000,000 (estimated)
# 59                       error
# 61                       error
# 62         $10,000 (estimated)
# 63      $5,000,000 (estimated)
# 64     $40,000,000 (estimated)
# Name: budget, dtype: object

# %% [markdown]
# ### 07.06.01 Clean Up Budget Data

# %%
# Remove 'estimated'
principals_history['budget_adj'] = principals_history['budget'].apply(lambda x: x[:-12] if "estimated" in x else x)
principals_history['budget_adj'].head(50)
# Out:
# 0            error
# 1            error
# 2      $27,000,000
# 3     $150,000,000
# 5            error
# 6      $95,000,000
# 7            error
# 8            error
# 9            error
# 10        $145,786
# 11      $6,400,000
# 12     $18,500,000
# 13     $70,000,000
# 14    $102,000,000
# 15    $115,000,000
# 16    $200,000,000
# 17     $13,000,000
# 18    $237,000,000
# 25      $8,100,000
# 26     $11,000,000
# 27     $17,500,000
# 28     $18,000,000
# 29     $35,000,000
# 30     $20,000,000
# 31     $40,000,000
# 32     $60,000,000
# 33      $6,000,000
# 34     $52,000,000
# 35     $80,000,000
# 36     $80,000,000
# 37    $123,000,000
# 38     $58,000,000
# 39     $60,000,000
# 40     $88,000,000
# 41    $125,000,000
# 42    $150,000,000
# 43     $25,000,000
# 48    $100,000,000
# 49     $70,000,000
# 51     $38,000,000
# 52           error
# 53           error
# 54     $75,000,000
# 55    $275,000,000
# 58     $45,000,000
# 59           error
# 61           error
# 62         $10,000
# 63      $5,000,000
# 64     $40,000,000
# Name: budget_adj, dtype: object

# %%
# Remove commas
principals_history['budget_adj'] = principals_history['budget_adj'].apply(lambda x: x.replace(",",""))
principals_history['budget_adj'] = principals_history['budget_adj'].apply(lambda x: x if "error" in x else x[1:])
principals_history['budget_adj'].head()
# Out:
# 0        error
# 1        error
# 2     27000000
# 3    150000000
# 5        error
# Name: budget_adj, dtype: object

# %%
# Remove 'error'
principals_history['budget_adj'] = principals_history['budget_adj'].apply(lambda x: 0 if "error" in x else x)
principals_history['budget_adj'].head()
# Out:
# 0            0
# 1            0
# 2     27000000
# 3    150000000
# 5            0
# Name: budget_adj, dtype: object

# %%
# Convert budget to integers
def convert(val):
    try:
        return(int(val))
    except:
        return(0)


principals_history['budget_adj'] = principals_history['budget_adj'].apply(lambda x: convert(x))

# %%
principals_history['budget_adj']
# Out:
# 0               0
# 1               0
# 2        27000000
# 3       150000000
# 5               0
#           ...
# 7745     16937665
# 7750      8000000
# 7751      4900000
# 7754      8000000
# 7756     20000000
# Name: budget_adj, Length: 6003, dtype: int64

# %% [markdown]
# ### 07.06.02 Clean Up Wordlwide Revenue Data

# %%
# Perform the same cleanup on Worldwide, remove commas, remove errors, then convert
principals_history['worldwide_adj'] = principals_history['wordlwide']
principals_history['worldwide_adj'] = principals_history['worldwide_adj'].apply(lambda x: x.replace(",",""))
principals_history['worldwide_adj'] = principals_history['worldwide_adj'].apply(lambda x: x if "error" in x else x[1:])
principals_history['worldwide_adj'] = principals_history['worldwide_adj'].apply(lambda x: 0 if "error" in x else x)

def convert(val):
    try:
        return(int(val))
    except:
        return(0)


principals_history['worldwide_adj'] = principals_history['worldwide_adj'].apply(lambda x: convert(x)) 
principals_history['worldwide_adj']
# Out:
# 0          469571
# 1          563162
# 2         2000853
# 3       449326618
# 5        46922870
#           ...
# 7745            0
# 7750      9074749
# 7751     10421847
# 7754      1561698
# 7756     62856743
# Name: worldwide_adj, Length: 6003, dtype: int64

# %%
principals_history.head()
# Out:
#        tconst titleType        primaryTitle startYear runtimeMinutes  \
# 0   tt0113403     movie  A Midwinter's Tale      1995             99
# 1   tt0450972     movie      As You Like It      2006            127
# 2   tt0475331     movie     The Magic Flute      2006            135
# 3   tt0800369     movie                Thor      2011            115
# 5  tt12789558     movie             Belfast      2021             98
#
#                      genres                                 newurl mpaarating  \
# 0                    Comedy   https://www.imdb.com/title/tt0113403          R
# 1      Comedy,Drama,Romance   https://www.imdb.com/title/tt0450972         PG
# 2     Drama,Musical,Romance   https://www.imdb.com/title/tt0475331      error
# 3  Action,Adventure,Fantasy   https://www.imdb.com/title/tt0800369      PG-13
# 5   Biography,Drama,History  https://www.imdb.com/title/tt12789558      PG-13
#
#                                  rlsdt                    budget  \
# 0    February 16, 1996 (United States)                     error
# 1  September 21, 2007 (United Kingdom)                     error
# 2           December 13, 2006 (France)   $27,000,000 (estimated)
# 3          May 6, 2011 (United States)  $150,000,000 (estimated)
# 5    November 12, 2021 (United States)                     error
#
#       wordlwide  averageRating  numVotes  budget_adj  worldwide_adj
# 0      $469,571            7.2    2577.0           0         469571
# 1      $563,162            6.1    3354.0           0         563162
# 2    $2,000,853            6.5    1236.0    27000000        2000853
# 3  $449,326,618            7.0  810857.0   150000000      449326618
# 5   $46,922,870            7.3   44239.0           0       46922870

# %% [markdown]
# ## 07.07 Create ROI Calculation

# %%
principals_history['ROI'] = (principals_history.worldwide_adj - principals_history.budget_adj ) / principals_history.budget_adj

# %%
principals_history.head()
# Out:
#        tconst titleType        primaryTitle startYear runtimeMinutes  \
# 0   tt0113403     movie  A Midwinter's Tale      1995             99
# 1   tt0450972     movie      As You Like It      2006            127
# 2   tt0475331     movie     The Magic Flute      2006            135
# 3   tt0800369     movie                Thor      2011            115
# 5  tt12789558     movie             Belfast      2021             98
#
#                      genres                                 newurl mpaarating  \
# 0                    Comedy   https://www.imdb.com/title/tt0113403          R
# 1      Comedy,Drama,Romance   https://www.imdb.com/title/tt0450972         PG
# 2     Drama,Musical,Romance   https://www.imdb.com/title/tt0475331      error
# 3  Action,Adventure,Fantasy   https://www.imdb.com/title/tt0800369      PG-13
# 5   Biography,Drama,History  https://www.imdb.com/title/tt12789558      PG-13
#
#                                  rlsdt                    budget  \
# 0    February 16, 1996 (United States)                     error
# 1  September 21, 2007 (United Kingdom)                     error
# 2           December 13, 2006 (France)   $27,000,000 (estimated)
# 3          May 6, 2011 (United States)  $150,000,000 (estimated)
# 5    November 12, 2021 (United States)                     error
#
#       wordlwide  averageRating  numVotes  budget_adj  worldwide_adj       ROI
# 0      $469,571            7.2    2577.0           0         469571       inf
# 1      $563,162            6.1    3354.0           0         563162       inf
# 2    $2,000,853            6.5    1236.0    27000000        2000853 -0.925894
# 3  $449,326,618            7.0  810857.0   150000000      449326618  1.995511
# 5   $46,922,870            7.3   44239.0           0       46922870       inf

# %% [markdown]
# ## 07.08 Release Date

# %%
# Reformat Date
principals_history['rlsdt_dt'] = principals_history['rlsdt'].str.replace(r"\(.*\)","")

# Convert date format to get the date, month, and day information
principals_history['rlsdt_dt']= pd.to_datetime(principals_history['rlsdt_dt'],errors='coerce')
principals_history['rlsdt_mo']= pd.DatetimeIndex(principals_history['rlsdt_dt']).month
principals_history['rlsdt_day']= pd.DatetimeIndex(principals_history['rlsdt_dt']).day
principals_history['rlsdt_daynm']= pd.to_datetime(principals_history['rlsdt_dt']).dt.day_name()
# Out:
# C:\Users\benro\AppData\Local\Temp/ipykernel_67804/3711955963.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   principals_history['rlsdt_dt'] = principals_history['rlsdt'].str.replace(r"\(.*\)","")

# %%
principals_history.head(5)
# Out:
#        tconst titleType        primaryTitle startYear runtimeMinutes  \
# 0   tt0113403     movie  A Midwinter's Tale      1995             99
# 1   tt0450972     movie      As You Like It      2006            127
# 2   tt0475331     movie     The Magic Flute      2006            135
# 3   tt0800369     movie                Thor      2011            115
# 5  tt12789558     movie             Belfast      2021             98
#
#                      genres                                 newurl mpaarating  \
# 0                    Comedy   https://www.imdb.com/title/tt0113403          R
# 1      Comedy,Drama,Romance   https://www.imdb.com/title/tt0450972         PG
# 2     Drama,Musical,Romance   https://www.imdb.com/title/tt0475331      error
# 3  Action,Adventure,Fantasy   https://www.imdb.com/title/tt0800369      PG-13
# 5   Biography,Drama,History  https://www.imdb.com/title/tt12789558      PG-13
#
#                                  rlsdt                    budget  \
# 0    February 16, 1996 (United States)                     error
# 1  September 21, 2007 (United Kingdom)                     error
# 2           December 13, 2006 (France)   $27,000,000 (estimated)
# 3          May 6, 2011 (United States)  $150,000,000 (estimated)
# 5    November 12, 2021 (United States)                     error
#
#       wordlwide  averageRating  numVotes  budget_adj  worldwide_adj       ROI  \
# 0      $469,571            7.2    2577.0           0         469571       inf
# 1      $563,162            6.1    3354.0           0         563162       inf
# 2    $2,000,853            6.5    1236.0    27000000        2000853 -0.925894
# 3  $449,326,618            7.0  810857.0   150000000      449326618  1.995511
# 5   $46,922,870            7.3   44239.0           0       46922870       inf
#
#     rlsdt_dt  rlsdt_mo  rlsdt_day rlsdt_daynm
# 0 1996-02-16       2.0       16.0      Friday
# 1 2007-09-21       9.0       21.0      Friday
# 2 2006-12-13      12.0       13.0   Wednesday
# 3 2011-05-06       5.0        6.0      Friday
# 5 2021-11-12      11.0       12.0      Friday

# %%
principals_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6003 entries, 0 to 7756
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          6003 non-null   object
#  1   titleType       6003 non-null   object
#  2   primaryTitle    6003 non-null   object
#  3   startYear       6003 non-null   object
#  4   runtimeMinutes  6003 non-null   object
#  5   genres          6003 non-null   object
#  6   newurl          6003 non-null   object
#  7   mpaarating      6003 non-null   object
#  8   rlsdt           6003 non-null   object
#  9   budget          6003 non-null   object
#  10  wordlwide       6003 non-null   object
#  11  averageRating   6003 non-null   float64
#  12  numVotes        6003 non-null   float64
#  13  budget_adj      6003 non-null   int64
#  14  worldwide_adj   6003 non-null   int64
#  15  ROI             2721 non-null   float64
#  16  rlsdt_dt        5894 non-null   datetime64[ns]
#  17  rlsdt_mo        5894 non-null   float64
#  18  rlsdt_day       5894 non-null   float64
#  19  rlsdt_daynm     5894 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(12)
# memory usage: 984.9+ KB

# %% [markdown]
# Now that we have ROI and worldwide revenue for most films in the history, we need to summarize as best we can and get this data combined with Disney Feature Film data so that we can start building our models.    We could also get to runtime, month of release, day(date) and day of the week of release.

# %% [markdown]
# ## 07.09 Export Principal History

# %%
principals_history.to_csv('../Bens_Data/principals_history_updated.csv')
