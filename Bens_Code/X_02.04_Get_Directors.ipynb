# %%
import gzip
import pandas as pd
import numpy as np
import requests
import re
from bs4 import BeautifulSoup
import time
import random
from sklearn.feature_extraction.text import CountVectorizer

# %%
nm=gzip.open('../Other Source Data/IMDB/name.basics.tsv.gz','rb')
df_names = pd.read_csv(nm,sep='\t', low_memory=False)
df_names.head(10)


# # Index nconst	primaryName	birthYear	deathYear	primaryProfession	knownForTitles
# # 0	nm0000001	Fred Astaire	1899	1987	soundtrack,actor,miscellaneous	tt0050419,tt0031983,tt0072308,tt0053137
# # 1	nm0000002	Lauren Bacall	1924	2014	actress,soundtrack	tt0117057,tt0071877,tt0038355,tt0037382
# # 2	nm0000003	Brigitte Bardot	1934	\N	actress,soundtrack,music_department	tt0057345,tt0049189,tt0056404,tt0054452
# # 3	nm0000004	John Belushi	1949	1982	actor,soundtrack,writer	tt0072562,tt0077975,tt0078723,tt0080455
# # 4	nm0000005	Ingmar Bergman	1918	2007	writer,director,actor	tt0083922,tt0069467,tt0060827,tt0050986
# # 5	nm0000006	Ingrid Bergman	1915	1982	actress,soundtrack,producer	tt0077711,tt0038109,tt0036855,tt0034583
# # 6	nm0000007	Humphrey Bogart	1899	1957	actor,soundtrack,producer	tt0037382,tt0043265,tt0042593,tt0034583
# # 7	nm0000008	Marlon Brando	1924	2004	actor,soundtrack,director	tt0078788,tt0068646,tt0070849,tt0047296
# # 8	nm0000009	Richard Burton	1925	1984	actor,soundtrack,producer	tt0057877,tt0087803,tt0061184,tt0059749
# # 9	nm0000010	James Cagney	1899	1986	actor,soundtrack,director	tt0031867,tt0029870,tt0042041,tt0035575
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
# 5  nm0000006   Ingrid Bergman      1915      1982
# 6  nm0000007  Humphrey Bogart      1899      1957
# 7  nm0000008    Marlon Brando      1924      2004
# 8  nm0000009   Richard Burton      1925      1984
# 9  nm0000010     James Cagney      1899      1986
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
# 5          actress,soundtrack,producer
# 6            actor,soundtrack,producer
# 7            actor,soundtrack,director
# 8            actor,soundtrack,producer
# 9            actor,soundtrack,director
#
#                             knownForTitles
# 0  tt0050419,tt0031983,tt0072308,tt0053137
# 1  tt0117057,tt0071877,tt0038355,tt0037382
# 2  tt0057345,tt0049189,tt0056404,tt0054452
# 3  tt0072562,tt0077975,tt0078723,tt0080455
# 4  tt0083922,tt0069467,tt0060827,tt0050986
# 5  tt0077711,tt0038109,tt0036855,tt0034583
# 6  tt0037382,tt0043265,tt0042593,tt0034583
# 7  tt0078788,tt0068646,tt0070849,tt0047296
# 8  tt0057877,tt0087803,tt0061184,tt0059749
# 9  tt0031867,tt0029870,tt0042041,tt0035575

# %%
# aka=gzip.open('IMDB/title.akas.tsv.gz','rb')
# df_akas = pd.read_csv(aka,sep='\t', low_memory=False)
# df_akas.head(10)


# # index titleId	ordering	title	region	language	types	attributes	isOriginalTitle
# # 0	tt0000001	1	Карменсіта	UA	\N	imdbDisplay	\N	0
# # 1	tt0000001	2	Carmencita	DE	\N	\N	literal title	0
# # 2	tt0000001	3	Carmencita - spanyol tánc	HU	\N	imdbDisplay	\N	0
# # 3	tt0000001	4	Καρμενσίτα	GR	\N	imdbDisplay	\N	0
# # 4	tt0000001	5	Карменсита	RU	\N	imdbDisplay	\N	0
# # 5	tt0000001	6	Carmencita	US	\N	imdbDisplay	\N	0
# # 6	tt0000001	7	Carmencita	\N	\N	original	\N	1
# # 7	tt0000001	8	カルメンチータ	JP	ja	imdbDisplay	\N	0
# # 8	tt0000002	1	Le clown et ses chiens	\N	\N	original	\N	1
# # 9	tt0000002	2	Le clown et ses chiens	FR	\N	imdbDisplay	\N	0

# %%
# since we are not considering anything other than full-length features, this may not be relevant
# ep=gzip.open('IMDB/title.episode.tsv.gz','rb')
# df_episodes = pd.read_csv(ep,sep='\t', low_memory=False)
# df_episodes.head()

# # Index tconst	parentTconst	seasonNumber	episodeNumber
# # 0	tt0020666	tt15180956	1	2
# # 1	tt0020829	tt15180956	1	1
# # 2	tt0021166	tt15180956	1	3
# # 3	tt0021612	tt15180956	2	2
# # 4	tt0021655	tt15180956	2	5

# %%
pr=gzip.open('../Other Source Data/IMDB/title.principals.tsv.gz','rb')
df_principals = pd.read_csv(pr,sep='\t', low_memory=False)
df_principals.head()

# # Index tconst	ordering	nconst	category	job	characters
# # 0	tt0000001	1	nm1588970	self	\N	["Self"]
# # 1	tt0000001	2	nm0005690	director	\N	\N
# # 2	tt0000001	3	nm0374658	cinematographer	director of photography	\N
# # 3	tt0000002	1	nm0721526	director	\N	\N
# # 4	tt0000002	2	nm1335271	composer	\N	\N
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt0000002         1  nm0721526         director                       \N
# 4  tt0000002         2  nm1335271         composer                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %%
# rt=gzip.open('IMDB/title.ratings.tsv.gz','rb')
# df_ratings = pd.read_csv(rt,sep='\t', low_memory=False)
# df_ratings.head()
# # Index	tconst	averageRating	numVotes
# # 0	tt0000001	5.7	1868
# # 1	tt0000002	5.9	247
# # 2	tt0000003	6.5	1640
# # 3	tt0000004	5.8	159
# # 4	tt0000005	6.2	2463

# %% [markdown]
# # Get the Directors and Writers from IMDB using the tconst values

# %%
Disney_List = pd.read_csv('../Bens_Data/imdb_scrape_final.csv')

# %%
Disney_List.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439 entries, 0 to 438
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      439 non-null    int64
#  1   DFL_title       439 non-null    object
#  2   tconst          439 non-null    object
#  3   titleType       439 non-null    object
#  4   primaryTitle    439 non-null    object
#  5   originalTitle   439 non-null    object
#  6   startYear       439 non-null    int64
#  7   runtimeMinutes  439 non-null    int64
#  8   genres          439 non-null    object
#  9   lower_title     439 non-null    object
#  10  averageRating   439 non-null    float64
#  11  numVotes        439 non-null    float64
#  12  newurl          439 non-null    object
#  13  rating          439 non-null    float64
#  14  votes           439 non-null    object
#  15  year            439 non-null    int64
#  16  mpaarating      439 non-null    object
#  17  runtime         439 non-null    object
#  18  rlsdt           439 non-null    object
#  19  budget          260 non-null    object
#  20  worldwide       308 non-null    object
# dtypes: float64(3), int64(4), object(14)
# memory usage: 72.1+ KB

# %%
cr=gzip.open('../Other Source Data/IMDB/title.crew.tsv.gz','rb')
df_crews = pd.read_csv(cr,sep='\t', low_memory=False)
df_crews.tail(10)


# # index tconst	directors	writers
# # 8784762	tt9916838	nm5519375,nm5519454	nm6182221,nm1628284,nm2921377
# # 8784763	tt9916840	nm0996406	nm1482639,nm2586970
# # 8784764	tt9916842	nm5519454,nm5519375	nm6182221,nm1628284,nm2921377
# # 8784765	tt9916844	nm5519454,nm5519375	nm6182221,nm1628284,nm2921377
# # 8784766	tt9916846	nm5519375,nm5519454	nm6182221,nm1628284,nm2921377
# # 8784767	tt9916848	nm5519454,nm5519375	nm6182221,nm1628284,nm2921377
# # 8784768	tt9916850	nm5519454,nm5519375	nm6182221,nm1628284,nm2921377
# # 8784769	tt9916852	nm5519454,nm5519375	nm6182221,nm1628284,nm2921377
# # 8784770	tt9916856	nm10538645	nm6951431
# # 8784771	tt9916880	nm0996406	nm1482639,nm2586970
# Out:
#             tconst            directors                        writers
# 8784762  tt9916838  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 8784763  tt9916840            nm0996406            nm1482639,nm2586970
# 8784764  tt9916842  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8784765  tt9916844  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8784766  tt9916846  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 8784767  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8784768  tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8784769  tt9916852  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 8784770  tt9916856           nm10538645                      nm6951431
# 8784771  tt9916880            nm0996406            nm1482639,nm2586970

# %%
Disney_Crews_combined = pd.merge(Disney_List ,                 # left df
                          df_crews,                  # right df
                          how="left",                 # left join
                          left_on='tconst',            # left column
                          right_on='tconst',    # right column
                          indicator = True,           # indicates source of each row
                          #validate = "one_to_many"    # alerts us of the relationship from left to right, incase there are dups
        )

# %%
Disney_Crews_combined.head()
# Out:
#    Unnamed: 0                     DFL_title     tconst titleType  \
# 0           0                101 Dalmatians  tt0115433     movie
# 1           1                102 Dalmatians  tt0211181     movie
# 2           2  20,000 Leagues Under the Sea  tt0046672     movie
# 3           3                  A Bug's Life  tt0120623     movie
# 4           4             A Christmas Carol  tt1067106     movie
#
#                    primaryTitle                 originalTitle  startYear  \
# 0                101 Dalmatians                101 Dalmatians       1996
# 1                102 Dalmatians                102 Dalmatians       2000
# 2  20,000 Leagues Under the Sea  20,000 Leagues Under the Sea       1954
# 3                  A Bug's Life                  A Bug's Life       1998
# 4             A Christmas Carol             A Christmas Carol       2009
#
#    runtimeMinutes                      genres                  lower_title  \
# 0             103      Adventure,Comedy,Crime               101 dalmatians
# 1             100     Adventure,Comedy,Family               102 dalmatians
# 2             127      Adventure,Drama,Family  20000 leagues under the sea
# 3              95  Adventure,Animation,Comedy                  a bugs life
# 4              96  Adventure,Animation,Comedy            a christmas carol
#
#    ...  votes  year mpaarating  runtime                              rlsdt  \
# 0  ...   110K  1996          G   1h 43m  November 27, 1996 (United States)
# 1  ...    37K  2000          G   1h 40m  November 22, 2000 (United States)
# 2  ...    33K  1954          G    2h 7m      July 20, 1955 (United States)
# 3  ...   285K  1998          G   1h 35m  November 25, 1998 (United States)
# 4  ...   113K  2009         PG   1h 36m   November 6, 2009 (United States)
#
#                      budget     worldwide            directors  \
# 0   $75,000,000 (estimated)  $320,689,294            nm0378893
# 1   $85,000,000 (estimated)  $183,611,771            nm0510674
# 2    $9,000,000 (estimated)           NaN            nm0281507
# 3  $120,000,000 (estimated)  $363,258,859  nm0005124,nm0004056
# 4  $200,000,000 (estimated)  $325,286,646            nm0000709
#
#                                              writers _merge
# 0                                nm0807977,nm0000455   both
# 1  nm0807977,nm0118649,nm0716391,nm0879318,nm0925276   both
# 2                                nm0271641,nm0894523   both
# 3  nm0005124,nm0004056,nm0710020,nm0568490,nm0789624   both
# 4                                nm0002042,nm0000709   both
#
# [5 rows x 24 columns]

# %%
Disney_Crews_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 439 entries, 0 to 438
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      439 non-null    int64
#  1   DFL_title       439 non-null    object
#  2   tconst          439 non-null    object
#  3   titleType       439 non-null    object
#  4   primaryTitle    439 non-null    object
#  5   originalTitle   439 non-null    object
#  6   startYear       439 non-null    int64
#  7   runtimeMinutes  439 non-null    int64
#  8   genres          439 non-null    object
#  9   lower_title     439 non-null    object
#  10  averageRating   439 non-null    float64
#  11  numVotes        439 non-null    float64
#  12  newurl          439 non-null    object
#  13  rating          439 non-null    float64
#  14  votes           439 non-null    object
#  15  year            439 non-null    int64
#  16  mpaarating      439 non-null    object
#  17  runtime         439 non-null    object
#  18  rlsdt           439 non-null    object
#  19  budget          260 non-null    object
#  20  worldwide       308 non-null    object
#  21  directors       439 non-null    object
#  22  writers         439 non-null    object
#  23  _merge          439 non-null    category
# dtypes: category(1), float64(3), int64(4), object(16)
# memory usage: 82.9+ KB

# %%
# There are 314 unique values, but we know some of those values contain multiple directors. 
# When we use CountVectorizer to get the unique list of directors, 
# we should ens up with more than 314 unique directors

len(Disney_Crews_combined['directors'].unique())
# Out:
# 314

# %%
# For each film,
#     for each dirctor on the film
#         get the name of each director
#         get the total number of films that director worked on PRIOR to this one
#         get the budget of each film that director worked on PRIOR to this one
#         get the revenue of each film that director worked on PRIOR to this one
#         get the number of DISNEY films that director worked on PRIOR to this one
#         get the budget of each DISNEY film that director worked on PRIOR to this one
#         get the revenue of each DISNEY film that director worked on PRIOR to this one
#         get the total number of films that director DIRECTED PRIOR to this one
#         get the budget of each film that director DIRECTED PRIOR to this one
#         get the revenue of each film that director DIRECTED PRIOR to this one
#         get the number of DISNEY films that director DIRECTED PRIOR to this one
#         get the budget of each DISNEY film that director DIRECTED PRIOR to this one
#         get the revenue of each DISNEY film that director DIRECTED PRIOR to this one
#    If there is more than one director,
#        get the AVERAGE for each of the above
#        get the SUM for each of the above

# %%
# 1 Get a list of unique Disney films / directors combos (film, tconst, director name, nconst, "director") 
# 2 Get a list of unique Disney films / writers combos (film, tconst, writer name, nconst, "writer") 
# 3 Get a list of the unique Directors
# 4 Get a list of the unique Writers
# ( SOME NAMES MIGHT APPEAR ON BOTH LISTS BUT EACH NAME SHOULD ONLY APPEAR ON EACH LIST ONE TIME)
# 5 Create a list of each film that each Director directed (director name, nconst, "director",film, tconst, rls date, budget, revenue )
# 6 Create a list of each film that wach Writer wrote (writer name, nconst, "writer",film, tconst, rls date, budget, revenue )
# 7 Determine if each film is a Disney Movie or Not Disney Movie
# 8 Either average or meadian the missing budget numbers
# 9 Either average or meadian the missing revenue numbers
# 10 Calculate ROI for each list

# %% [markdown]
# #### Create a list of directors from Disney Films

# %%
cv = CountVectorizer()
cvec = cv.fit(Disney_Crews_combined['directors'])
csr = cvec.transform(Disney_Crews_combined['directors'])
disney_directors = pd.DataFrame(csr.todense(), columns=cvec.get_feature_names())
disney_directors = disney_directors.T
disney_directors.reset_index(inplace=True)
disney_directors.rename(columns={"index": "nconst"},inplace=True)
disney_directors = disney_directors[['nconst']]
disney_directors['director'] = 'director'


disney_directors = pd.merge(disney_directors ,                 # left df
                          df_names[['nconst', 'primaryName', 'birthYear']],                  # right df
                          how="left",                 # left join
                          left_on='nconst',            # left column
                          right_on='nconst',    # right column
                          indicator = True,           # indicates source of each row
                          #validate = "one_to_many"    # alerts us of the relationship from left to right, incase there are dups
        )

disney_directors['_merge'].value_counts()
# Out:
# both          349
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %%
disney_directors.drop(columns='_merge',inplace = True)
disney_directors.head()
# Out:
#       nconst  director      primaryName birthYear
# 0  nm0000110  director  Kenneth Branagh      1960
# 1  nm0000116  director    James Cameron      1954
# 2  nm0000165  director       Ron Howard      1954
# 3  nm0000186  director      David Lynch      1946
# 4  nm0000200  director      Bill Paxton      1955

# %% [markdown]
# #### Create a list of all films the Disney Directors have worked on, Disney or Otherwise

# %%
df_directors = df_principals[df_principals['category']=='director']

# %%
disney_directors_history = pd.merge(disney_directors ,                 # left df
                          df_directors[['tconst', 'nconst', 'category']],                  # right df
                          how="left",                 # left join
                          left_on='nconst',            # left column
                          right_on='nconst',    # right column
                          #indicator = True,           # indicates source of each row
                          #validate = "one_to_many"    # alerts us of the relationship from left to right, incase there are dups
        )

# %%
disney_directors_history.head()
# Out:
#       nconst  director      primaryName birthYear     tconst  category
# 0  nm0000110  director  Kenneth Branagh      1960  tt0105506  director
# 1  nm0000110  director  Kenneth Branagh      1960  tt0113403  director
# 2  nm0000110  director  Kenneth Branagh      1960  tt0357865  director
# 3  nm0000110  director  Kenneth Branagh      1960  tt0450972  director
# 4  nm0000110  director  Kenneth Branagh      1960  tt0475331  director

# %% [markdown]
# #### Create a list of writers from Disney Films

# %%
cvec = cv.fit(Disney_Crews_combined['writers'])
csr = cvec.transform(Disney_Crews_combined['writers'])
disney_writers = pd.DataFrame(csr.todense(), columns=cvec.get_feature_names())
disney_writers = disney_writers.T
disney_writers.reset_index(inplace=True)
disney_writers.rename(columns={"index": "nconst"},inplace=True)
disney_writers = disney_writers[['nconst']]
disney_writers['writer'] = 'writer'

disney_writers = pd.merge(disney_writers ,                 # left df
                          df_names[['nconst', 'primaryName', 'birthYear']],                  # right df
                          how="left",                 # left join
                          left_on='nconst',            # left column
                          right_on='nconst',    # right column
                          indicator = True,           # indicates source of each row
                          #validate = "one_to_many"    # alerts us of the relationship from left to right, incase there are dups
        )
disney_writers['_merge'].value_counts()
# Out:
# both          1093
# left_only        0
# right_only       0
# Name: _merge, dtype: int64

# %%
disney_writers.drop(columns='_merge',inplace = True)
disney_writers.head()
# Out:
#       nconst  writer    primaryName birthYear
# 0  nm0000184  writer   George Lucas      1944
# 1  nm0000318  writer     Tim Burton      1958
# 2  nm0000370  writer    Walt Disney      1901
# 3  nm0000436  writer  Curtis Hanson      1945
# 4  nm0000455  writer    John Hughes      1950

# %% [markdown]
# #### Create a list of all films the Disney Writers have worked on, Disney or Otherwise

# %%
df_writers = df_principals[df_principals['category']=='writer']

# %%
disney_writers_history = pd.merge(disney_writers ,                 # left df
                          df_writers[['tconst', 'nconst', 'category']],                  # right df
                          how="left",                 # left join
                          left_on='nconst',            # left column
                          right_on='nconst',    # right column
                          #indicator = True,           # indicates source of each row
                          #validate = "one_to_many"    # alerts us of the relationship from left to right, incase there are dups
        )

# %%
disney_writers_history.head()
# Out:
#       nconst  writer   primaryName birthYear     tconst category
# 0  nm0000184  writer  George Lucas      1944  tt0079576   writer
# 1  nm0000184  writer  George Lucas      1944  tt0080684   writer
# 2  nm0000184  writer  George Lucas      1944  tt0082971   writer
# 3  nm0000184  writer  George Lucas      1944  tt0086190   writer
# 4  nm0000184  writer  George Lucas      1944  tt0087225   writer

# %% [markdown]
# ## For our Directors History and Writers History, we need to get the realse date for each film they worked on, as well as the budget and revenue.
# ### The title and release date can come from data already provided by IMDB.
# ### The budget and revenue numbers will need to be scraped from IMDB.

# %%
disney_directors_history.head(3)
# Out:
#       nconst  director      primaryName birthYear     tconst  category
# 0  nm0000110  director  Kenneth Branagh      1960  tt0105506  director
# 1  nm0000110  director  Kenneth Branagh      1960  tt0113403  director
# 2  nm0000110  director  Kenneth Branagh      1960  tt0357865  director

# %%
disney_writers_history.head(3)
# Out:
#       nconst  writer   primaryName birthYear     tconst category
# 0  nm0000184  writer  George Lucas      1944  tt0079576   writer
# 1  nm0000184  writer  George Lucas      1944  tt0080684   writer
# 2  nm0000184  writer  George Lucas      1944  tt0082971   writer

# %% [markdown]
# ### To make things a little easier to manage, we're going to get a list of unique tconst values from Disney Directors and Disney Writers, use the combined list to gather all of the unformation, then marry the film information to the Director and Writer.

# %%
len(disney_directors_history['tconst'].unique()), len(disney_writers_history['tconst'].unique())
# Out:
# (18366, 51988)

# %%
comb = np.concatenate((disney_directors_history['tconst'].unique(), disney_writers_history['tconst'].unique()), axis=0)

# %%
df_comb = pd.DataFrame(comb, columns = ['tconst'])
df_comb = df_comb['tconst'].unique()
df_comb = pd.DataFrame(df_comb, columns = ['tconst'])
df_comb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67296 entries, 0 to 67295
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tconst  67295 non-null  object
# dtypes: object(1)
# memory usage: 525.9+ KB

# %%
bs=gzip.open('../Other Source Data/IMDB/title.basics.tsv.gz','rb')
df_basics = pd.read_csv(bs,sep='\t', low_memory=False)

# %%
df_basics.shape
# Out:
# (8784772, 9)

# %%
df_basics_movies= df_basics[df_basics['titleType']=='movie']
df_basics_movies.shape
# Out:
# (605156, 9)

# %%
df_basics_movies.head()
# Out:
#         tconst titleType                 primaryTitle  \
# 498  tt0000502     movie                     Bohemios
# 570  tt0000574     movie  The Story of the Kelly Gang
# 587  tt0000591     movie             The Prodigal Son
# 610  tt0000615     movie           Robbery Under Arms
# 625  tt0000630     movie                       Hamlet
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 498                     Bohemios       0      1905      \N            100
# 570  The Story of the Kelly Gang       0      1906      \N             70
# 587            L'enfant prodigue       0      1907      \N             90
# 610           Robbery Under Arms       0      1907      \N             \N
# 625                       Amleto       0      1908      \N             \N
#
#                          genres
# 498                          \N
# 570  Action,Adventure,Biography
# 587                       Drama
# 610                       Drama
# 625                       Drama

# %%
directors_writers_combined_history = pd.merge(df_comb ,                 # left df
                          df_basics_movies[['tconst', 'titleType', 'primaryTitle', 'startYear', 'runtimeMinutes', 'genres']],                  # right df
                          how="left",                 # left join
                          left_on='tconst',            # left column
                          right_on='tconst',    # right column
                          #indicator = True,           # indicates source of each row
                          #validate = "one_to_many"    # alerts us of the relationship from left to right, incase there are dups
        )
directors_writers_combined_history.shape
# Out:
# (67296, 6)

# %%
directors_writers_combined_history = directors_writers_combined_history[directors_writers_combined_history['titleType'] == 'movie']
directors_writers_combined_history.shape
# Out:
# (7837, 6)

# %% [markdown]
# # Now it's time to scrape the data we need from IMDB

# %%
# Target web page:
url = "https://www.imdb.com/title/"
# Establishing the connection to the web page:
response = requests.get(url)
# response.text[:50]
soup = BeautifulSoup(response.text, 'lxml')

imdb_errors = pd.DataFrame(columns=['tconst'])
imdb_soup = pd.DataFrame(columns=['tconst','newurl','soup_text'])
imdb_scrape = pd.DataFrame(columns=['tconst','newurl','mpaarating','rlsdt','budget','wordlwide' ])

# %%
counter = 1
for const in directors_writers_combined_history['tconst']:
 
        t= random.uniform(.4, 1.1)
        time.sleep(t)
        newurl = url + const
        response = requests.get(newurl)
        soup = BeautifulSoup(response.text, 'lxml')

        try:
            print(counter)
            counter += 1
            print(newurl)
            
            try:
                metaul = soup.find_all('ul', {'data-testid' : 'hero-title-block__metadata'})
                mpaarating = metaul[0].find_all('li')[1].find_all('span')[0].get_text()
                print(mpaarating) 
            except:
                print('mpaarating error')
                mpaarating='error'
                imdb_errors.loc[len(imdb_errors.index)] = [const]
                imdb__errors_soup.loc[len(imdb_soup.index)] = [const, newurl, soup]
            
            try:
                rlsdt = soup.find_all('li', {'data-testid' : 'title-details-releasedate'})[0].find_all('a')[1].get_text()
                print(rlsdt) 
            except:
                print('rlsdt error')
                rlsdt='error'
                imdb_errors.loc[len(imdb_errors.index)] = [const]
                imdb__errors_soup.loc[len(imdb_soup.index)] = [const, newurl, soup]
            
            try:
                budget = soup.find_all('li', {'data-testid' : 'title-boxoffice-budget'})[0].find_all('li')[0].get_text()
                print(budget) 
            except:
                print('budget error')
                budget='error'
                imdb_errors.loc[len(imdb_errors.index)] = [const]
                imdb__errors_soup.loc[len(imdb_soup.index)] = [const, newurl, soup]
            
            try:
                worldwide = soup.find_all('li', {'data-testid' : 'title-boxoffice-cumulativeworldwidegross'})[0].find_all('li')[0].get_text()
                print(worldwide) 
            except:
                print('worldwide error')
                worldwide='error'
                imdb_errors.loc[len(imdb_errors.index)] = [const]
                imdb__errors_soup.loc[len(imdb_soup.index)] = [const, newurl, soup]
                
            
            
            imdb_scrape.loc[len(imdb_scrape.index)] = [const, newurl, mpaarating ,rlsdt ,budget ,worldwide]
            imdb_soup.loc[len(imdb_soup.index)] = [const, newurl, soup]

        except:
            print(counter)
            counter += 1
            
            print(f"ERROR ON: {const}")
            print(newurl)
# Out:
# 1
# https://www.imdb.com/title/tt0113403
# R
# February 16, 1996 (United States)
# budget error
# $469,571
# C:\Users\benro\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# 2
# https://www.imdb.com/title/tt0450972
# PG
# September 21, 2007 (United Kingdom)
# budget error
# $563,162
# 3
# https://www.imdb.com/title/tt0475331
# mpaarating error
# December 13, 2006 (France)
# $27,000,000 (estimated)
# $2,000,853
# 4
# https://www.imdb.com/title/tt0800369
# PG-13
# May 6, 2011 (United States)
# $150,000,000 (estimated)
# $449,326,618
# 5
# https://www.imdb.com/title/tt11229040
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 6
# https://www.imdb.com/title/tt12789558
# PG-13
# November 12, 2021 (United States)
# budget error
# $46,922,870
# 7
# https://www.imdb.com/title/tt1661199
# PG
# March 13, 2015 (United States)
# $95,000,000 (estimated)
# $542,358,331
# 8
# https://www.imdb.com/title/tt3089630
# PG
# June 12, 2020 (United States)
# budget error
# worldwide error
# 9
# https://www.imdb.com/title/tt5226844
# mpaarating error
# December 4, 2019 (United States)
# budget error
# $141,143
# 10
# https://www.imdb.com/title/tt5943392
# mpaarating error
# November 18, 2016 (Japan)
# budget error
# $1,191,021
# 11
# https://www.imdb.com/title/tt0082910
# R
# November 5, 1982 (United States)
# $145,786 (estimated)
# worldwide error
# 12
# https://www.imdb.com/title/tt0088247
# R
# October 26, 1984 (United States)
# $6,400,000 (estimated)
# $78,371,200
# 13
# https://www.imdb.com/title/tt0090605
# R
# July 18, 1986 (United States)
# $18,500,000 (estimated)
# $131,060,248
# 14
# https://www.imdb.com/title/tt0096754
# PG-13
# August 9, 1989 (United States)
# $70,000,000 (estimated)
# $90,000,098
# 15
# https://www.imdb.com/title/tt0103064
# R
# July 3, 1991 (United States)
# $102,000,000 (estimated)
# $520,881,154
# 16
# https://www.imdb.com/title/tt0111503
# R
# July 15, 1994 (United States)
# $115,000,000 (estimated)
# $378,882,411
# 17
# https://www.imdb.com/title/tt0120338
# PG-13
# December 19, 1997 (United States)
# $200,000,000 (estimated)
# $2,201,647,264
# 18
# https://www.imdb.com/title/tt0297144
# G
# May 23, 2003 (United States)
# $13,000,000 (estimated)
# $27,570,076
# 19
# https://www.imdb.com/title/tt0499549
# PG-13
# December 18, 2009 (United States)
# $237,000,000 (estimated)
# $2,847,379,794
# 20
# https://www.imdb.com/title/tt1582272
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 21
# https://www.imdb.com/title/tt1630029
# mpaarating error
# December 16, 2022 (United States)
# budget error
# worldwide error
# 22
# https://www.imdb.com/title/tt1757678
# mpaarating error
# December 20, 2024 (United States)
# budget error
# worldwide error
# 23
# https://www.imdb.com/title/tt2475426
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 24
# https://www.imdb.com/title/tt3095356
# mpaarating error
# December 18, 2026 (United States)
# budget error
# worldwide error
# 25
# https://www.imdb.com/title/tt5637536
# mpaarating error
# December 22, 2028 (United States)
# budget error
# worldwide error
# 26
# https://www.imdb.com/title/tt0084412
# R
# July 30, 1982 (United States)
# $8,100,000 (estimated)
# $21,095,638
# 27
# https://www.imdb.com/title/tt0088161
# PG
# March 9, 1984 (United States)
# $11,000,000 (estimated)
# $69,821,334
# 28
# https://www.imdb.com/title/tt0088933
# PG-13
# June 21, 1985 (United States)
# $17,500,000 (estimated)
# $85,313,124
# 29
# https://www.imdb.com/title/tt0091159
# PG-13
# March 14, 1986 (United States)
# $18,000,000 (estimated)
# $36,611,610
# 30
# https://www.imdb.com/title/tt0096446
# PG
# May 20, 1988 (United States)
# $35,000,000 (estimated)
# $57,269,863
# 31
# https://www.imdb.com/title/tt0098067
# PG-13
# August 2, 1989 (United States)
# $20,000,000 (estimated)
# $126,297,830
# 32
# https://www.imdb.com/title/tt0101393
# R
# May 24, 1991 (United States)
# $40,000,000 (estimated)
# $152,368,585
# 33
# https://www.imdb.com/title/tt0104231
# PG-13
# May 22, 1992 (United States)
# $60,000,000 (estimated)
# $137,783,840
# 34
# https://www.imdb.com/title/tt0110771
# R
# March 25, 1994 (United States)
# $6,000,000 (estimated)
# $48,424,341
# 35
# https://www.imdb.com/title/tt0112384
# PG
# June 30, 1995 (United States)
# $52,000,000 (estimated)
# $355,237,933
# 36
# https://www.imdb.com/title/tt0117438
# R
# November 8, 1996 (United States)
# $80,000,000 (estimated)
# $309,492,681
# 37
# https://www.imdb.com/title/tt0131369
# PG-13
# March 26, 1999 (United States)
# $80,000,000 (estimated)
# $35,242,897
# 38
# https://www.imdb.com/title/tt0170016
# PG
# November 17, 2000 (United States)
# $123,000,000 (estimated)
# $345,823,032
# 39
# https://www.imdb.com/title/tt0268978
# PG-13
# January 4, 2002 (United States)
# $58,000,000 (estimated)
# $316,791,257
# 40
# https://www.imdb.com/title/tt0338188
# R
# November 26, 2003 (United States)
# $60,000,000 (estimated)
# $38,364,277
# 41
# https://www.imdb.com/title/tt0352248
# PG-13
# June 3, 2005 (United States)
# $88,000,000 (estimated)
# $108,539,911
# 42
# https://www.imdb.com/title/tt0382625
# PG-13
# May 19, 2006 (United States)
# $125,000,000 (estimated)
# $760,006,945
# 43
# https://www.imdb.com/title/tt0808151
# PG-13
# May 15, 2009 (United States)
# $150,000,000 (estimated)
# $485,930,816
# 44
# https://www.imdb.com/title/tt0870111
# R
# January 23, 2009 (United States)
# $25,000,000 (estimated)
# $27,426,335
# 45
# https://www.imdb.com/title/tt10551162
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 46
# https://www.imdb.com/title/tt11708502
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 47
# https://www.imdb.com/title/tt12156974
# mpaarating error
# March 19, 2022 (United States)
# budget error
# worldwide error
# 48
# https://www.imdb.com/title/tt12262116
# PG-13
# November 18, 2022 (United States)
# budget error
# worldwide error
# 49
# https://www.imdb.com/title/tt1390411
# PG-13
# December 11, 2015 (United States)
# $100,000,000 (estimated)
# $93,920,758
# 50
# https://www.imdb.com/title/tt1578275
# PG-13
# January 14, 2011 (United States)
# $70,000,000 (estimated)
# $69,721,966
# 51
# https://www.imdb.com/title/tt1730763
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 52
# https://www.imdb.com/title/tt1979320
# R
# September 27, 2013 (United States)
# $38,000,000 (estimated)
# $96,983,009
# 53
# https://www.imdb.com/title/tt2366572
# mpaarating error
# July 11, 2014 (United States)
# budget error
# worldwide error
# 54
# https://www.imdb.com/title/tt2531318
# Not Rated
# September 15, 2016 (United States)
# budget error
# $12,283,966
# 55
# https://www.imdb.com/title/tt3062096
# PG-13
# October 28, 2016 (United States)
# $75,000,000 (estimated)
# $220,021,259
# 56
# https://www.imdb.com/title/tt3778644
# PG-13
# May 25, 2018 (United States)
# $275,000,000 (estimated)
# $392,924,807
# 57
# https://www.imdb.com/title/tt5795154
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 58
# https://www.imdb.com/title/tt6173448
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 59
# https://www.imdb.com/title/tt6772802
# R
# November 24, 2020 (United States)
# $45,000,000 (estimated)
# worldwide error
# 60
# https://www.imdb.com/title/tt6964076
# PG-13
# December 30, 2019 (United States)
# budget error
# $8,083,942
# 61
# https://www.imdb.com/title/tt8629752
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 62
# https://www.imdb.com/title/tt9735350
# PG-13
# September 8, 2020 (United States)
# budget error
# $3,414
# 63
# https://www.imdb.com/title/tt0074486
# Not Rated
# February 3, 1978 (United States)
# $10,000 (estimated)
# $23,557
# 64
# https://www.imdb.com/title/tt0080678
# PG
# October 10, 1980 (United States)
# $5,000,000 (estimated)
# $26,023,860
# 65
# https://www.imdb.com/title/tt0087182
# PG-13
# December 14, 1984 (United States)
# $40,000,000 (estimated)
# $30,979,816
# 66
# https://www.imdb.com/title/tt0090756
# R
# January 1, 1986 (Turkey)
# $6,000,000 (estimated)
# $8,618,766
# 67
# https://www.imdb.com/title/tt0100935
# R
# August 17, 1990 (United States)
# $9,500,000 (estimated)
# $14,561,425
# 68
# https://www.imdb.com/title/tt0105665
# R
# August 28, 1992 (United States)
# $10,000,000 (estimated)
# $4,184,990
# 69
# https://www.imdb.com/title/tt0116922
# R
# January 15, 1997 (France)
# $15,000,000 (estimated)
# $3,703,548
# 70
# https://www.imdb.com/title/tt0166896
# G
# November 3, 1999 (France)
# $10,000,000 (estimated)
# $6,416,569
# 71
# https://www.imdb.com/title/tt0166924
# R
# October 19, 2001 (United States)
# $15,000,000 (estimated)
# $20,271,129
# 72
# https://www.imdb.com/title/tt0460829
# R
# February 7, 2007 (France)
# budget error
# $4,046,144
# 73
# https://www.imdb.com/title/tt5334704
# mpaarating error
# August 1, 2014 (Brazil)
# budget error
# worldwide error
# 74
# https://www.imdb.com/title/tt0388980
# PG
# September 30, 2005 (United States)
# $26,000,000 (estimated)
# $15,431,177
# 75
# https://www.imdb.com/title/tt0059181
# mpaarating error
# March 24, 1964 (United States)
# $400 (estimated)
# worldwide error
# 76
# https://www.imdb.com/title/tt0072226
# PG
# May 29, 1974 (Sweden)
# $3,000,000 (estimated)
# $7,504,841
# 77
# https://www.imdb.com/title/tt0073195
# PG
# June 20, 1975 (United States)
# $7,000,000 (estimated)
# $471,411,300
# 78
# https://www.imdb.com/title/tt0075860
# PG
# December 14, 1977 (United States)
# $20,000,000 (estimated)
# $306,889,114
# 79
# https://www.imdb.com/title/tt0078723
# PG
# December 14, 1979 (United States)
# $35,000,000 (estimated)
# $92,455,742
# 80
# https://www.imdb.com/title/tt0082971
# PG
# June 12, 1981 (United States)
# $18,000,000 (estimated)
# $389,925,971
# 81
# https://www.imdb.com/title/tt0083866
# PG
# June 11, 1982 (United States)
# $10,500,000 (estimated)
# $792,910,554
# 82
# https://www.imdb.com/title/tt0086491
# PG
# June 24, 1983 (United States)
# $10,000,000 (estimated)
# $29,450,919
# 83
# https://www.imdb.com/title/tt0087469
# PG
# May 23, 1984 (United States)
# $28,000,000 (estimated)
# $333,107,271
# 84
# https://www.imdb.com/title/tt0088939
# PG-13
# February 7, 1986 (United States)
# $15,000,000 (estimated)
# $98,467,863
# 85
# https://www.imdb.com/title/tt0092965
# PG
# December 25, 1987 (United States)
# $35,000,000 (estimated)
# $22,238,696
# 86
# https://www.imdb.com/title/tt0096794
# PG
# December 22, 1989 (United States)
# $31,000,000 (estimated)
# $74,134,790
# 87
# https://www.imdb.com/title/tt0097576
# PG-13
# May 24, 1989 (United States)
# $48,000,000 (estimated)
# $474,171,806
# 88
# https://www.imdb.com/title/tt0102057
# PG
# December 11, 1991 (United States)
# $70,000,000 (estimated)
# $300,854,823
# 89
# https://www.imdb.com/title/tt0107290
# PG-13
# June 11, 1993 (United States)
# $63,000,000 (estimated)
# $1,099,428,303
# 90
# https://www.imdb.com/title/tt0108052
# R
# February 4, 1994 (United States)
# $22,000,000 (estimated)
# $322,161,245
# 91
# https://www.imdb.com/title/tt0118607
# R
# December 25, 1997 (United States)
# $36,000,000 (estimated)
# $44,229,441
# 92
# https://www.imdb.com/title/tt0119567
# PG-13
# May 23, 1997 (United States)
# $73,000,000 (estimated)
# $618,638,999
# 93
# https://www.imdb.com/title/tt0120815
# R
# July 24, 1998 (United States)
# $70,000,000 (estimated)
# $482,349,603
# 94
# https://www.imdb.com/title/tt0181689
# PG-13
# June 21, 2002 (United States)
# $102,000,000 (estimated)
# $358,372,926
# 95
# https://www.imdb.com/title/tt0212720
# PG-13
# June 29, 2001 (United States)
# $100,000,000 (estimated)
# $235,926,552
# 96
# https://www.imdb.com/title/tt0264464
# PG-13
# December 25, 2002 (United States)
# $52,000,000 (estimated)
# $352,114,312
# 97
# https://www.imdb.com/title/tt0362227
# PG-13
# June 18, 2004 (United States)
# $60,000,000 (estimated)
# $219,100,084
# 98
# https://www.imdb.com/title/tt0367882
# PG-13
# May 22, 2008 (United States)
# $185,000,000 (estimated)
# $790,653,942
# 99
# https://www.imdb.com/title/tt0407304
# PG-13
# June 29, 2005 (United States)
# $132,000,000 (estimated)
# $603,873,119
# 100
# https://www.imdb.com/title/tt0408306
# R
# January 6, 2006 (United States)
# $70,000,000 (estimated)
# $130,982,129
# 101
# https://www.imdb.com/title/tt0443272
# PG-13
# November 16, 2012 (United States)
# $65,000,000 (estimated)
# $275,293,450
# 102
# https://www.imdb.com/title/tt0983193
# PG
# December 21, 2011 (United States)
# $135,000,000 (estimated)
# $373,993,951
# 103
# https://www.imdb.com/title/tt14208870
# mpaarating error
# November 23, 2022 (United States)
# budget error
# worldwide error
# 104
# https://www.imdb.com/title/tt1568911
# PG-13
# December 25, 2011 (United States)
# $66,000,000 (estimated)
# $177,584,879
# 105
# https://www.imdb.com/title/tt1594575
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 106
# https://www.imdb.com/title/tt1677720
# PG-13
# March 29, 2018 (United States)
# $175,000,000 (estimated)
# $582,918,849
# 107
# https://www.imdb.com/title/tt18334932
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 108
# https://www.imdb.com/title/tt3581652
# PG-13
# December 10, 2021 (United States)
# $100,000,000 (estimated)
# $75,742,975
# 109
# https://www.imdb.com/title/tt3682448
# PG-13
# October 16, 2015 (United States)
# $40,000,000 (estimated)
# $165,478,348
# 110
# https://www.imdb.com/title/tt3691740
# PG
# July 1, 2016 (United States)
# $140,000,000 (estimated)
# $195,243,411
# 111
# https://www.imdb.com/title/tt6294822
# PG-13
# January 12, 2018 (United States)
# $50,000,000 (estimated)
# $180,419,276
# 112
# https://www.imdb.com/title/tt7763324
# mpaarating error
# July 10, 1986 (Spain)
# budget error
# worldwide error
# 113
# https://www.imdb.com/title/tt8295436
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 114
# https://www.imdb.com/title/tt8430788
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 115
# https://www.imdb.com/title/tt0089791
# PG
# August 9, 1985 (United States)
# $6,000,000 (estimated)
# $41,047,344
# 116
# https://www.imdb.com/title/tt0094721
# PG
# March 30, 1988 (United States)
# $15,000,000 (estimated)
# $74,714,298
# 117
# https://www.imdb.com/title/tt0096895
# PG-13
# June 23, 1989 (United States)
# $35,000,000 (estimated)
# $411,569,241
# 118
# https://www.imdb.com/title/tt0099487
# PG-13
# December 14, 1990 (United States)
# $20,000,000 (estimated)
# $86,024,005
# 119
# https://www.imdb.com/title/tt0103776
# PG-13
# June 19, 1992 (United States)
# $80,000,000 (estimated)
# $266,915,287
# 120
# https://www.imdb.com/title/tt0109707
# R
# October 7, 1994 (United States)
# $18,000,000 (estimated)
# $5,887,725
# 121
# https://www.imdb.com/title/tt0116996
# PG-13
# December 13, 1996 (United States)
# $70,000,000 (estimated)
# $101,381,197
# 122
# https://www.imdb.com/title/tt0121164
# PG
# September 23, 2005 (United States)
# $40,000,000 (estimated)
# $118,133,252
# 123
# https://www.imdb.com/title/tt0133152
# PG-13
# July 27, 2001 (United States)
# $100,000,000 (estimated)
# $362,211,740
# 124
# https://www.imdb.com/title/tt0162661
# R
# November 19, 1999 (United States)
# $100,000,000 (estimated)
# $206,071,502
# 125
# https://www.imdb.com/title/tt0319061
# PG-13
# January 9, 2004 (United States)
# $70,000,000 (estimated)
# $123,218,424
# 126
# https://www.imdb.com/title/tt0367594
# PG
# July 15, 2005 (United States)
# $150,000,000 (estimated)
# $474,968,763
# 127
# https://www.imdb.com/title/tt0408236
# R
# December 21, 2007 (United States)
# $50,000,000 (estimated)
# $153,383,627
# 128
# https://www.imdb.com/title/tt1014759
# PG
# March 5, 2010 (United States)
# $200,000,000 (estimated)
# $1,025,468,216
# 129
# https://www.imdb.com/title/tt1077368
# PG-13
# May 11, 2012 (United States)
# $150,000,000 (estimated)
# $245,527,149
# 130
# https://www.imdb.com/title/tt1126590
# PG-13
# December 25, 2014 (United States)
# $10,000,000 (estimated)
# $29,253,166
# 131
# https://www.imdb.com/title/tt1142977
# PG
# October 5, 2012 (United States)
# $39,000,000 (estimated)
# $81,493,846
# 132
# https://www.imdb.com/title/tt1935859
# PG-13
# September 30, 2016 (United States)
# $110,000,000 (estimated)
# $296,482,446
# 133
# https://www.imdb.com/title/tt2049403
# mpaarating error
# June 2025 (United States)
# budget error
# worldwide error
# 134
# https://www.imdb.com/title/tt3861390
# PG
# March 29, 2019 (United States)
# $170,000,000 (estimated)
# $353,284,621
# 135
# https://www.imdb.com/title/tt0052920
# R
# January 22, 1960 (United States)
# $24,000 (estimated)
# worldwide error
# 136
# https://www.imdb.com/title/tt0054852
# mpaarating error
# July 14, 1961 (United States)
# $4,000 (estimated)
# worldwide error
# 137
# https://www.imdb.com/title/tt0054859
# mpaarating error
# May 5, 1961 (United States)
# budget error
# worldwide error
# 138
# https://www.imdb.com/title/tt0056692
# R
# May 9, 1962 (United States)
# $26,000 (estimated)
# worldwide error
# 139
# https://www.imdb.com/title/tt0057047
# Not Rated
# March 28, 1963 (United States)
# budget error
# worldwide error
# 140
# https://www.imdb.com/title/tt0057133
# mpaarating error
# July 1, 1966 (Finland)
# $5,000 (estimated)
# worldwide error
# 141
# https://www.imdb.com/title/tt0058088
# GP
# March 10, 1965 (United States)
# budget error
# worldwide error
# 142
# https://www.imdb.com/title/tt0058301
# Unrated
# October 1964 (Japan)
# $60,000 (estimated)
# worldwide error
# 143
# https://www.imdb.com/title/tt0059170
# Not Rated
# August 6, 1965 (United States)
# $45,000 (estimated)
# worldwide error
# 144
# https://www.imdb.com/title/tt0059474
# mpaarating error
# August 12, 1965 (United States)
# $38,000 (estimated)
# worldwide error
# 145
# https://www.imdb.com/title/tt0059477
# TV-MA
# July 1, 1965 (Japan)
# $60,000 (estimated)
# worldwide error
# 146
# https://www.imdb.com/title/tt0060712
# X
# October 1, 1966 (United States)
# $12,000 (estimated)
# worldwide error
# 147
# https://www.imdb.com/title/tt0061504
# R
# July 1967 (United States)
# budget error
# worldwide error
# 148
# https://www.imdb.com/title/tt0061719
# R
# February 19, 1968 (United Kingdom)
# $55,000 (estimated)
# worldwide error
# 149
# https://www.imdb.com/title/tt0062973
# mpaarating error
# August 28, 1969 (West Germany)
# $82,000 (estimated)
# worldwide error
# 150
# https://www.imdb.com/title/tt0063787
# X
# October 22, 1968 (United States)
# $76,000 (estimated)
# worldwide error
# 151
# https://www.imdb.com/title/tt0064160
# X
# 1972 (Belgium)
# $90,000 (estimated)
# worldwide error
# 152
# https://www.imdb.com/title/tt0065466
# X
# June 17, 1970 (United States)
# $900,000 (estimated)
# worldwide error
# 153
# https://www.imdb.com/title/tt0067736
# R
# July 23, 1971 (United States)
# budget error
# worldwide error
# 154
# https://www.imdb.com/title/tt0069796
# R
# August 10, 1973 (West Germany)
# $300,000 (estimated)
# worldwide error
# 155
# https://www.imdb.com/title/tt0073768
# Unrated
# November 13, 1976 (Japan)
# $100,000 (estimated)
# worldwide error
# 156
# https://www.imdb.com/title/tt0075376
# X
# December 7, 1983 (France)
# budget error
# worldwide error
# 157
# https://www.imdb.com/title/tt0078846
# X
# April 1979 (United States)
# $239,000 (estimated)
# worldwide error
# 158
# https://www.imdb.com/title/tt10912362
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 159
# https://www.imdb.com/title/tt10912436
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 160
# https://www.imdb.com/title/tt10912442
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 161
# https://www.imdb.com/title/tt0083907
# NC-17
# April 15, 1983 (United States)
# $350,000 (estimated)
# $2,895,379
# 162
# https://www.imdb.com/title/tt0088967
# PG-13
# April 25, 1986 (United States)
# $3,000,000 (estimated)
# $5,101
# 163
# https://www.imdb.com/title/tt0092991
# R
# March 13, 1987 (United States)
# $3,600,000 (estimated)
# $5,924,421
# 164
# https://www.imdb.com/title/tt0099365
# R
# August 24, 1990 (United States)
# $14,000,000 (estimated)
# $48,878,502
# 165
# https://www.imdb.com/title/tt0106308
# R
# February 19, 1993 (United States)
# $11,000,000 (estimated)
# $11,505,128
# 166
# https://www.imdb.com/title/tt0114214
# R
# February 10, 1995 (United States)
# $32,000,000 (estimated)
# $18,636,537
# 167
# https://www.imdb.com/title/tt0120324
# R
# January 22, 1999 (United States)
# $30,000,000 (estimated)
# $16,316,273
# 168
# https://www.imdb.com/title/tt0126916
# PG-13
# September 17, 1999 (United States)
# $80,000,000 (estimated)
# $46,112,640
# 169
# https://www.imdb.com/title/tt0145487
# PG-13
# May 3, 2002 (United States)
# $139,000,000 (estimated)
# $825,025,036
# 170
# https://www.imdb.com/title/tt0219699
# R
# January 19, 2001 (United States)
# $10,000,000 (estimated)
# $44,567,606
# 171
# https://www.imdb.com/title/tt0316654
# PG-13
# June 30, 2004 (United States)
# $200,000,000 (estimated)
# $788,976,453
# 172
# https://www.imdb.com/title/tt0413300
# PG-13
# May 4, 2007 (United States)
# $258,000,000 (estimated)
# $894,983,373
# 173
# https://www.imdb.com/title/tt1127180
# PG-13
# May 29, 2009 (United States)
# $30,000,000 (estimated)
# $90,842,646
# 174
# https://www.imdb.com/title/tt1623205
# PG
# March 8, 2013 (United States)
# $215,000,000 (estimated)
# $493,311,825
# 175
# https://www.imdb.com/title/tt17497950
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 176
# https://www.imdb.com/title/tt5504930
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 177
# https://www.imdb.com/title/tt6292018
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 178
# https://www.imdb.com/title/tt8036976
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 179
# https://www.imdb.com/title/tt9419884
# PG-13
# May 6, 2022 (United States)
# budget error
# worldwide error
# 180
# https://www.imdb.com/title/tt0077714
# PG
# 1978 (United Kingdom)
# $2,700,000 (estimated)
# $1,944,682
# 181
# https://www.imdb.com/title/tt0081698
# R
# July 11, 1980 (United States)
# $8,000,000 (estimated)
# $11,715,321
# 182
# https://www.imdb.com/title/tt0088011
# PG
# March 30, 1984 (United States)
# $10,000,000 (estimated)
# $86,572,238
# 183
# https://www.imdb.com/title/tt0088763
# PG
# July 3, 1985 (United States)
# $19,000,000 (estimated)
# $383,336,762
# 184
# https://www.imdb.com/title/tt0096438
# PG
# June 22, 1988 (United States)
# $70,000,000 (estimated)
# $329,803,958
# 185
# https://www.imdb.com/title/tt0096874
# PG
# November 22, 1989 (United States)
# $40,000,000 (estimated)
# $332,500,002
# 186
# https://www.imdb.com/title/tt0099088
# PG
# May 25, 1990 (United States)
# $40,000,000 (estimated)
# $245,077,583
# 187
# https://www.imdb.com/title/tt0104070
# PG-13
# July 31, 1992 (United States)
# $55,000,000 (estimated)
# $149,022,650
# 188
# https://www.imdb.com/title/tt0109830
# PG-13
# July 6, 1994 (United States)
# $55,000,000 (estimated)
# $678,226,133
# 189
# https://www.imdb.com/title/tt0118884
# PG
# July 11, 1997 (United States)
# $90,000,000 (estimated)
# $171,120,329
# 190
# https://www.imdb.com/title/tt0161081
# PG-13
# July 21, 2000 (United States)
# $100,000,000 (estimated)
# $291,420,351
# 191
# https://www.imdb.com/title/tt0162222
# PG-13
# December 22, 2000 (United States)
# $90,000,000 (estimated)
# $429,632,142
# 192
# https://www.imdb.com/title/tt0338348
# G
# November 10, 2004 (United States)
# $165,000,000 (estimated)
# $315,249,768
# 193
# https://www.imdb.com/title/tt0442933
# PG-13
# November 16, 2007 (United States)
# $150,000,000 (estimated)
# $196,393,745
# 194
# https://www.imdb.com/title/tt0805647
# PG
# October 22, 2020 (United States)
# budget error
# $27,103,571
# 195
# https://www.imdb.com/title/tt0814214
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 196
# https://www.imdb.com/title/tt1067106
# PG
# November 6, 2009 (United States)
# $200,000,000 (estimated)
# $325,286,646
# 197
# https://www.imdb.com/title/tt18272208
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 198
# https://www.imdb.com/title/tt1907668
# R
# November 2, 2012 (United States)
# $31,000,000 (estimated)
# $161,772,375
# 199
# https://www.imdb.com/title/tt3289724
# PG-13
# December 21, 2018 (United States)
# $39,000,000 (estimated)
# $13,061,491
# 200
# https://www.imdb.com/title/tt3488710
# PG
# October 9, 2015 (United States)
# $35,000,000 (estimated)
# $61,181,942
# 201
# https://www.imdb.com/title/tt3640424
# R
# November 23, 2016 (United States)
# $85,000,000 (estimated)
# $119,520,023
# 202
# https://www.imdb.com/title/tt4593060
# mpaarating error
# September 2022 (United States)
# $150,000,000 (estimated)
# worldwide error
# 203
# https://www.imdb.com/title/tt5304988
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 204
# https://www.imdb.com/title/tt8917520
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 205
# https://www.imdb.com/title/tt0373469
# R
# November 18, 2005 (United States)
# $15,000,000 (estimated)
# $15,785,148
# 206
# https://www.imdb.com/title/tt1297469
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 207
# https://www.imdb.com/title/tt1300854
# PG-13
# May 3, 2013 (United States)
# $200,000,000 (estimated)
# $1,214,811,252
# 208
# https://www.imdb.com/title/tt1606752
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 209
# https://www.imdb.com/title/tt18392014
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 210
# https://www.imdb.com/title/tt2082453
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 211
# https://www.imdb.com/title/tt3799694
# R
# May 20, 2016 (United States)
# $50,000,000 (estimated)
# $62,788,218
# 212
# https://www.imdb.com/title/tt3829266
# R
# September 14, 2018 (United States)
# $88,000,000 (estimated)
# $160,542,134
# 213
# https://www.imdb.com/title/tt0092513
# PG-13
# July 3, 1987 (United States)
# $7,000,000 (estimated)
# $34,368,475
# 214
# https://www.imdb.com/title/tt0095288
# PG-13
# September 30, 1988 (United States)
# $13,000,000 (estimated)
# $5,509,417
# 215
# https://www.imdb.com/title/tt0099785
# PG
# November 16, 1990 (United States)
# $18,000,000 (estimated)
# $476,684,675
# 216
# https://www.imdb.com/title/tt0102598
# PG-13
# May 24, 1991 (United States)
# budget error
# $25,092,802
# 217
# https://www.imdb.com/title/tt0104431
# PG
# November 20, 1992 (United States)
# $28,000,000 (estimated)
# $358,994,850
# 218
# https://www.imdb.com/title/tt0107614
# PG-13
# November 24, 1993 (United States)
# $25,000,000 (estimated)
# $441,286,195
# 219
# https://www.imdb.com/title/tt0113986
# PG-13
# July 12, 1995 (United States)
# budget error
# $138,510,230
# 220
# https://www.imdb.com/title/tt0120686
# PG-13
# December 25, 1998 (United States)
# $50,000,000 (estimated)
# $159,710,793
# 221
# https://www.imdb.com/title/tt0182789
# PG
# December 17, 1999 (United States)
# $100,000,000 (estimated)
# $87,423,861
# 222
# https://www.imdb.com/title/tt0241527
# PG
# November 16, 2001 (United States)
# $125,000,000 (estimated)
# $1,017,713,119
# 223
# https://www.imdb.com/title/tt0294870
# PG-13
# November 23, 2005 (United States)
# $40,000,000 (estimated)
# $31,670,620
# 224
# https://www.imdb.com/title/tt0295297
# PG
# November 15, 2002 (United States)
# $100,000,000 (estimated)
# $879,793,867
# 225
# https://www.imdb.com/title/tt0429478
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 226
# https://www.imdb.com/title/tt0814255
# PG
# February 12, 2010 (United States)
# $95,000,000 (estimated)
# $226,497,209
# 227
# https://www.imdb.com/title/tt0976057
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 228
# https://www.imdb.com/title/tt1032815
# PG-13
# July 10, 2009 (United States)
# $18,000,000 (estimated)
# $15,821,907
# 229
# https://www.imdb.com/title/tt11057644
# PG
# November 25, 2020 (United States)
# budget error
# worldwide error
# 230
# https://www.imdb.com/title/tt1848925
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 231
# https://www.imdb.com/title/tt2120120
# PG-13
# July 24, 2015 (United States)
# $88,000,000 (estimated)
# $244,874,809
# 232
# https://www.imdb.com/title/tt2343559
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 233
# https://www.imdb.com/title/tt4590700
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 234
# https://www.imdb.com/title/tt0078324
# PG
# 1984 (Italy)
# $330,000 (estimated)
# worldwide error
# 235
# https://www.imdb.com/title/tt0082379
# R
# October 28, 1983 (United States)
# budget error
# worldwide error
# 236
# https://www.imdb.com/title/tt0088936
# R
# May 3, 1985 (United States)
# $7,000,000 (estimated)
# $20,345,361
# 237
# https://www.imdb.com/title/tt0094602
# R
# April 22, 1988 (United States)
# $7,500,000 (estimated)
# $18,869,631
# 238
# https://www.imdb.com/title/tt0098051
# R
# August 25, 1989 (United States)
# $18,000,000 (estimated)
# $10,647,219
# 239
# https://www.imdb.com/title/tt0105690
# R
# October 9, 1992 (United States)
# $35,000,000 (estimated)
# $156,563,139
# 240
# https://www.imdb.com/title/tt0106977
# PG-13
# August 6, 1993 (United States)
# $44,000,000 (estimated)
# $368,875,760
# 241
# https://www.imdb.com/title/tt0114536
# PG-13
# September 29, 1995 (United States)
# $35,000,000 (estimated)
# $3,150,170
# 242
# https://www.imdb.com/title/tt0115857
# PG-13
# August 2, 1996 (United States)
# $50,000,000 (estimated)
# $60,209,334
# 243
# https://www.imdb.com/title/tt0120787
# R
# June 5, 1998 (United States)
# $60,000,000 (estimated)
# $128,038,368
# 244
# https://www.imdb.com/title/tt0233469
# R
# February 8, 2002 (United States)
# $85,000,000 (estimated)
# $78,382,433
# 245
# https://www.imdb.com/title/tt0311289
# PG
# April 18, 2003 (United States)
# $20,000,000 (estimated)
# $71,406,573
# 246
# https://www.imdb.com/title/tt0406816
# PG-13
# September 29, 2006 (United States)
# $70,000,000 (estimated)
# $94,973,540
# 247
# https://www.imdb.com/title/tt10837702
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 248
# https://www.imdb.com/title/tt15566366
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 249
# https://www.imdb.com/title/tt15566506
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 250
# https://www.imdb.com/title/tt18264464
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 251
# https://www.imdb.com/title/tt3735542
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 252
# https://www.imdb.com/title/tt0091369
# PG
# June 27, 1986 (United States)
# $25,000,000 (estimated)
# $13,915,874
# 253
# https://www.imdb.com/title/tt0071853
# PG
# May 25, 1975 (United Kingdom)
# £229,575 (estimated)
# $1,940,906
# 254
# https://www.imdb.com/title/tt0079470
# R
# August 17, 1979 (United States)
# $4,000,000 (estimated)
# $20,745,728
# 255
# https://www.imdb.com/title/tt0093727
# R
# May 15, 1987 (United States)
# $19,897,678 (estimated)
# $1,744,164
# 256
# https://www.imdb.com/title/tt0097289
# PG-13
# September 22, 1989 (United States)
# budget error
# $1,932,642
# 257
# https://www.imdb.com/title/tt1727770
# R
# May 12, 2017 (United States)
# budget error
# $6,303,792
# 258
# https://www.imdb.com/title/tt0080402
# R
# October 31, 1980 (United States)
# budget error
# $8,415,112
# 259
# https://www.imdb.com/title/tt0082043
# Not Rated
# November 12, 1982 (New Zealand)
# budget error
# worldwide error
# 260
# https://www.imdb.com/title/tt0088987
# R
# August 9, 1985 (United States)
# budget error
# $2,174,622
# 261
# https://www.imdb.com/title/tt0092545
# PG
# October 24, 1987 (Japan)
# $5,000,000 (estimated)
# worldwide error
# 262
# https://www.imdb.com/title/tt0093103
# R
# February 11, 1987 (United States)
# budget error
# $421,201
# 263
# https://www.imdb.com/title/tt0096146
# R
# May 15, 1988 (United Kingdom)
# budget error
# worldwide error
# 264
# https://www.imdb.com/title/tt0101811
# PG
# December 25, 1992 (Sweden)
# budget error
# $13,200,170
# 265
# https://www.imdb.com/title/tt0104522
# PG
# September 17, 1993 (United States)
# budget error
# $4,790,801
# 266
# https://www.imdb.com/title/tt0109831
# R
# April 15, 1994 (United States)
# $4,400,000 (estimated)
# $245,700,832
# 267
# https://www.imdb.com/title/tt0112427
# R
# July 21, 1995 (United States)
# $4,000,000 (estimated)
# $259,724
# 268
# https://www.imdb.com/title/tt0119008
# R
# February 28, 1997 (United States)
# $35,000,000 (estimated)
# $124,909,762
# 269
# https://www.imdb.com/title/tt0120797
# R
# April 23, 1999 (United States)
# $33,000,000 (estimated)
# $8,408,835
# 270
# https://www.imdb.com/title/tt0250255
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 271
# https://www.imdb.com/title/tt0304415
# PG-13
# December 19, 2003 (United States)
# $65,000,000 (estimated)
# $141,337,989
# 272
# https://www.imdb.com/title/tt0330373
# PG-13
# November 18, 2005 (United States)
# $150,000,000 (estimated)
# $896,730,264
# 273
# https://www.imdb.com/title/tt0473075
# PG-13
# May 28, 2010 (United States)
# $200,000,000 (estimated)
# $336,365,676
# 274
# https://www.imdb.com/title/tt0484740
# R
# November 16, 2007 (United States)
# $45,000,000 (estimated)
# $31,575,877
# 275
# https://www.imdb.com/title/tt0918506
# mpaarating error
# June 5, 1964 (United Kingdom)
# budget error
# worldwide error
# 276
# https://www.imdb.com/title/tt1289403
# TV-14
# August 10, 2018 (United States)
# budget error
# $23,148,937
# 277
# https://www.imdb.com/title/tt1731706
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 278
# https://www.imdb.com/title/tt1781003
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 279
# https://www.imdb.com/title/tt1836808
# PG-13
# November 8, 2013 (United States)
# budget error
# $6,202,879
# 280
# https://www.imdb.com/title/tt0073239
# mpaarating error
# June 25, 1975 (Sweden)
# SEK 1,800,000 (estimated)
# worldwide error
# 281
# https://www.imdb.com/title/tt0075617
# G
# February 2, 1979 (United States)
# budget error
# $38
# 282
# https://www.imdb.com/title/tt0079360
# mpaarating error
# December 1, 1979 (Sweden)
# SEK 6,000,000 (estimated)
# worldwide error
# 283
# https://www.imdb.com/title/tt0083238
# mpaarating error
# September 4, 1981 (Sweden)
# budget error
# worldwide error
# 284
# https://www.imdb.com/title/tt0086488
# mpaarating error
# March 25, 1983 (Sweden)
# budget error
# worldwide error
# 285
# https://www.imdb.com/title/tt0089606
# Unrated
# May 1, 1987 (United States)
# budget error
# $8,349,284
# 286
# https://www.imdb.com/title/tt0090610
# mpaarating error
# December 6, 1986 (Sweden)
# budget error
# worldwide error
# 287
# https://www.imdb.com/title/tt0093524
# mpaarating error
# September 5, 1987 (Sweden)
# budget error
# worldwide error
# 288
# https://www.imdb.com/title/tt0102590
# R
# February 1, 1991 (United States)
# $16,000,000 (estimated)
# $14,851,083
# 289
# https://www.imdb.com/title/tt0108550
# PG-13
# March 4, 1994 (United States)
# $11,000,000 (estimated)
# $10,032,765
# 290
# https://www.imdb.com/title/tt0114496
# R
# August 4, 1995 (United States)
# budget error
# $50,865,589
# 291
# https://www.imdb.com/title/tt0120824
# R
# January 18, 2002 (United States)
# $38,000,000 (estimated)
# $24,690,441
# 292
# https://www.imdb.com/title/tt0124315
# PG-13
# January 7, 2000 (United States)
# $24,000,000 (estimated)
# $88,545,092
# 293
# https://www.imdb.com/title/tt0241303
# PG-13
# January 19, 2001 (United States)
# $25,000,000 (estimated)
# $152,699,976
# 294
# https://www.imdb.com/title/tt0350261
# PG-13
# September 16, 2005 (United States)
# $30,000,000 (estimated)
# $18,618,284
# 295
# https://www.imdb.com/title/tt0402894
# R
# January 6, 2006 (United States)
# budget error
# $37,691,644
# 296
# https://www.imdb.com/title/tt0462338
# R
# April 20, 2007 (United States)
# $25,000,000 (estimated)
# $11,772,461
# 297
# https://www.imdb.com/title/tt0477437
# mpaarating error
# 1981 (Sweden)
# budget error
# worldwide error
# 298
# https://www.imdb.com/title/tt0989757
# PG-13
# February 5, 2010 (United States)
# $25,000,000 (estimated)
# $114,984,666
# 299
# https://www.imdb.com/title/tt1028532
# G
# March 12, 2010 (United Kingdom)
# $16,000,000 (estimated)
# $46,749,646
# 300
# https://www.imdb.com/title/tt1441952
# PG-13
# April 20, 2012 (United Kingdom)
# budget error
# $34,564,651
# 301
# https://www.imdb.com/title/tt14620236
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 302
# https://www.imdb.com/title/tt1556243
# mpaarating error
# September 28, 2012 (Sweden)
# budget error
# $7,181,735
# 303
# https://www.imdb.com/title/tt1702439
# PG-13
# February 14, 2013 (United States)
# $28,000,000 (estimated)
# $97,594,140
# 304
# https://www.imdb.com/title/tt1753383
# PG
# January 27, 2017 (United States)
# $22,000,000 (estimated)
# $205,035,819
# 305
# https://www.imdb.com/title/tt2980648
# PG
# August 8, 2014 (United States)
# $22,000,000 (estimated)
# $89,514,453
# 306
# https://www.imdb.com/title/tt3529186
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 307
# https://www.imdb.com/title/tt5523010
# PG
# November 2, 2018 (United States)
# $120,000,000 (estimated)
# $173,961,069
# 308
# https://www.imdb.com/title/tt7923136
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 309
# https://www.imdb.com/title/tt0050229
# Passed
# September 2, 1957 (United States)
# budget error
# worldwide error
# 310
# https://www.imdb.com/title/tt0057312
# mpaarating error
# March 29, 1963 (United States)
# budget error
# worldwide error
# 311
# https://www.imdb.com/title/tt0057681
# Approved
# November 14, 1963 (United States)
# budget error
# worldwide error
# 312
# https://www.imdb.com/title/tt0057840
# Approved
# October 27, 1964 (United States)
# $2,700,000 (estimated)
# worldwide error
# 313
# https://www.imdb.com/title/tt0060818
# Approved
# November 10, 1966 (United States)
# $4,000,000 (estimated)
# worldwide error
# 314
# https://www.imdb.com/title/tt0060863
# Not Rated
# February 22, 1966 (United States)
# budget error
# worldwide error
# 315
# https://www.imdb.com/title/tt0062369
# Approved
# March 16, 1970 (Denmark)
# budget error
# worldwide error
# 316
# https://www.imdb.com/title/tt0062377
# Approved
# October 30, 1967 (Spain)
# $6,000,000 (estimated)
# worldwide error
# 317
# https://www.imdb.com/title/tt0064827
# G
# October 22, 1969 (France)
# budget error
# worldwide error
# 318
# https://www.imdb.com/title/tt0066011
# PG
# December 16, 1970 (United States)
# $2,200,000 (estimated)
# $106,550,690
# 319
# https://www.imdb.com/title/tt0066193
# G
# May 28, 1970 (United States)
# budget error
# worldwide error
# 320
# https://www.imdb.com/title/tt0067217
# PG-13
# May 11, 1972 (United Kingdom)
# budget error
# worldwide error
# 321
# https://www.imdb.com/title/tt0067589
# PG-13
# May 12, 1971 (United States)
# budget error
# worldwide error
# 322
# https://www.imdb.com/title/tt0068909
# PG
# September 8, 1973 (Italy)
# $12,000,000 (estimated)
# worldwide error
# 323
# https://www.imdb.com/title/tt0071370
# PG
# October 18, 1974 (United States)
# $1,700,000 (estimated)
# worldwide error
# 324
# https://www.imdb.com/title/tt0073345
# PG
# January 27, 1975 (United States)
# budget error
# worldwide error
# 325
# https://www.imdb.com/title/tt0075223
# PG
# December 3, 1976 (United States)
# $6,500,000 (estimated)
# $51,079,064
# 326
# https://www.imdb.com/title/tt0075409
# PG
# September 1976 (United Kingdom)
# budget error
# worldwide error
# 327
# https://www.imdb.com/title/tt0079336
# PG
# September 12, 1979 (France)
# $9,000,000 (estimated)
# worldwide error
# 328
# https://www.imdb.com/title/tt0079631
# PG
# June 22, 1979 (United States)
# budget error
# worldwide error
# 329
# https://www.imdb.com/title/tt0083598
# PG
# June 18, 1982 (United States)
# budget error
# $13,111,101
# 330
# https://www.imdb.com/title/tt0084293
# R
# March 5, 1982 (United States)
# budget error
# $11,897,978
# 331
# https://www.imdb.com/title/tt0086205
# PG
# October 7, 1983 (United States)
# budget error
# $6,857,733
# 332
# https://www.imdb.com/title/tt0087635
# R
# January 27, 1984 (United States)
# budget error
# $5,718,573
# 333
# https://www.imdb.com/title/tt0088242
# R
# October 5, 1984 (United States)
# $9,000,000 (estimated)
# $27,774,237
# 334
# https://www.imdb.com/title/tt0093690
# R
# January 30, 1987 (United States)
# budget error
# $52,864,741
# 335
# https://www.imdb.com/title/tt0098282
# R
# May 12, 1989 (United States)
# $18,000,000 (estimated)
# $46,908,987
# 336
# https://www.imdb.com/title/tt0103035
# R
# August 17, 1990 (United States)
# $15,000,000 (estimated)
# $20,005,435
# 337
# https://www.imdb.com/title/tt0103747
# PG
# April 17, 1992 (United States)
# budget error
# $19,930,973
# 338
# https://www.imdb.com/title/tt0107523
# R
# March 26, 1993 (United States)
# $14,000,000 (estimated)
# $2,059,832
# 339
# https://www.imdb.com/title/tt0115836
# PG
# August 23, 1996 (United States)
# $17,000,000 (estimated)
# $3,325,651
# 340
# https://www.imdb.com/title/tt0118577
# R
# May 8, 1998 (Thailand)
# $10,000,000 (estimated)
# $59,921
# 341
# https://www.imdb.com/title/tt0407038
# R
# February 10, 2006 (United States)
# $3,500,000 (estimated)
# worldwide error
# 342
# https://www.imdb.com/title/tt0040189
# Approved
# May 31, 1948 (United Kingdom)
# budget error
# worldwide error
# 343
# https://www.imdb.com/title/tt0040335
# Approved
# November 22, 1948 (United Kingdom)
# budget error
# worldwide error
# 344
# https://www.imdb.com/title/tt0040431
# Approved
# December 23, 1950 (United States)
# £100,000 (estimated)
# worldwide error
# 345
# https://www.imdb.com/title/tt0040443
# Approved
# September 15, 1947 (United Kingdom)
# £150,400 (estimated)
# worldwide error
# 346
# https://www.imdb.com/title/tt0040597
# Not Rated
# May 24, 1948 (United Kingdom)
# budget error
# worldwide error
# 347
# https://www.imdb.com/title/tt0041489
# Approved
# May 1949 (United Kingdom)
# budget error
# worldwide error
# 348
# https://www.imdb.com/title/tt0041576
# mpaarating error
# November 14, 1949 (United Kingdom)
# budget error
# worldwide error
# 349
# https://www.imdb.com/title/tt0042028
# mpaarating error
# February 1949 (United Kingdom)
# budget error
# worldwide error
# 350
# https://www.imdb.com/title/tt0042410
# mpaarating error
# November 4, 1951 (United States)
# budget error
# worldwide error
# 351
# https://www.imdb.com/title/tt0042752
# Not Rated
# December 20, 1950 (Denmark)
# budget error
# worldwide error
# 352
# https://www.imdb.com/title/tt0043658
# Not Rated
# December 31, 1951 (United States)
# budget error
# worldwide error
# 353
# https://www.imdb.com/title/tt0045005
# Not Rated
# December 4, 1952 (United States)
# budget error
# worldwide error
# 354
# https://www.imdb.com/title/tt0045197
# Approved
# June 26, 1952 (United States)
# budget error
# worldwide error
# 355
# https://www.imdb.com/title/tt0046387
# Approved
# July 23, 1953 (United States)
# budget error
# $2,500,000
# 356
# https://www.imdb.com/title/tt0047467
# mpaarating error
# June 24, 1954 (New Zealand)
# budget error
# worldwide error
# 357
# https://www.imdb.com/title/tt0047687
# Approved
# November 4, 1954 (United States)
# budget error
# worldwide error
# 358
# https://www.imdb.com/title/tt0048772
# mpaarating error
# April 16, 1956 (Denmark)
# budget error
# worldwide error
# 359
# https://www.imdb.com/title/tt0049451
# Not Rated
# September 1956 (United Kingdom)
# budget error
# worldwide error
# 360
# https://www.imdb.com/title/tt0049847
# Approved
# January 21, 1957 (United Kingdom)
# budget error
# worldwide error
# 361
# https://www.imdb.com/title/tt0050097
# mpaarating error
# September 6, 1957 (Denmark)
# budget error
# worldwide error
# 362
# https://www.imdb.com/title/tt0052773
# mpaarating error
# August 7, 1958 (United Kingdom)
# budget error
# worldwide error
# 363
# https://www.imdb.com/title/tt0053352
# Approved
# November 10, 1959 (United States)
# $2,000,000 (estimated)
# worldwide error
# 364
# https://www.imdb.com/title/tt0054357
# G
# December 21, 1960 (United States)
# $5,000,000 (estimated)
# $40,356,000
# 365
# https://www.imdb.com/title/tt0054968
# Approved
# March 14, 1962 (United States)
# budget error
# worldwide error
# 366
# https://www.imdb.com/title/tt0055593
# mpaarating error
# September 11, 1961 (Sweden)
# budget error
# worldwide error
# 367
# https://www.imdb.com/title/tt0055875
# mpaarating error
# April 1962 (United Kingdom)
# budget error
# worldwide error
# 368
# https://www.imdb.com/title/tt0055977
# Approved
# 1965 (United States)
# budget error
# worldwide error
# 369
# https://www.imdb.com/title/tt0056197
# G
# October 4, 1962 (United States)
# $10,000,000 (estimated)
# worldwide error
# 370
# https://www.imdb.com/title/tt0058947
# Not Rated
# January 19, 1966 (France)
# budget error
# worldwide error
# 371
# https://www.imdb.com/title/tt0059312
# mpaarating error
# November 29, 1963 (West Germany)
# budget error
# worldwide error
# 372
# https://www.imdb.com/title/tt0059797
# G
# June 16, 1965 (United States)
# $5,600,000 (estimated)
# worldwide error
# 373
# https://www.imdb.com/title/tt0061916
# Approved
# October 12, 1967 (West Germany)
# £1,000,000 (estimated)
# worldwide error
# 374
# https://www.imdb.com/title/tt0062731
# Not Rated
# July 12, 1968 (West Germany)
# $2,000,000 (estimated)
# worldwide error
# 375
# https://www.imdb.com/title/tt0064688
# G
# June 1969 (United Kingdom)
# $10,000,000 (estimated)
# worldwide error
# 376
# https://www.imdb.com/title/tt0069197
# PG
# March 17, 1975 (United States)
# budget error
# worldwide error
# 377
# https://www.imdb.com/title/tt0073511
# PG
# November 5, 1975 (United States)
# budget error
# worldwide error
# 378
# https://www.imdb.com/title/tt0079152
# PG
# November 8, 1979 (Argentina)
# $7,000,000 (estimated)
# worldwide error
# 379
# https://www.imdb.com/title/tt0080519
# R
# 1981 (Canada)
# budget error
# worldwide error
# 380
# https://www.imdb.com/title/tt0084504
# PG
# August 6, 1982 (United States)
# budget error
# $7,983,086
# 381
# https://www.imdb.com/title/tt0093744
# G
# July 29, 1988 (United States)
# $5,000,000 (estimated)
# $3,569,939
# 382
# https://www.imdb.com/title/tt1280009
# mpaarating error
# 2010 (United States)
# $55,000,000 (estimated)
# worldwide error
# 383
# https://www.imdb.com/title/tt0053226
# Not Rated
# January 22, 1959 (United Kingdom)
# £280,000 (estimated)
# worldwide error
# 384
# https://www.imdb.com/title/tt0055018
# Not Rated
# December 15, 1961 (United States)
# £430,000 (estimated)
# $30,103
# 385
# https://www.imdb.com/title/tt0058500
# Not Rated
# November 9, 1964 (United States)
# budget error
# worldwide error
# 386
# https://www.imdb.com/title/tt0062089
# Approved
# October 13, 1967 (United States)
# budget error
# worldwide error
# 387
# https://www.imdb.com/title/tt0071577
# PG
# March 29, 1974 (United States)
# $6,500,000 (estimated)
# $20,563,273
# 388
# https://www.imdb.com/title/tt0086336
# PG
# April 29, 1983 (United States)
# $19,000,000 (estimated)
# $8,400,000
# 389
# https://www.imdb.com/title/tt0093431
# R
# February 2, 1989 (Italy)
# budget error
# worldwide error
# 390
# https://www.imdb.com/title/tt0097523
# PG
# June 23, 1989 (United States)
# $18,000,000 (estimated)
# $222,724,172
# 391
# https://www.imdb.com/title/tt0102803
# PG
# June 21, 1991 (United States)
# $35,000,000 (estimated)
# $46,704,056
# 392
# https://www.imdb.com/title/tt0110763
# G
# November 23, 1994 (United States)
# $27,000,000 (estimated)
# $13,670,688
# 393
# https://www.imdb.com/title/tt0113497
# PG
# December 15, 1995 (United States)
# $65,000,000 (estimated)
# $262,821,940
# 394
# https://www.imdb.com/title/tt0132477
# PG
# February 19, 1999 (United States)
# $25,000,000 (estimated)
# $34,698,753
# 395
# https://www.imdb.com/title/tt0163025
# PG-13
# July 18, 2001 (United States)
# $93,000,000 (estimated)
# $368,780,809
# 396
# https://www.imdb.com/title/tt0317648
# PG-13
# March 5, 2004 (United States)
# $100,000,000 (estimated)
# $108,040,622
# 397
# https://www.imdb.com/title/tt0458339
# PG-13
# July 22, 2011 (United States)
# $140,000,000 (estimated)
# $370,569,774
# 398
# https://www.imdb.com/title/tt0780653
# R
# February 12, 2010 (United States)
# $150,000,000 (estimated)
# $139,789,765
# 399
# https://www.imdb.com/title/tt11399224
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 400
# https://www.imdb.com/title/tt1223947
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 401
# https://www.imdb.com/title/tt2226495
# Not Rated
# May 9, 2014 (United States)
# budget error
# worldwide error
# 402
# https://www.imdb.com/title/tt0079198
# mpaarating error
# March 24, 1981 (Austria)
# budget error
# worldwide error
# 403
# https://www.imdb.com/title/tt0100470
# PG
# April 26, 1991 (United States)
# budget error
# $261,718
# 404
# https://www.imdb.com/title/tt0111271
# PG
# October 28, 1994 (United States)
# $19,200,000 (estimated)
# $3,342,223
# 405
# https://www.imdb.com/title/tt0143860
# mpaarating error
# November 20, 1986 (West Germany)
# budget error
# worldwide error
# 406
# https://www.imdb.com/title/tt0186202
# PG-13
# September 3, 2002 (United States)
# budget error
# worldwide error
# 407
# https://www.imdb.com/title/tt0199000
# mpaarating error
# November 16, 2000 (Germany)
# DEM 10,400,000 (estimated)
# $39,616
# 408
# https://www.imdb.com/title/tt1677724
# mpaarating error
# rlsdt error
# £5,000,000 (estimated)
# worldwide error
# 409
# https://www.imdb.com/title/tt1853544
# mpaarating error
# April 17, 2014 (Germany)
# budget error
# $37,338
# 410
# https://www.imdb.com/title/tt1954412
# mpaarating error
# March 1, 2012 (Switzerland)
# budget error
# worldwide error
# 411
# https://www.imdb.com/title/tt2160375
# mpaarating error
# rlsdt error
# $30,000,000 (estimated)
# worldwide error
# 412
# https://www.imdb.com/title/tt4136636
# mpaarating error
# March 18, 2016 (Austria)
# budget error
# $8,565
# 413
# https://www.imdb.com/title/tt4905870
# mpaarating error
# November 30, 1972 (Switzerland)
# budget error
# worldwide error
# 414
# https://www.imdb.com/title/tt0081159
# PG
# February 8, 1980 (United States)
# budget error
# $2,900,000
# 415
# https://www.imdb.com/title/tt0120623
# G
# November 25, 1998 (United States)
# $120,000,000 (estimated)
# $363,258,859
# 416
# https://www.imdb.com/title/tt0266543
# G
# May 30, 2003 (United States)
# $94,000,000 (estimated)
# $940,352,645
# 417
# https://www.imdb.com/title/tt0401729
# PG-13
# March 9, 2012 (United States)
# $250,000,000 (estimated)
# $284,139,100
# 418
# https://www.imdb.com/title/tt0910970
# G
# June 27, 2008 (United States)
# $180,000,000 (estimated)
# $521,311,890
# 419
# https://www.imdb.com/title/tt14271954
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 420
# https://www.imdb.com/title/tt2277860
# PG
# June 17, 2016 (United States)
# $200,000,000 (estimated)
# $1,028,570,942
# 421
# https://www.imdb.com/title/tt6348388
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 422
# https://www.imdb.com/title/tt0106868
# PG
# March 12, 1993 (United States)
# budget error
# $12,890,752
# 423
# https://www.imdb.com/title/tt0120696
# R
# January 16, 1998 (United States)
# $70,000,000 (estimated)
# $19,870,567
# 424
# https://www.imdb.com/title/tt16103576
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 425
# https://www.imdb.com/title/tt2325002
# R
# June 19, 2014 (Kuwait)
# budget error
# worldwide error
# 426
# https://www.imdb.com/title/tt3037526
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 427
# https://www.imdb.com/title/tt3703988
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 428
# https://www.imdb.com/title/tt6577170
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 429
# https://www.imdb.com/title/tt8936254
# TV-PG
# January 1, 2007 (United States)
# $7,000,000 (estimated)
# worldwide error
# 430
# https://www.imdb.com/title/tt9425442
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 431
# https://www.imdb.com/title/tt0089908
# PG
# June 21, 1985 (United States)
# $25,000,000 (estimated)
# $11,137,801
# 432
# https://www.imdb.com/title/tt0104940
# G
# December 11, 1992 (United States)
# $12,000,000 (estimated)
# $32,574,382
# 433
# https://www.imdb.com/title/tt0117110
# G
# February 16, 1996 (United States)
# budget error
# $34,327,391
# 434
# https://www.imdb.com/title/tt1082598
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 435
# ...
# budget error
# worldwide error
# 4940
# https://www.imdb.com/title/tt0028486
# mpaarating error
# October 9, 1936 (United States)
# budget error
# worldwide error
# 4941
# https://www.imdb.com/title/tt0029777
# Approved
# July 9, 1937 (United States)
# budget error
# worldwide error
# 4942
# https://www.imdb.com/title/tt0030507
# Approved
# February 5, 1938 (United States)
# budget error
# worldwide error
# 4943
# https://www.imdb.com/title/tt0034920
# Passed
# February 1942 (United States)
# $236,000 (estimated)
# worldwide error
# 4944
# https://www.imdb.com/title/tt0035211
# Approved
# March 5, 1943 (United States)
# budget error
# worldwide error
# 4945
# https://www.imdb.com/title/tt0037604
# Passed
# May 25, 1945 (United States)
# $1,324,000 (estimated)
# worldwide error
# 4946
# https://www.imdb.com/title/tt0042839
# mpaarating error
# March 24, 1953 (Portugal)
# budget error
# worldwide error
# 4947
# https://www.imdb.com/title/tt0044049
# mpaarating error
# April 28, 1952 (United States)
# budget error
# worldwide error
# 4948
# https://www.imdb.com/title/tt0046000
# Passed
# July 10, 1953 (United States)
# $1,353,000 (estimated)
# worldwide error
# 4949
# https://www.imdb.com/title/tt0050126
# Approved
# March 1958 (United States)
# budget error
# worldwide error
# 4950
# https://www.imdb.com/title/tt0051817
# mpaarating error
# October 16, 1958 (Liechtenstein)
# budget error
# worldwide error
# 4951
# https://www.imdb.com/title/tt0051924
# Passed
# April 4, 1958 (United States)
# budget error
# worldwide error
# 4952
# https://www.imdb.com/title/tt0052629
# Approved
# August 1959 (United States)
# $527,000 (estimated)
# worldwide error
# 4953
# https://www.imdb.com/title/tt0054117
# Not Rated
# October 31, 1958 (France)
# budget error
# worldwide error
# 4954
# https://www.imdb.com/title/tt0069113
# PG
# December 13, 1972 (United States)
# $5,000,000 (estimated)
# $84,563,118
# 4955
# https://www.imdb.com/title/tt0077917
# G
# October 5, 1978 (Argentina)
# budget error
# worldwide error
# 4956
# https://www.imdb.com/title/tt0078856
# PG
# May 18, 1979 (United States)
# $10,000,000 (estimated)
# worldwide error
# 4957
# https://www.imdb.com/title/tt0166506
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 4958
# https://www.imdb.com/title/tt0305179
# mpaarating error
# February 3, 1980 (United States)
# budget error
# worldwide error
# 4959
# https://www.imdb.com/title/tt0409182
# PG-13
# May 12, 2006 (United States)
# $160,000,000 (estimated)
# $181,674,817
# 4960
# https://www.imdb.com/title/tt0430606
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 4961
# https://www.imdb.com/title/tt5151570
# PG
# July 15, 2022 (United States)
# budget error
# worldwide error
# 4962
# https://www.imdb.com/title/tt0039196
# Approved
# May 2, 1947 (United States)
# budget error
# worldwide error
# 4963
# https://www.imdb.com/title/tt0043957
# Approved
# November 1951 (United States)
# budget error
# worldwide error
# 4964
# https://www.imdb.com/title/tt0045919
# Approved
# September 5, 1953 (United States)
# $967,000 (estimated)
# worldwide error
# 4965
# https://www.imdb.com/title/tt0047086
# Not Rated
# July 3, 1954 (United States)
# $1,470,000 (estimated)
# $4,334
# 4966
# https://www.imdb.com/title/tt0048640
# Approved
# May 27, 1955 (United States)
# $2,515,000 (estimated)
# worldwide error
# 4967
# https://www.imdb.com/title/tt0052326
# Approved
# August 6, 1958 (United States)
# budget error
# worldwide error
# 4968
# https://www.imdb.com/title/tt0058091
# Approved
# October 16, 1964 (West Germany)
# $2,525,000 (estimated)
# worldwide error
# 4969
# https://www.imdb.com/title/tt0088758
# PG
# March 15, 1985 (United States)
# budget error
# $1,304,192
# 4970
# https://www.imdb.com/title/tt0090056
# PG
# December 6, 1985 (United States)
# $22,000,000 (estimated)
# $60,106,536
# 4971
# https://www.imdb.com/title/tt0096378
# PG
# August 5, 1988 (United States)
# $18,000,000 (estimated)
# $1,883,811
# 4972
# https://www.imdb.com/title/tt0104694
# PG
# July 1, 1992 (United States)
# $40,000,000 (estimated)
# $132,440,069
# 4973
# https://www.imdb.com/title/tt0104928
# R
# September 25, 1992 (United States)
# $43,000,000 (estimated)
# $13,351,357
# 4974
# https://www.imdb.com/title/tt0109439
# PG-13
# June 10, 1994 (United States)
# $40,000,000 (estimated)
# $43,622,150
# 4975
# https://www.imdb.com/title/tt0109936
# PG-13
# March 4, 1994 (United States)
# budget error
# $13,137,484
# 4976
# https://www.imdb.com/title/tt0113097
# PG-13
# May 19, 1995 (United States)
# budget error
# $33,177,694
# 4977
# https://www.imdb.com/title/tt0117108
# PG-13
# July 17, 1996 (United States)
# $45,000,000 (estimated)
# $21,075,014
# 4978
# https://www.imdb.com/title/tt0119109
# PG-13
# May 9, 1997 (United States)
# $85,000,000 (estimated)
# $28,598,376
# 4979
# https://www.imdb.com/title/tt0198021
# PG-13
# April 28, 2000 (United States)
# $15,000,000 (estimated)
# $40,863,718
# 4980
# https://www.imdb.com/title/tt0332047
# PG-13
# April 8, 2005 (United States)
# $30,000,000 (estimated)
# $50,605,163
# 4981
# https://www.imdb.com/title/tt0466061
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 4982
# https://www.imdb.com/title/tt1388334
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 4983
# https://www.imdb.com/title/tt0316732
# PG-13
# October 6, 2004 (United States)
# $25,000,000 (estimated)
# $71,255,003
# 4984
# https://www.imdb.com/title/tt0454987
# R
# November 17, 2006 (United States)
# budget error
# $4,630,045
# 4985
# https://www.imdb.com/title/tt0477347
# PG
# December 22, 2006 (United States)
# $110,000,000 (estimated)
# $574,481,229
# 4986
# https://www.imdb.com/title/tt1078912
# PG
# May 22, 2009 (United States)
# $150,000,000 (estimated)
# $413,106,170
# 4987
# https://www.imdb.com/title/tt1792608
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 4988
# https://www.imdb.com/title/tt1814904
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 4989
# https://www.imdb.com/title/tt1825711
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 4990
# https://www.imdb.com/title/tt1937386
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 4991
# https://www.imdb.com/title/tt2012661
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 4992
# https://www.imdb.com/title/tt2091430
# mpaarating error
# rlsdt error
# $100,000,000 (estimated)
# worldwide error
# 4993
# https://www.imdb.com/title/tt2298239
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 4994
# https://www.imdb.com/title/tt2300975
# PG-13
# November 7, 2014 (United States)
# budget error
# $6,998,359
# 4995
# https://www.imdb.com/title/tt2692250
# PG
# December 19, 2014 (United States)
# $127,000,000 (estimated)
# $363,204,635
# 4996
# https://www.imdb.com/title/tt3402138
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 4997
# https://www.imdb.com/title/tt3533916
# R
# January 19, 2016 (United States)
# $4,000,000 (estimated)
# worldwide error
# 4998
# https://www.imdb.com/title/tt3647858
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 4999
# https://www.imdb.com/title/tt3775280
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5000
# https://www.imdb.com/title/tt5037780
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5001
# https://www.imdb.com/title/tt7130948
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5002
# https://www.imdb.com/title/tt7208370
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5003
# https://www.imdb.com/title/tt0046273
# mpaarating error
# 1958 (United States)
# budget error
# worldwide error
# 5004
# https://www.imdb.com/title/tt0048053
# mpaarating error
# March 3, 1958 (Spain)
# budget error
# worldwide error
# 5005
# https://www.imdb.com/title/tt0061633
# mpaarating error
# August 10, 1964 (Spain)
# budget error
# $746
# 5006
# https://www.imdb.com/title/tt0078001
# mpaarating error
# December 29, 1977 (Mexico)
# budget error
# worldwide error
# 5007
# https://www.imdb.com/title/tt0097368
# R
# February 10, 1989 (United States)
# budget error
# $38,903,179
# 5008
# https://www.imdb.com/title/tt0446013
# R
# April 13, 2007 (United States)
# $45,000,000 (estimated)
# $30,984,583
# 5009
# https://www.imdb.com/title/tt0091225
# PG
# August 1, 1986 (United States)
# $37,000,000 (estimated)
# $37,962,774
# 5010
# https://www.imdb.com/title/tt0290747
# R
# April 21, 2005 (Singapore)
# $5,000,000 (estimated)
# $1,123,136
# 5011
# https://www.imdb.com/title/tt8716054
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5012
# https://www.imdb.com/title/tt0163676
# PG-13
# July 19, 2000 (United States)
# $24,000,000 (estimated)
# $5,280,035
# 5013
# https://www.imdb.com/title/tt10539310
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5014
# https://www.imdb.com/title/tt1470019
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5015
# https://www.imdb.com/title/tt2239604
# mpaarating error
# rlsdt error
# $7,000,000 (estimated)
# worldwide error
# 5016
# https://www.imdb.com/title/tt0104647
# PG-13
# January 10, 1992 (United States)
# $10,000,000 (estimated)
# $21,142,815
# 5017
# https://www.imdb.com/title/tt0780571
# R
# June 1, 2007 (United States)
# $20,000,000 (estimated)
# $48,443,734
# 5018
# https://www.imdb.com/title/tt0045464
# G
# July 1, 1953 (United States)
# $2,750,000 (estimated)
# worldwide error
# 5019
# https://www.imdb.com/title/tt0312528
# PG
# November 21, 2003 (United States)
# $109,000,000 (estimated)
# $133,960,541
# 5020
# https://www.imdb.com/title/tt13397652
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5021
# https://www.imdb.com/title/tt13397896
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5022
# https://www.imdb.com/title/tt2321555
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5023
# https://www.imdb.com/title/tt2709692
# PG
# November 9, 2018 (United States)
# $75,000,000 (estimated)
# $512,858,819
# 5024
# https://www.imdb.com/title/tt0830971
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5025
# https://www.imdb.com/title/tt1509745
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5026
# https://www.imdb.com/title/tt1911637
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5027
# https://www.imdb.com/title/tt2514476
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5028
# https://www.imdb.com/title/tt14279120
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5029
# https://www.imdb.com/title/tt3347266
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5030
# https://www.imdb.com/title/tt6513318
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5031
# https://www.imdb.com/title/tt7185524
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5032
# https://www.imdb.com/title/tt9689810
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5033
# https://www.imdb.com/title/tt0045083
# Approved
# June 16, 1952 (United Kingdom)
# budget error
# worldwide error
# 5034
# https://www.imdb.com/title/tt0052906
# Unrated
# November 1959 (United States)
# budget error
# worldwide error
# 5035
# https://www.imdb.com/title/tt6241270
# PG
# 2018 (United States)
# $20,000,000 (estimated)
# $12,211,895
# 5036
# https://www.imdb.com/title/tt0072251
# R
# November 14, 1974 (West Germany)
# $5,000,000 (estimated)
# worldwide error
# 5037
# https://www.imdb.com/title/tt0097626
# R
# September 29, 1989 (United States)
# $20,000,000 (estimated)
# $7,237,794
# 5038
# https://www.imdb.com/title/tt1111422
# R
# June 12, 2009 (United States)
# $100,000,000 (estimated)
# $150,166,126
# 5039
# https://www.imdb.com/title/tt0117740
# G
# November 10, 1996 (United States)
# budget error
# worldwide error
# 5040
# https://www.imdb.com/title/tt0220619
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5041
# https://www.imdb.com/title/tt0220783
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5042
# https://www.imdb.com/title/tt0295427
# PG
# August 2, 2002 (United States)
# $16,000,000 (estimated)
# $43,411,001
# 5043
# https://www.imdb.com/title/tt0367652
# R
# August 12, 2005 (United States)
# $22,000,000 (estimated)
# $45,109,561
# 5044
# https://www.imdb.com/title/tt5226736
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5045
# https://www.imdb.com/title/tt5425174
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5046
# https://www.imdb.com/title/tt0112602
# PG-13
# August 4, 1995 (United States)
# budget error
# $7,919,823
# 5047
# https://www.imdb.com/title/tt1717210
# mpaarating error
# April 28, 2012 (United States)
# $5,000,000 (estimated)
# worldwide error
# 5048
# https://www.imdb.com/title/tt0094593
# PG
# April 8, 1988 (United States)
# budget error
# $2,567,099
# 5049
# https://www.imdb.com/title/tt0046928
# Passed
# September 3, 1954 (United States)
# budget error
# worldwide error
# 5050
# https://www.imdb.com/title/tt0047205
# Approved
# April 19, 1954 (United Kingdom)
# budget error
# worldwide error
# 5051
# https://www.imdb.com/title/tt0055972
# Not Rated
# May 1962 (Canada)
# budget error
# worldwide error
# 5052
# https://www.imdb.com/title/tt0119012
# R
# September 5, 1997 (United States)
# $8,000,000 (estimated)
# worldwide error
# 5053
# https://www.imdb.com/title/tt0175877
# R
# August 4, 1999 (France)
# $6,000,000 (estimated)
# worldwide error
# 5054
# https://www.imdb.com/title/tt0184894
# PG-13
# May 26, 2000 (United States)
# $55,000,000 (estimated)
# $99,274,467
# 5055
# https://www.imdb.com/title/tt0284490
# PG-13
# March 15, 2002 (United States)
# $85,000,000 (estimated)
# $77,885,672
# 5056
# https://www.imdb.com/title/tt0300471
# PG-13
# February 7, 2003 (United States)
# $50,000,000 (estimated)
# $88,323,487
# 5057
# https://www.imdb.com/title/tt0859163
# PG-13
# August 1, 2008 (United States)
# $145,000,000 (estimated)
# $403,449,830
# 5058
# https://www.imdb.com/title/tt1464540
# PG-13
# February 18, 2011 (United States)
# $60,000,000 (estimated)
# $149,878,437
# 5059
# https://www.imdb.com/title/tt3829568
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5060
# https://www.imdb.com/title/tt4685784
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5061
# https://www.imdb.com/title/tt0118172
# PG
# October 31, 1997 (United States)
# budget error
# worldwide error
# 5062
# https://www.imdb.com/title/tt1600212
# mpaarating error
# rlsdt error
# $60,000,000 (estimated)
# worldwide error
# 5063
# https://www.imdb.com/title/tt2369119
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5064
# https://www.imdb.com/title/tt7981864
# Not Rated
# April 2, 2018 (United Kingdom)
# £500,000 (estimated)
# worldwide error
# 5065
# https://www.imdb.com/title/tt0120631
# PG-13
# July 31, 1998 (United States)
# $26,000,000 (estimated)
# $98,005,666
# 5066
# https://www.imdb.com/title/tt0191754
# PG-13
# April 14, 2000 (United States)
# $43,000,000 (estimated)
# $62,198,945
# 5067
# https://www.imdb.com/title/tt0195685
# R
# March 17, 2000 (United States)
# $52,000,000 (estimated)
# $256,271,286
# 5068
# https://www.imdb.com/title/tt0388125
# PG-13
# October 7, 2005 (United States)
# budget error
# $83,697,473
# 5069
# https://www.imdb.com/title/tt0413895
# G
# December 15, 2006 (United States)
# $85,000,000 (estimated)
# $148,963,822
# 5070
# https://www.imdb.com/title/tt0821642
# PG-13
# April 24, 2009 (United States)
# $60,000,000 (estimated)
# $38,332,994
# 5071
# https://www.imdb.com/title/tt1736316
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5072
# https://www.imdb.com/title/tt1846816
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5073
# https://www.imdb.com/title/tt2304933
# PG-13
# January 22, 2016 (United States)
# $38,000,000 (estimated)
# $109,906,372
# 5074
# https://www.imdb.com/title/tt2709654
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5075
# https://www.imdb.com/title/tt3978400
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5076
# https://www.imdb.com/title/tt4239560
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5077
# https://www.imdb.com/title/tt1133985
# PG-13
# June 17, 2011 (United States)
# $200,000,000 (estimated)
# $219,851,172
# 5078
# https://www.imdb.com/title/tt1781862
# mpaarating error
# rlsdt error
# budget error
# worldwide error
# 5079
# https://www.imdb.com/title/tt1856101
# R
# October 6, 2017 (United States)
# $150,000,000 (estimated)
# $259,352,064
# 5080
# https://www.imdb.com/title/tt2316204
# R
# May 19, 2017 (United States)
# $97,000,000 (estimated)
# $240,891,763
# 5081
# https://www.imdb.com/title/tt3315342
# R
# March 3, 2017 (United States)
# $97,000,000 (estimated)
# $619,179,950
# 5082
# https://www.imdb.com/title/tt3402236
# PG-13
# November 10, 2017 (United States)
# $55,000,000 (estimated)
# $352,794,081
# 5083
# https://www.imdb.com/title/tt7657566
# PG-13
# February 11, 2022 (United States)
# $90,000,000 (estimated)
# $136,106,267
# 5084
# https://www.imdb.com/title/tt0059470
# Approved
# September 17, 1965 (West Germany)
# $6,290,000 (estimated)
# worldwide error
# 5085
# https://www.imdb.com/title/tt0065214
# R
# June 19, 1969 (United States)
# $6,244,087 (estimated)
# $638,641
# 5086
# https://www.imdb.com/title/tt0076740
# PG
# June 24, 1977 (United States)
# $22,000,000 (estimated)
# $6,014

# %%
imdb_scrape.head()
