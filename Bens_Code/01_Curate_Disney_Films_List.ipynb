# %% [markdown]
# # 01 Curate A List of Disney Films

# %% [markdown]
# I gathered Disney Film Lists from
#  - Disney.com (657 titles)
#  - D23 (The official Disney Fan Club) (749 titles)
#  - Wikipedia (425 titles)
#
# The lists all contain different titles and different film data. I'll explore each and consider creating a single master list of Disney films to work from.

# %% [markdown]
# ## 01.01 Python Imports

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

from pathlib import Path

from datetime import datetime
from sklearn.model_selection import train_test_split

import warnings # necessary b/c pandas & statsmodels datetime issue
warnings.simplefilter(action="ignore")

# %% [markdown]
# ## 01.02 Disney.com Data

# %% [markdown]
# ### 01.02.01 Import Disney.com data

# %%
FL_Disney = pd.read_csv('../Other Source Data/DD_Films_List_Disney_Com/Film_list_Disney_com.csv')
FL_Disney.rename(     columns=({ 'Movie Title': 'title'}),     inplace=True )

print(FL_Disney.shape)
FL_Disney.head()
# Out:
# (657, 1)
#                                          title
# 0                               101 Dalmatians
# 1                        101 Dalmatians (1996)
# 2  101 Dalmatians II: Patch's London Adventure
# 3                               102 Dalmatians
# 4                 20,000 Leagues Under the Sea

# %% [markdown]
# ### 01.02.02 Exploring Disney.com Data

# %% [markdown]
# In some cases, the remake of the film included the year of release in the title.  In some cases, the orignal release includes the year in the title. This may not be big deal as the IMDB

# %% [markdown]
# In some cases, parentheses do not indicate the year of release i.e Frozen (Sing-Along Edition) or The Wizards Return: Alex vs. Alex (TV Special)

# %%
FL_Disney[FL_Disney['title'].str.contains("\(")]
# Out:
#                                               title
# 1                             101 Dalmatians (1996)
# 35                                     Annie (1999)
# 90                                Cinderella (1950)
# 169                            Freaky Friday (1976)
# 171                     Frozen (Sing-Along Edition)
# 348                            Pete's Dragon (2016)
# 420                          Sleeping Beauty (1959)
# 516                          The Jungle Book (1967)
# 517                          The Jungle Book (1994)
# 518                          The Jungle Book (2016)
# 545                         The Muppet Movie (1979)
# 556                          The Parent Trap (1998)
# 577                           The Shaggy Dog (2006)
# 595  The Wizards Return: Alex vs. Alex (TV Special)
# 646                          Winnie the Pooh (2011)

# %% [markdown]
# In some cases, the same or similar title is used multiple times. Since this list is from Disney.com, we will include all of these in our master list but may not include all of the films in our analyis.  Once we have more data, we will explore different groupings and determine which films or subset of films to work with.

# %%
FL_Disney[FL_Disney['title'].str.contains("101 Dalmatians")]
# Out:
#                                                  title
# 0                                       101 Dalmatians
# 1                                101 Dalmatians (1996)
# 2          101 Dalmatians II: Patch's London Adventure
# 412  Sing Along Songs: 101 Dalmatians -- Pongo & Pe...

# %% [markdown]
# The 1982 release of Annie was produced by Rastart and distributed by Columbia pictures.  Not Disney. The 1999 version was a Disney production.

# %%
FL_Disney[FL_Disney['title'].str.contains("Annie")]
# Out:
#            title
# 35  Annie (1999)

# %% [markdown]
# Cinderella was remade in 2015 as a live-action film. It seems odd that (1950) would be used to denote the original Disney production but we're going to leave it for now.

# %%
FL_Disney[FL_Disney['title'].str.contains("Cinderella")]
# Out:
#                                   title
# 89                           Cinderella
# 90                    Cinderella (1950)
# 91      Cinderella II: Dreams Come True
# 92      Cinderella III: A Twist in Time
# 393  Rodgers & Hammerstein's Cinderella

# %% [markdown]
# There was a Freaky Friday release in 1976, 2003, and 2018.  The 2018 release was a TV movie.  Not a theatrical release.

# %%
FL_Disney[FL_Disney['title'].str.contains("Freaky Friday")]
# Out:
#                     title
# 167         Freaky Friday
# 168         Freaky Friday
# 169  Freaky Friday (1976)

# %%
FL_Disney[FL_Disney['title'].str.contains("Pete's Dragon")]
# Out:
#                     title
# 347         Pete's Dragon
# 348  Pete's Dragon (2016)

# %%
FL_Disney[FL_Disney['title'].str.contains("Sleeping Beauty")]
# Out:
#                       title
# 420  Sleeping Beauty (1959)
# 630  Waking Sleeping Beauty

# %% [markdown]
# When spot checking some title, I noticed that "Sing Along Songs: The Jungle Book -- The Bare ..." is in IMDB as "Disney Sing-Along-Songs: The Bare Necessities". Forthermore, when looking at IMDB, many of the "Disney Sing-Along-Songs" titles do not contain the name of the film. Creating a script to pick up the nuances may be time consuming with too litle reward. Sorting out the Sing-Along titles may be better done manually for the sake of time.

# %%
FL_Disney[FL_Disney['title'].str.contains("Jungle Book")]
# Out:
#                                                  title
# 417  Sing Along Songs: The Jungle Book -- The Bare ...
# 516                             The Jungle Book (1967)
# 517                             The Jungle Book (1994)
# 518                             The Jungle Book (2016)
# 519                                  The Jungle Book 2

# %%
FL_Disney[FL_Disney['title'].str.contains("Muppet Movie")]
# Out:
#                        title
# 545  The Muppet Movie (1979)

# %%
FL_Disney[FL_Disney['title'].str.contains("Parent Trap")]
# Out:
#                       title
# 555         The Parent Trap
# 556  The Parent Trap (1998)
# 557      The Parent Trap II

# %%
FL_Disney[FL_Disney['title'].str.contains("Shaggy Dog")]
# Out:
#                      title
# 576         The Shaggy Dog
# 577  The Shaggy Dog (2006)

# %%
FL_Disney[FL_Disney['title'].str.contains("Winnie the Pooh")]
# Out:
#                                        title
# 537   The Many Adventures of Winnie the Pooh
# 646                   Winnie the Pooh (2011)
# 647  Winnie the Pooh: A Very Merry Pooh Year
# 648     Winnie the Pooh: Springtime with Roo

# %% [markdown]
# ## 01.03 D23 Data

# %% [markdown]
# ### 01.03.01 Import D23 data

# %% [markdown]
# This one column holds the film title, year of release, and Motion Picture Association film rating. Will need to seperate those before moving forward.  <br>
# Also, the D23 list (Disney's Official Fan Club) has almost 100 more titles that the Disney.com list.  657 to 749
# .  I might need to create a list of titles that differ from list to list and research further

# %%
FL_D23 = pd.read_csv('../Other Source Data/DD_Films_List_D23/D23_list.csv', header=None )
FL_D23.rename(     columns=({ 0: 'orig_title'}),     inplace=True )
print(FL_D23.shape)
FL_D23.head(5)
# Out:
# (749, 1)
#                                      orig_title
# 0  1. 1937: Snow White and the Seven Dwarfs (G)
# 1                        2. 1940: Pinocchio (G)
# 2                         3. 1940: Fantasia (G)
# 3                 4. 1941: The Reluctant Dragon
# 4                            5. 1941: Dumbo (G)

# %% [markdown]
# ### 01.03.02 Exploring D23 Data

# %%
# Splitting out the d_23 index number from the title
# Not dropping the d23_index just yet incase I need it to trouble shoot

index_split = FL_D23['orig_title'].str.split(".", n = 1, expand = True)    
FL_D23['d23_index'] = index_split[0]
FL_D23['d23_title_str'] = index_split[1]

# %%
FL_D23.head(5)
# Out:
#                                      orig_title d23_index  \
# 0  1. 1937: Snow White and the Seven Dwarfs (G)         1
# 1                        2. 1940: Pinocchio (G)         2
# 2                         3. 1940: Fantasia (G)         3
# 3                 4. 1941: The Reluctant Dragon         4
# 4                            5. 1941: Dumbo (G)         5
#
#                                 d23_title_str
# 0   1937: Snow White and the Seven Dwarfs (G)
# 1                         1940: Pinocchio (G)
# 2                          1940: Fantasia (G)
# 3                  1941: The Reluctant Dragon
# 4                             1941: Dumbo (G)

# %%
# Splitting out the year number from the title

year_split = FL_D23['d23_title_str'].str.split(":", n = 1, expand = True)    

FL_D23['d23_year'] = year_split[0]
FL_D23['d23_title_str'] = year_split[1]

FL_D23 = FL_D23[['orig_title', 'd23_index', 'd23_year', 'd23_title_str']]

# %%
FL_D23.head(5)
# Out:
#                                      orig_title d23_index d23_year  \
# 0  1. 1937: Snow White and the Seven Dwarfs (G)         1     1937
# 1                        2. 1940: Pinocchio (G)         2     1940
# 2                         3. 1940: Fantasia (G)         3     1940
# 3                 4. 1941: The Reluctant Dragon         4     1941
# 4                            5. 1941: Dumbo (G)         5     1941
#
#                           d23_title_str
# 0   Snow White and the Seven Dwarfs (G)
# 1                         Pinocchio (G)
# 2                          Fantasia (G)
# 3                  The Reluctant Dragon
# 4                             Dumbo (G)

# %%
# Now that we have the year seperate, we have to split the title further.
# The problem is that some of the strings end with the rating (G), (PG-13), etc.
# While others have no rating
# Further complicating things, some of the title strings include the name of the production company in a set or parenthesis
# and lastly, sometimes there is a production company with a rating, sometimes there is a production company with no rating
# sometimes there is no production company, but there is a rating, and sometimes there is neither
# After a few different attempts, the logic just got too messy. Going to use if/else (np.where) statements

# %%
# If the rating is included in the title string, then assign the rating value to the rating column

FL_D23['d23_rating'] = np.where(FL_D23['d23_title_str'].str.contains("\(G\)"), "G", 
                                np.where(FL_D23['d23_title_str'].str.contains("\(PG\)"), "PG", 
                                         np.where(FL_D23['d23_title_str'].str.contains("\(PG-13\)"), "PG-13", 
                                                  np.where(FL_D23['d23_title_str'].str.contains("\(R\)"), "R",
                                                           np.where(FL_D23['d23_title_str'].str.contains("\(PG_13\)"), "PG-13",
                                                                    np.where(FL_D23['d23_title_str'].str.contains("\(PG-13"), "PG-13",
                                                                             np.where(FL_D23['d23_title_str'].str.contains("\(NR\)"), "NaN",
                                                           "NaN" ) ) ) ) ) ) )

# If the rating is included in the title string, then strip it out

FL_D23['d23_title_str'] = np.where(FL_D23['d23_title_str'].str.contains("\(G\)"), FL_D23['d23_title_str'].str.replace("\(G\)",''), 
                                np.where(FL_D23['d23_title_str'].str.contains("\(PG\)"), FL_D23['d23_title_str'].str.replace("\(PG\)",''), 
                                         np.where(FL_D23['d23_title_str'].str.contains("\(PG-13\)"), FL_D23['d23_title_str'].str.replace("\(PG-13\)",''), 
                                                  np.where(FL_D23['d23_title_str'].str.contains("\(R\)"), FL_D23['d23_title_str'].str.replace("\(R\)",''),
                                                           np.where(FL_D23['d23_title_str'].str.contains("\(PG_13\)"), FL_D23['d23_title_str'].str.replace("\(PG_13\)",''),
                                                                    np.where(FL_D23['d23_title_str'].str.contains("\(PG-13"), FL_D23['d23_title_str'].str.replace("\(PG-13",''),
                                                                             np.where(FL_D23['d23_title_str'].str.contains("\(NR\)"), FL_D23['d23_title_str'].str.replace("\(NR\)",''),
                                                                    FL_D23['d23_title_str'] ) ) ) ) ) ) )

FL_D23 = FL_D23[['orig_title', 'd23_index', 'd23_year', 'd23_rating', 'd23_title_str']]

# %%
FL_D23.head(35)
# Out:
#                                            orig_title d23_index d23_year  \
# 0        1. 1937: Snow White and the Seven Dwarfs (G)         1     1937
# 1                              2. 1940: Pinocchio (G)         2     1940
# 2                               3. 1940: Fantasia (G)         3     1940
# 3                       4. 1941: The Reluctant Dragon         4     1941
# 4                                  5. 1941: Dumbo (G)         5     1941
# 5                                  6. 1942: Bambi (G)         6     1942
# 6                             7. 1943: Saludos Amigos         7     1943
# 7                  8. 1943: Victory Through Air Power         8     1943
# 8                   9. 1945: The Three Caballeros (G)         9     1945
# 9                           10. 1946: Make Mine Music        10     1946
# 10                    11. 1946: Song of the South (G)        11     1946
# 11                       12. 1947: Fun and Fancy Free        12     1947
# 12                              13. 1948: Melody Time        13     1948
# 13                  14. 1949: So Dear to My Heart (G)        14     1949
# 14  15. 1949: The Adventures of Ichabod and Mr. To...        15     1949
# 15                           16. 1950: Cinderella (G)        16     1950
# 16                     17. 1950: Treasure Island (PG)        17     1950
# 17                  18. 1951: Alice in Wonderland (G)        18     1951
# 18  19. 1952: The Story of Robin Hood and His Merr...        19     1952
# 19                            20. 1953: Peter Pan (G)        20     1953
# 20              21. 1953: The Sword and the Rose (PG)        21     1953
# 21                        22. 1953: The Living Desert        22     1953
# 22              23. 1954: Rob Roy, the Highland Rogue        23     1954
# 23                    24. 1954: The Vanishing Prairie        24     1954
# 24         25. 1954: 20,000 Leagues Under the Sea (G)        25     1954
# 25  26. 1955: Davy Crockett, King of the Wild Fron...        26     1955
# 26                   27. 1955: Lady and the Tramp (G)        27     1955
# 27                         28. 1955: The African Lion        28     1955
# 28                      29. 1955: The Littlest Outlaw        29     1955
# 29               30. 1956: The Great Locomotive Chase        30     1956
# 30      31. 1956: Davy Crockett and the River Pirates        31     1956
# 31                          32. 1956: Secrets of Life        32     1956
# 32                  33. 1956: Westward Ho the Wagons!        33     1956
# 33                           34. 1957: Johnny Tremain        34     1957
# 34                                35. 1957: Perri (G)        35     1957
#
#    d23_rating                                 d23_title_str
# 0           G              Snow White and the Seven Dwarfs
# 1           G                                    Pinocchio
# 2           G                                     Fantasia
# 3         NaN                          The Reluctant Dragon
# 4           G                                        Dumbo
# 5           G                                        Bambi
# 6         NaN                                Saludos Amigos
# 7         NaN                     Victory Through Air Power
# 8           G                         The Three Caballeros
# 9         NaN                               Make Mine Music
# 10          G                            Song of the South
# 11        NaN                            Fun and Fancy Free
# 12        NaN                                   Melody Time
# 13          G                          So Dear to My Heart
# 14          G       The Adventures of Ichabod and Mr. Toad
# 15          G                                   Cinderella
# 16         PG                              Treasure Island
# 17          G                          Alice in Wonderland
# 18         PG   The Story of Robin Hood and His Merrie Men
# 19          G                                    Peter Pan
# 20         PG                       The Sword and the Rose
# 21        NaN                             The Living Desert
# 22        NaN                   Rob Roy, the Highland Rogue
# 23        NaN                         The Vanishing Prairie
# 24          G                 20,000 Leagues Under the Sea
# 25         PG     Davy Crockett, King of the Wild Frontier
# 26          G                           Lady and the Tramp
# 27        NaN                              The African Lion
# 28        NaN                           The Littlest Outlaw
# 29        NaN                    The Great Locomotive Chase
# 30        NaN           Davy Crockett and the River Pirates
# 31        NaN                               Secrets of Life
# 32        NaN                       Westward Ho the Wagons!
# 33        NaN                                Johnny Tremain
# 34          G                                        Perri

# %%
FL_D23.tail(35)
# Out:
#                                             orig_title d23_index d23_year  \
# 714                     715. 2016: Queen of Katwe (PG)       715     2016
# 715         716. 2016: Doctor Strange (Marvel) (PG-13)       716     2016
# 716                              717. 2016: Moana (PG)       717     2016
# 717  718. 2016: Rogue One: A Star Wars Story (Lucas...       718     2016
# 718                   719. 2017: Dangal (Disney India)       719     2017
# 719               720. 2017: Beauty and the Beast (PG)       720     2017
# 720        721. 2017: Born in China (Disneynature) (G)       721     2017
# 721  722. 2017: Guardians of the Galaxy, Vol. 2 (Ma...       722     2017
# 722  723. 2017: Pirates of the Caribbean: Dead Men ...       723     2017
# 723                      724. 2017: Cars 3 (Pixar) (G)       724     2017
# 724             725. 2017: Jagga Jasoos (Disney India)       725     2017
# 725         726. 2017: Thor: Ragnarok (Marvel) (PG-13)       726     2017
# 726                       727. 2017: Coco (Pixar) (PG)       727     2017
# 727  728. 2017: Star Wars: The Last Jedi (Lucasfilm...       728     2017
# 728          729. 2018: Black Panther (Marvel) (PG-13)       729     2018
# 729                  730. 2018: A Wrinkle in Time (PG)       730     2018
# 730  731. 2018: Avengers: Infinity War (Marvel) (PG...       731     2018
# 731  732. 2018: Solo: A Star Wars Story (Lucasfilm)...       732     2018
# 732              733. 2018: Incredibles 2 (Pixar) (PG)       733     2018
# 733   734. 2018: Ant-Man and The Wasp (Marvel) (PG_13)       734     2018
# 734                  735. 2018: Christopher Robin (PG)       735     2018
# 735  736. 2018: The Nutcracker and the Four Realms ...       736     2018
# 736          737. 2018: Ralph Breaks the Internet (PG)       737     2018
# 737               738. 2018: Mary Poppins Returns (PG)       738     2018
# 738         739. 2019: Captain Marvel (Marvel) (PG-13)       739     2019
# 739                              740. 2019: Dumbo (PG)       740     2019
# 740             741. 2019: Penguins (Disneynature) (G)       741     2019
# 741      742. 2019: Avengers: Endgame (Marvel) (PG-13)       742     2019
# 742                            743. 2019: Aladdin (PG)       743     2019
# 743                 744. 2019: Toy Story 4 (Pixar) (G)       744     2019
# 744                      745. 2019: The Lion King (PG)       745     2019
# 745       746. 2019: Maleficent: Mistress of Evil (PG)       746     2019
# 746                           747. 2019: Frozen 2 (PG)       747     2019
# 747  748. 2019: Star Wars: The Rise of Skywalker(PG...       748     2019
# 748                     749. 2020: Onward (Pixar) (PG)       749     2020
#
#     d23_rating                                      d23_title_str
# 714         PG                                    Queen of Katwe
# 715      PG-13                           Doctor Strange (Marvel)
# 716         PG                                             Moana
# 717      PG-13            Rogue One: A Star Wars Story (Lucasilm)
# 718        NaN                              Dangal (Disney India)
# 719         PG                              Beauty and the Beast
# 720          G                      Born in China (Disneynature)
# 721      PG-13          Guardians of the Galaxy, Vol. 2 (Marvel)
# 722      PG-13   Pirates of the Caribbean: Dead Men Tell No Ta...
# 723          G                                    Cars 3 (Pixar)
# 724        NaN                        Jagga Jasoos (Disney India)
# 725      PG-13                           Thor: Ragnarok (Marvel)
# 726         PG                                      Coco (Pixar)
# 727      PG-13              Star Wars: The Last Jedi (Lucasfilm)
# 728      PG-13                            Black Panther (Marvel)
# 729         PG                                 A Wrinkle in Time
# 730      PG-13                   Avengers: Infinity War (Marvel)
# 731      PG-13               Solo: A Star Wars Story (Lucasfilm)
# 732         PG                             Incredibles 2 (Pixar)
# 733      PG-13                     Ant-Man and The Wasp (Marvel)
# 734         PG                                 Christopher Robin
# 735         PG                The Nutcracker and the Four Realms
# 736         PG                         Ralph Breaks the Internet
# 737         PG                              Mary Poppins Returns
# 738      PG-13                           Captain Marvel (Marvel)
# 739         PG                                             Dumbo
# 740          G                           Penguins (Disneynature)
# 741      PG-13                        Avengers: Endgame (Marvel)
# 742         PG                                           Aladdin
# 743          G                               Toy Story 4 (Pixar)
# 744         PG                                     The Lion King
# 745         PG                      Maleficent: Mistress of Evil
# 746         PG                                          Frozen 2
# 747      PG-13                   Star Wars: The Rise of Skywalker
# 748         PG                                    Onward (Pixar)

# %%
# Count the parenthesis remaining to understand how much clean up is left

FL_D23['d23_p_count'] = FL_D23['d23_title_str'].str.count("\(")

# %%
# 405 rows are ready to go
# 344 rows contain one set of parenthesis

FL_D23['d23_p_count'].value_counts()
# Out:
# 0    405
# 1    344
# Name: d23_p_count, dtype: int64

# %%
FL_D23[FL_D23['d23_p_count'] == 1]
# Out:
#                                             orig_title d23_index d23_year  \
# 155                156. 1984: Splash (Touchstone) (PG)       156     1984
# 157               158. 1984: Country (Touchstone) (PG)       158     1984
# 158  159. 1985: Baby...Secret of the Lost Legend(To...       159     1985
# 161    162. 1985: My Science Project (Touchstone) (PG)       162     1985
# 164  165. 1986: Down and Out in Beverly Hills (Touc...       165     1986
# ..                                                 ...       ...      ...
# 738         739. 2019: Captain Marvel (Marvel) (PG-13)       739     2019
# 740             741. 2019: Penguins (Disneynature) (G)       741     2019
# 741      742. 2019: Avengers: Endgame (Marvel) (PG-13)       742     2019
# 743                 744. 2019: Toy Story 4 (Pixar) (G)       744     2019
# 748                     749. 2020: Onward (Pixar) (PG)       749     2020
#
#     d23_rating                                   d23_title_str  d23_p_count
# 155         PG                            Splash (Touchstone)             1
# 157         PG                           Country (Touchstone)             1
# 158         PG   Baby...Secret of the Lost Legend(Touchstone)             1
# 161         PG                My Science Project (Touchstone)             1
# 164          R     Down and Out in Beverly Hills (Touchstone)             1
# ..         ...                                             ...          ...
# 738      PG-13                        Captain Marvel (Marvel)             1
# 740          G                        Penguins (Disneynature)             1
# 741      PG-13                     Avengers: Endgame (Marvel)             1
# 743          G                            Toy Story 4 (Pixar)             1
# 748         PG                                 Onward (Pixar)             1
#
# [344 rows x 6 columns]

# %%
# Splitting out the title from everything else

studio_split = FL_D23['d23_title_str'].str.split("\(", n = 1, expand = True)

# %%
FL_D23['d23_title'] = studio_split[0]
FL_D23['d23_studio'] = studio_split[1]
FL_D23['d23_studio'] = FL_D23['d23_studio'].str.replace('\)', '')

# FL_D23[FL_D23['d23_p_count'] == 1]
FL_D23 = FL_D23[['orig_title', 'd23_index', 'd23_year', 'd23_rating', 'd23_title', 'd23_studio']]

# %%
FL_D23 = FL_D23[['orig_title', 'd23_index', 'd23_year', 'd23_rating', 'd23_title', 'd23_studio']]

# %%
FL_D23.head()
# Out:
#                                      orig_title d23_index d23_year d23_rating  \
# 0  1. 1937: Snow White and the Seven Dwarfs (G)         1     1937          G
# 1                        2. 1940: Pinocchio (G)         2     1940          G
# 2                         3. 1940: Fantasia (G)         3     1940          G
# 3                 4. 1941: The Reluctant Dragon         4     1941        NaN
# 4                            5. 1941: Dumbo (G)         5     1941          G
#
#                            d23_title d23_studio
# 0   Snow White and the Seven Dwarfs        None
# 1                         Pinocchio        None
# 2                          Fantasia        None
# 3               The Reluctant Dragon       None
# 4                             Dumbo        None

# %%
# spot checking some film titles to confirm that the splits all worked as expected.

# for val in FL_D23['d23_title']:
#     print(val)
    
# for val in FL_D23['d23_year']:
#     print(val)    

# There are a number of "Touchstone" and "Hollywood Pictures", so the split didn't work as expected
# for val in FL_D23['d23_rating']:
#     print(val)    

# for val in FL_D23['d23_studio']:
#     print(val)

# %% [markdown]
# ## 1.04 Wikipedia All Films

# %% [markdown]
# ### 01.04.01 Import Wikipedia All Films  data

# %% [markdown]
# Wikipedia's list includes a lot more information, but only 425 titels, as compared to 657 from Disney.com and 748 from D23.

# %%
FL_WK = pd.read_csv('../Other Source Data/DD_Films_LIst_WK/FIlms_List_WK.csv', )
print(FL_WK.shape)
FL_WK.head()
# Out:
# (425, 10)
#    US Release Other Release Date  \
# 0   5/19/1937                NaN
# 1   12/4/1939                NaN
# 2    6/1/1940                NaN
# 3  10/23/1941                NaN
# 4   11/2/1941                NaN
#
#                                           Title Co-production companies  \
# 0  Academy Award Review of Walt Disney Cartoons                     NaN
# 1               Snow White and the Seven Dwarfs                     NaN
# 2                                     Pinocchio                     NaN
# 3                                         Dumbo                     NaN
# 4                                         Bambi                     NaN
#
#            Category Direct to video or streaming exclusive Disney+  \
# 0  Animated feature                                            NaN
# 1  Animated feature                                            NaN
# 2  Animated feature                                            NaN
# 3  Animated feature                                            NaN
# 4  Animated feature                                            NaN
#
#   Premium video on demand release through Disney+  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Simultaneous release to theatres and on premium video on demand non-US Film  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#    Notes
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %% [markdown]
# ## 1.05 Wikipedia Animated Films

# %% [markdown]
# ### 01.05.01 Import Wikipedia Animated  data

# %% [markdown]
# Wikipedia's list of Disney anitmated films.  A lot of movie info, but only 144 titles.

# %%
FL_WK_Animated = pd.read_csv('../Other Source Data/DD_Animated_List_WK/Disney_Animated_List_wk.csv', )
print(FL_WK_Animated.shape)
FL_WK_Animated.head()
# Out:
# (144, 14)
#                                           Title  \
# 0  Academy Award Review of Walt Disney Cartoons
# 1               Snow White and the Seven Dwarfs
# 2                                     Pinocchio
# 3                                      Fantasia
# 4                          The Reluctant Dragon
#
#   Original U.S. theatrical release date[rls 1] Other Theatrical Release Date  \
# 0                                    5/19/1937                           NaN
# 1                                   12/21/1937                           NaN
# 2                                     2/7/1940                           NaN
# 3                                   11/13/1940                     1/29/1941
# 4                                    6/20/1941                           NaN
#
#                            Animation studio[st 2] CoCredit  \
# 0  Walt Disney Animation Studios (1937 - Present)      NaN
# 1  Walt Disney Animation Studios (1937 - Present)      NaN
# 2  Walt Disney Animation Studios (1937 - Present)      NaN
# 3  Walt Disney Animation Studios (1937 - Present)      NaN
# 4  Walt Disney Animation Studios (1937 - Present)      NaN
#
#                                       Released By  Film Type  \
# 0                             RKO Radio Pictures   Animation
# 1                             RKO Radio Pictures   Animation
# 2                             RKO Radio Pictures   Animation
# 3  Walt Disney Productions /  RKO Radio Pictures   Animation
# 4                             RKO Radio Pictures   Animation
#
#    Live-action / Animation hybrid  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3  Live-action / Animation hybrid
# 4  Live-action / Animation hybrid
#
#   Not produced by Disney, but released under its label. US Release Exceptions  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#   Released under the Touchstone Pictures label  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   Released by Disney outside North America  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Released by Miramax Films when the studio was a subsidiary of Disney at the time of release  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Release Note
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Originally distributed by Walt Disney Producti...
# 4                                                NaN

# %% [markdown]
# ## 1.06 Conclusion and next steps

# %% [markdown]
# For the sake of time, I elected to just work from the Disney.com list of films.  If Disney consideres a title to be a Disney movie, that that should be goog enough for me.
