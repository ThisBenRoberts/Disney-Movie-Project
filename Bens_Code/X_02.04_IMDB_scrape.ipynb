# %%
# You'll need the requests library in order to fully utilize bs4.
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup
import time
import random

# %%
Disney_IMDB = pd.read_csv('../Bens_Data/Updated_IMDB_Disney_444.csv')
Disney_IMDB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      444 non-null    int64
#  1   orig_index      444 non-null    int64
#  2   DFL_title       444 non-null    object
#  3   tconst          444 non-null    object
#  4   titleType       444 non-null    object
#  5   primaryTitle    444 non-null    object
#  6   originalTitle   444 non-null    object
#  7   startYear       444 non-null    int64
#  8   runtimeMinutes  444 non-null    int64
#  9   genres          444 non-null    object
#  10  lower_title     444 non-null    object
#  11  averageRating   444 non-null    float64
#  12  numVotes        444 non-null    float64
#  13  _merge          444 non-null    object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 48.7+ KB

# %%
Disney_IMDB.head(5)
# Out:
#    Unnamed: 0  orig_index                     DFL_title     tconst titleType  \
# 0           0           0                101 Dalmatians  tt0115433     movie
# 1           1           5                102 Dalmatians  tt0211181     movie
# 2           2          10  20,000 Leagues Under the Sea  tt0046672     movie
# 3           3          24                  A Bug's Life  tt0120623     movie
# 4           4          74             A Christmas Carol  tt1067106     movie
#
#                    primaryTitle                 originalTitle  startYear  \
# 0                101 Dalmatians                101 Dalmatians       1996
# 1                102 Dalmatians                102 Dalmatians       2000
# 2  20,000 Leagues Under the Sea  20,000 Leagues Under the Sea       1954
# 3                  A Bug's Life                  A Bug's Life       1998
# 4             A Christmas Carol             A Christmas Carol       2009
#
#    runtimeMinutes                      genres                  lower_title  \
# 0             103      Adventure,Comedy,Crime               101 dalmatians
# 1             100     Adventure,Comedy,Family               102 dalmatians
# 2             127      Adventure,Drama,Family  20000 leagues under the sea
# 3              95  Adventure,Animation,Comedy                  a bugs life
# 4              96  Adventure,Animation,Comedy            a christmas carol
#
#    averageRating  numVotes _merge
# 0            5.7  109712.0   both
# 1            4.8   37056.0   both
# 2            7.2   33109.0   both
# 3            7.2  284538.0   both
# 4            6.8  112582.0   both

# %%
imdb_scrape = pd.read_csv('../Bens_Data/imdb_scrape_rnd2.csv')
# imdb_errors_r2 = pd.read_csv('../Bens_Data/imdb_errors_rnd2.csv')
imdb_scrape.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  440 non-null    int64
#  1   tconst      440 non-null    object
#  2   newurl      440 non-null    object
#  3   rating      440 non-null    float64
#  4   votes       440 non-null    object
#  5   year        440 non-null    int64
#  6   mpaarating  440 non-null    object
#  7   runtime     440 non-null    object
#  8   rlsdt       440 non-null    object
#  9   budget      261 non-null    object
#  10  worldwide   308 non-null    object
#  11  soup_text   440 non-null    object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 41.4+ KB

# %%
imdb_scrape.head(5)
# Out:
#    Unnamed: 0     tconst                                newurl  rating votes  \
# 0           0  tt0115433  https://www.imdb.com/title/tt0115433     5.7  110K
# 1           1  tt0211181  https://www.imdb.com/title/tt0211181     4.8   37K
# 2           2  tt0120623  https://www.imdb.com/title/tt0120623     7.2  285K
# 3           3  tt1067106  https://www.imdb.com/title/tt1067106     6.8  113K
# 4           4  tt0113198  https://www.imdb.com/title/tt0113198     6.9   52K
#
#    year mpaarating runtime                              rlsdt  \
# 0  1996          G  1h 43m  November 27, 1996 (United States)
# 1  2000          G  1h 40m  November 22, 2000 (United States)
# 2  1998          G  1h 35m  November 25, 1998 (United States)
# 3  2009         PG  1h 36m   November 6, 2009 (United States)
# 4  1995          G  1h 18m      April 7, 1995 (United States)
#
#                      budget     worldwide  \
# 0   $75,000,000 (estimated)  $320,689,294
# 1   $85,000,000 (estimated)  $183,611,771
# 2  $120,000,000 (estimated)  $363,258,859
# 3  $200,000,000 (estimated)  $325,286,646
# 4   $18,000,000 (estimated)   $35,348,597
#
#                                            soup_text
# 0  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...
# 1  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...
# 2  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...
# 3  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...
# 4  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...

# %%
tconst
0	tt0057312
1	tt2064925
2	tt0058099
3	tt1686635

# %%
Disney_IMDB[Disney_IMDB['tconst'] == 'tt0057312']
# Out:
#      Unnamed: 0  orig_index                       DFL_title     tconst  \
# 176         182        3264  Miracle of the White Stallions  tt0057312
#
#     titleType                    primaryTitle                   originalTitle  \
# 176     movie  Miracle of the White Stallions  Miracle of the White Stallions
#
#      startYear  runtimeMinutes                  genres  \
# 176       1963             118  Adventure,Drama,Family
#
#                         lower_title  averageRating  numVotes _merge
# 176  miracle of the white stallions            6.5     696.0   both

# %%
imdb_scrape[imdb_scrape['tconst'] == 'tt0057312']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, tconst, newurl, rating, votes, year, mpaarating, runtime, rlsdt, budget, worldwide, soup_text]
# Index: []

# %%
# Target web page:
url = "https://www.imdb.com/title/"
# Establishing the connection to the web page:
response = requests.get(url)
# response.text[:50]
soup = BeautifulSoup(response.text, 'lxml')

imdb_scrape = pd.DataFrame(columns=['tconst','newurl','rating','votes','year','mpaarating','runtime','rlsdt','budget','worldwide','soup_text'])
imdb_errors = pd.DataFrame(columns=['tconst'])

# %%
for const in Disney_IMDB['tconst']:
    
#     found1 = imdb_scrape[imdb_scrape['tconst'].str.contains(const)]
#     found2 = imdb_errors[imdb_errors['tconst'].str.contains(const)]
#     summ = found1.count().sum() + found2.count().sum()
    
#     if summ < 1:
    
        # const = "tt0115433"
        # const = "tt0029583"
        # const = "tt1067106"

        t= random.uniform(1, 5)
        time.sleep(t)
        newurl = url + const
        response = requests.get(newurl)
        soup = BeautifulSoup(response.text, 'lxml')

        rtspan = soup.find_all('span', {'class' : 'sc-7ab21ed2-1 jGRxWM'})
        rating = rtspan[0].get_text()

        vtdiv = soup.find_all('div', {'class' : 'sc-7ab21ed2-3 dPVcnq'})
        votes = vtdiv[0].text

        # mpaaspan = soup.find_all('span', {'class' : 'ipc-metadata-list-item__list-content-item'})
        # mpaarating = mpaaspan[2].get_text()
        try:

            metaul = soup.find_all('ul', {'data-testid' : 'hero-title-block__metadata'})
            year = metaul[0].find_all('li')[0].find_all('span')[0].get_text()
            mpaarating = metaul[0].find_all('li')[1].find_all('span')[0].get_text()
            runtime = metaul[0].find_all('li')[2].get_text()
            rlsdt = soup.find_all('li', {'data-testid' : 'title-details-releasedate'})[0].find_all('a')[1].get_text()
            budget = soup.find_all('li', {'data-testid' : 'title-boxoffice-budget'})[0].find_all('li')[0].get_text()
            worldwide = soup.find_all('li', {'data-testid' : 'title-boxoffice-cumulativeworldwidegross'})[0].find_all('li')[0].get_text()
            print(newurl)
            print(rating)
            print(votes) 
            print(year) 
            print(mpaarating) 
            print(runtime) 
            print(rlsdt) 
            print(budget) 
            print(worldwide) 
            imdb_scrape.loc[len(imdb_scrape.index)] = [const, newurl, rating, votes, year ,mpaarating ,runtime ,rlsdt ,budget ,worldwide, soup]

        except:
            imdb_errors.loc[len(imdb_errors.index)] = [const]
            print(f"ERROR ON: {const}")
# Out:
# https://www.imdb.com/title/tt0115433
# 5.7
# 110K
# 1996
# G
# 1h 43m
# November 27, 1996 (United States)
# $75,000,000 (estimated)
# $320,689,294
# https://www.imdb.com/title/tt0211181
# 4.8
# 37K
# 2000
# G
# 1h 40m
# November 22, 2000 (United States)
# $85,000,000 (estimated)
# $183,611,771
# ERROR ON: tt0046672
# https://www.imdb.com/title/tt0120623
# 7.2
# 285K
# 1998
# G
# 1h 35m
# November 25, 1998 (United States)
# $120,000,000 (estimated)
# $363,258,859
# https://www.imdb.com/title/tt1067106
# 6.8
# 113K
# 2009
# PG
# 1h 36m
# November 6, 2009 (United States)
# $200,000,000 (estimated)
# $325,286,646
# ERROR ON: tt0106868
# https://www.imdb.com/title/tt0113198
# 6.9
# 52K
# 1995
# G
# 1h 18m
# April 7, 1995 (United States)
# $18,000,000 (estimated)
# $35,348,597
# https://www.imdb.com/title/tt0113538
# 4.7
# 6.2K
# 1995
# PG
# 1h 29m
# August 11, 1995 (United States)
# $15,000,000 (estimated)
# $13,406,717
# ERROR ON: tt0058657
# https://www.imdb.com/title/tt1620680
# 4.2
# 44K
# 2018
# PG
# 1h 49m
# March 9, 2018 (United States)
# $100,000,000 (estimated)
# $132,675,864
# https://www.imdb.com/title/tt0092513
# 6.9
# 43K
# 1987
# PG-13
# 1h 42m
# July 3, 1987 (United States)
# $7,000,000 (estimated)
# $34,368,475
# https://www.imdb.com/title/tt1223236
# 7.5
# 6.4K
# 2011
# G
# 1h 29m
# April 22, 2011 (United States)
# $5,000,000 (estimated)
# $30,857,747
# https://www.imdb.com/title/tt0103639
# 8.1
# 399K
# 1992
# G
# 1h 30m
# November 25, 1992 (United States)
# $28,000,000 (estimated)
# $504,050,219
# https://www.imdb.com/title/tt6139732
# 6.9
# 255K
# 2019
# PG
# 2h 8m
# May 24, 2019 (United States)
# $183,000,000 (estimated)
# $1,050,693,953
# https://www.imdb.com/title/tt1698641
# 6.2
# 44K
# 2014
# PG
# 1h 21m
# October 10, 2014 (United States)
# $28,000,000 (estimated)
# $100,654,149
# ERROR ON: tt0043274
# https://www.imdb.com/title/tt1014759
# 6.4
# 405K
# 2010
# PG
# 1h 48m
# March 5, 2010 (United States)
# $200,000,000 (estimated)
# $1,025,468,216
# https://www.imdb.com/title/tt2567026
# 6.2
# 104K
# 2016
# PG
# 1h 53m
# May 27, 2016 (United States)
# $170,000,000 (estimated)
# $299,820,798
# ERROR ON: tt0417415
# ERROR ON: tt0055740
# ERROR ON: tt0381006
# ERROR ON: tt0082017
# ERROR ON: tt0043286
# https://www.imdb.com/title/tt0109127
# 6.2
# 32K
# 1994
# PG
# 1h 42m
# July 15, 1994 (United States)
# $24,000,000 (estimated)
# $50,236,831
# https://www.imdb.com/title/tt0478970
# 7.3
# 636K
# 2015
# PG-13
# 1h 57m
# July 17, 2015 (United States)
# $130,000,000 (estimated)
# $519,311,965
# https://www.imdb.com/title/tt5095030
# 7.0
# 374K
# 2018
# PG-13
# 1h 58m
# July 6, 2018 (United States)
# $162,000,000 (estimated)
# $622,674,139
# https://www.imdb.com/title/tt0327437
# 5.8
# 89K
# 2004
# PG
# 2h
# June 16, 2004 (United States)
# $110,000,000 (estimated)
# $72,178,895
# ERROR ON: tt3089630
# https://www.imdb.com/title/tt0230011
# 6.9
# 115K
# 2001
# PG
# 1h 35m
# June 15, 2001 (United States)
# $120,000,000 (estimated)
# $186,053,725
# https://www.imdb.com/title/tt4154796
# 8.4
# 1M
# 2019
# PG-13
# 3h 1m
# April 26, 2019 (United States)
# $356,000,000 (estimated)
# $2,797,501,328
# https://www.imdb.com/title/tt4154756
# 8.5
# 998K
# 2018
# PG-13
# 2h 29m
# April 27, 2018 (United States)
# $321,000,000 (estimated)
# $2,048,359,754
# ERROR ON: tt0054649
# ERROR ON: tt0168473
# ERROR ON: tt0034492
# https://www.imdb.com/title/tt2458776
# 7.3
# 6.8K
# 2014
# G
# 1h 18m
# April 18, 2014 (United States)
# $5,000,000 (estimated)
# $21,316,745
# https://www.imdb.com/title/tt0101414
# 8.1
# 439K
# 1991
# G
# 1h 24m
# November 22, 1991 (United States)
# $25,000,000 (estimated)
# $424,967,620
# https://www.imdb.com/title/tt2771200
# 7.1
# 299K
# 2017
# PG
# 2h 9m
# March 17, 2017 (United States)
# $160,000,000 (estimated)
# $1,273,576,220
# ERROR ON: tt0066817
# ERROR ON: tt0092638
# https://www.imdb.com/title/tt1014775
# 3.9
# 24K
# 2008
# PG
# 1h 31m
# October 3, 2008 (United States)
# $20,000,000 (estimated)
# $149,292,488
# https://www.imdb.com/title/tt2245084
# 7.8
# 445K
# 2014
# PG
# 1h 42m
# November 7, 2014 (United States)
# $165,000,000 (estimated)
# $657,869,686
# ERROR ON: tt0055793
# https://www.imdb.com/title/tt1825683
# 7.3
# 714K
# 2018
# PG-13
# 2h 14m
# February 16, 2018 (United States)
# $200,000,000 (estimated)
# $1,347,597,973
# https://www.imdb.com/title/tt3480822
# 6.7
# 344K
# 2021
# PG-13
# 2h 14m
# July 9, 2021 (United States)
# $200,000,000 (estimated)
# $379,751,655
# ERROR ON: tt0062737
# ERROR ON: tt0109287
# https://www.imdb.com/title/tt0397892
# 6.9
# 205K
# 2008
# PG
# 1h 36m
# November 21, 2008 (United States)
# $150,000,000 (estimated)
# $309,979,994
# ERROR ON: tt0055807
# https://www.imdb.com/title/tt1217209
# 7.1
# 400K
# 2012
# PG
# 1h 33m
# June 22, 2012 (United States)
# 7.4
# 216K
# 2021
# PG-13
# 2h 14m
# May 28, 2021 (United States)
# $100,000,000 (estimated)
# $233,503,234
# ERROR ON: tt0109520
# ERROR ON: tt0116000
# ERROR ON: tt0052722
# ERROR ON: tt0049125
# ERROR ON: tt0047977
# https://www.imdb.com/title/tt0130623
# 6.4
# 59K
# 2000
# PG
# 1h 22m
# May 19, 2000 (United States)
# $127,500,000 (estimated)
# $349,822,765
# ERROR ON: tt1714832
# https://www.imdb.com/title/tt0451079
# 6.8
# 138K
# 2008
# G
# 1h 26m
# March 14, 2008 (United States)
# $85,000,000 (estimated)
# $298,572,799
# ERROR ON: tt0099472
# https://www.imdb.com/title/tt0033563
# 7.3
# 129K
# 1941
# G
# 1h 4m
# October 31, 1941 (United States)
# $950,000 (estimated)
# $3,731
# https://www.imdb.com/title/tt3861390
# 6.3
# 73K
# 2019
# PG
# 1h 52m
# March 29, 2019 (United States)
# $170,000,000 (estimated)
# $353,284,621
# https://www.imdb.com/title/tt0393597
# 8.0
# 14K
# 2007
# G
# 1h 30m
# April 22, 2009 (United States)
# €30,000,000 (estimated)
# $108,976,456
# https://www.imdb.com/title/tt0397313
# 7.3
# 64K
# 2006
# PG
# 2h
# February 17, 2006 (United States)
# $40,000,000 (estimated)
# $120,455,994
# ERROR ON: tt0058056
# https://www.imdb.com/title/tt2953050
# 7.3
# 176K
# 2021
# PG
# 1h 42m
# November 24, 2021 (United States)
# $50,000,000 (estimated)
# $252,446,462
# https://www.imdb.com/title/tt0461770
# 7.1
# 194K
# 2007
# PG
# 1h 47m
# November 21, 2007 (United States)
# $85,000,000 (estimated)
# $340,487,836
# ERROR ON: tt0120659
# https://www.imdb.com/title/tt0848537
# 6.6
# 104K
# 2013
# PG
# 1h 42m
# May 24, 2013 (United States)
# $100,000,000 (estimated)
# $268,426,634
# ERROR ON: tt0072951
# https://www.imdb.com/title/tt0032455
# 7.7
# 94K
# 1940
# G
# 2h 5m
# September 19, 1941 (United States)
# $2,280,000 (estimated)
# $76,411,819
# https://www.imdb.com/title/tt0120910
# 7.1
# 38K
# 1999
# G
# 1h 15m
# June 16, 2000 (United States)
# $80,000,000 (estimated)
# $90,874,570
# https://www.imdb.com/title/tt3411444
# 6.7
# 55K
# 2017
# PG
# 1h 48m
# December 15, 2017 (United States)
# $111,000,000 (estimated)
# $296,069,199
# https://www.imdb.com/title/tt2277860
# 7.3
# 265K
# 2016
# PG
# 1h 37m
# June 17, 2016 (United States)
# $200,000,000 (estimated)
# $1,028,570,942
# https://www.imdb.com/title/tt0266543
# 8.2
# 1M
# 2003
# G
# 1h 40m
# May 30, 2003 (United States)
# $94,000,000 (estimated)
# $940,352,645
# ERROR ON: tt0116311
# https://www.imdb.com/title/tt0091059
# 6.9
# 47K
# 1986
# PG
# 1h 30m
# August 1, 1986 (United States)
# $9,000,000 (estimated)
# $18,564,613
# https://www.imdb.com/title/tt0119137
# 5.3
# 89K
# 1997
# PG
# 1h 33m
# November 26, 1997 (United States)
# $80,000,000 (estimated)
# $177,977,226
# ERROR ON: tt0060420
# ERROR ON: tt0113104
# https://www.imdb.com/title/tt1142977
# 6.9
# 105K
# 2012
# PG
# 1h 27m
# October 5, 2012 (United States)
# $39,000,000 (estimated)
# $81,493,846
# ERROR ON: tt0076054
# https://www.imdb.com/title/tt0322330
# 6.3
# 135K
# 2003
# PG
# 1h 37m
# August 6, 2003 (United States)
# $20,000,000 (estimated)
# $160,846,332
# ERROR ON: tt0039404
# https://www.imdb.com/title/tt0119190
# 5.5
# 76K
# 1997
# PG
# 1h 32m
# July 16, 1997 (United States)
# $55,000,000 (estimated)
# $174,463,257
# https://www.imdb.com/title/tt0436339
# 5.1
# 46K
# 2009
# PG
# 1h 28m
# July 24, 2009 (United States)
# $150,000,000 (estimated)
# $292,817,898
# https://www.imdb.com/title/tt0297144
# 6.8
# 5.4K
# 2003
# G
# 1h 1m
# May 23, 2003 (United States)
# $13,000,000 (estimated)
# $27,570,076
# ERROR ON: tt0385726
# ERROR ON: tt0054944
# https://www.imdb.com/title/tt3896198
# 7.6
# 643K
# 2017
# PG-13
# 2h 16m
# May 5, 2017 (United States)
# $200,000,000 (estimated)
# $863,756,051
# ERROR ON: tt0074599
# https://www.imdb.com/title/tt1127884
# 2.6
# 12K
# 2008
# G
# 1h 14m
# February 1, 2008 (United States)
# $7,000,000 (estimated)
# $70,642,966
# https://www.imdb.com/title/tt1114677
# 4.5
# 42K
# 2009
# G
# 1h 42m
# April 10, 2009 (United States)
# $30,000,000 (estimated)
# $155,545,279
# ERROR ON: tt0110006
# ERROR ON: tt0080861
# ERROR ON: tt0076137
# ERROR ON: tt0071607
# https://www.imdb.com/title/tt0400497
# 4.9
# 47K
# 2005
# G
# 1h 41m
# June 22, 2005 (United States)
# $50,000,000 (estimated)
# $144,146,816
# https://www.imdb.com/title/tt0119282
# 7.3
# 223K
# 1997
# G
# 1h 33m
# June 27, 1997 (United States)
# $85,000,000 (estimated)
# $252,712,101
# https://www.imdb.com/title/tt0962726
# 4.9
# 62K
# 2008
# G
# 1h 52m
# October 24, 2008 (United States)
# $11,000,000 (estimated)
# $252,909,177
# ERROR ON: tt1556143
# https://www.imdb.com/title/tt0107120
# 6.9
# 120K
# 1993
# PG
# 1h 36m
# July 16, 1993 (United States)
# $28,000,000 (estimated)
# $45,395,069
# https://www.imdb.com/title/tt0311289
# 7.0
# 86K
# 2003
# PG
# 1h 57m
# April 18, 2003 (United States)
# $20,000,000 (estimated)
# $71,406,573
# https://www.imdb.com/title/tt0299172
# 5.4
# 23K
# 2004
# PG
# 1h 16m
# April 2, 2004 (United States)
# $110,000,000 (estimated)
# $145,358,062
# ERROR ON: tt0116552
# ERROR ON: tt0107131
# https://www.imdb.com/title/tt0104437
# 4.8
# 44K
# 1992
# PG
# 1h 29m
# July 17, 1992 (United States)
# $40,000,000 (estimated)
# $58,662,452
# https://www.imdb.com/title/tt0097523
# 6.4
# 152K
# 1989
# PG
# 1h 33m
# June 23, 1989 (United States)
# $18,000,000 (estimated)
# $222,724,172
# ERROR ON: tt0077698
# https://www.imdb.com/title/tt0268380
# 7.5
# 471K
# 2002
# PG
# 1h 21m
# March 15, 2002 (United States)
# $59,000,000 (estimated)
# $383,257,136
# ERROR ON: tt0396652
# https://www.imdb.com/title/tt0155753
# 5.5
# 11K
# 1998
# PG
# 1h 26m
# November 13, 1998 (United States)
# $30,000,000 (estimated)
# $12,214,338
# ERROR ON: tt0056095
# https://www.imdb.com/title/tt3606756
# 7.6
# 282K
# 2018
# PG
# 1h 58m
# June 15, 2018 (United States)
# $200,000,000 (estimated)
# $1,243,089,244
# https://www.imdb.com/title/tt2096673
# 8.2
# 682K
# 2015
# PG
# 1h 35m
# June 19, 2015 (United States)
# $175,000,000 (estimated)
# $858,848,019
# https://www.imdb.com/title/tt0141369
# 4.1
# 48K
# 1999
# PG
# 1h 18m
# July 23, 1999 (United States)
# $90,000,000 (estimated)
# $134,403,112
# https://www.imdb.com/title/tt2180411
# 5.9
# 139K
# 2014
# PG
# 2h 5m
# December 25, 2014 (United States)
# $50,000,000 (estimated)
# $212,902,372
# https://www.imdb.com/title/tt0445990
# 7.0
# 70K
# 2006
# PG
# 1h 45m
# August 25, 2006 (United States)
# $40,000,000 (estimated)
# $58,480,828
# ERROR ON: tt0110157
# https://www.imdb.com/title/tt0116683
# 6.7
# 66K
# 1996
# PG
# 1h 19m
# April 12, 1996 (United States)
# $38,000,000 (estimated)
# $28,946,127
# https://www.imdb.com/title/tt0401729
# 6.6
# 268K
# 2012
# PG-13
# 2h 12m
# March 9, 2012 (United States)
# $250,000,000 (estimated)
# $284,139,100
# ERROR ON: tt0050567
# ERROR ON: tt1229827
# https://www.imdb.com/title/tt0119432
# 5.1
# 24K
# 1997
# PG
# 1h 45m
# March 7, 1997 (United States)
# $32,000,000 (estimated)
# $59,927,618
# ERROR ON: tt0053977
# https://www.imdb.com/title/tt0870154
# 6.6
# 173K
# 2021
# PG-13
# 2h 7m
# July 30, 2021 (United States)
# $200,000,000 (estimated)
# $220,889,446
# ERROR ON: tt0053994
# ERROR ON: tt0065943
# https://www.imdb.com/title/tt0048280
# 7.3
# 132K
# 1955
# G
# 1h 16m
# June 22, 1955 (United States)
# $4,000,000 (estimated)
# $93,933,394
# ERROR ON: tt8096832
# ERROR ON: tt0070131
# ERROR ON: tt0986264
# https://www.imdb.com/title/tt0275847
# 7.3
# 184K
# 2002
# PG
# 1h 25m
# June 21, 2002 (United States)
# $80,000,000 (estimated)
# $273,144,151
# ERROR ON: tt0060640
# ERROR ON: tt12801262
# ERROR ON: tt0038718
# https://www.imdb.com/title/tt1587310
# 7.0
# 367K
# 2014
# PG
# 1h 37m
# May 30, 2014 (United States)
# $180,000,000 (estimated)
# $758,411,779
# https://www.imdb.com/title/tt4777008
# 6.6
# 100K
# 2019
# PG
# 1h 59m
# October 18, 2019 (United States)
# $185,000,000 (estimated)
# $491,730,089
# ERROR ON: tt0113755
# $21,437,192
# ERROR ON: tt0118172
# https://www.imdb.com/title/tt0120762
# 7.6
# 278K
# 1998
# G
# 1h 28m
# June 19, 1998 (United States)
# $90,000,000 (estimated)
# $304,320,254
# https://www.imdb.com/title/tt4566758
# 5.7
# 143K
# 2020
# PG-13
# 1h 55m
# September 4, 2020 (United States)
# $200,000,000 (estimated)
# $66,800,000
# ERROR ON: tt0117110
# https://www.imdb.com/title/tt2281587
# 6.4
# 34K
# 2014
# PG
# 1h 47m
# March 21, 2014 (United States)
# $50,000,000 (estimated)
# $80,383,113
# https://www.imdb.com/title/tt0120764
# 5.1
# 14K
# 1999
# PG
# 1h 34m
# February 12, 1999 (United States)
# $65,000,000 (estimated)
# $36,850,101
# ERROR ON: tt0206013
# ERROR ON: tt0068990
# https://www.imdb.com/title/tt0368891
# 6.9
# 324K
# 2004
# PG
# 2h 11m
# November 19, 2004 (United States)
# $100,000,000 (estimated)
# $347,512,318
# https://www.imdb.com/title/tt0465234
# 6.5
# 232K
# 2007
# PG
# 2h 4m
# December 21, 2007 (United States)
# $130,000,000 (estimated)
# $459,242,249
# ERROR ON: tt0063341
# ERROR ON: tt0086005
# https://www.imdb.com/title/tt0104990
# 6.9
# 21K
# 1992
# PG
# 2h 1m
# April 10, 1992 (United States)
# $15,000,000 (estimated)
# $2,819,485
# https://www.imdb.com/title/tt0082810
# 6.5
# 1.4K
# 1982
# PG
# 1h 47m
# February 5, 1982 (United States)
# $10,000,000 (estimated)
# $8,000,000
# ERROR ON: tt0055232
# ERROR ON: tt0074968
# ERROR ON: tt0069031
# https://www.imdb.com/title/tt0765128
# 7.7
# 9.6K
# 2009
# G
# 1h 24m
# April 22, 2010 (United States)
# $80,000,000 (estimated)
# $83,090,556
# https://www.imdb.com/title/tt0976238
# 5.3
# 38K
# 2009
# PG
# 1h 28m
# November 25, 2009 (United States)
# $35,000,000 (estimated)
# $96,753,696
# ERROR ON: tt0050798
# https://www.imdb.com/title/tt0095776
# 6.7
# 48K
# 1988
# G
# 1h 14m
# November 18, 1988 (United States)
# $31,000,000 (estimated)
# $74,151,346
# ERROR ON: tt1621994
# ERROR ON: tt0070481
# ERROR ON: tt0089731
# ERROR ON: tt0075016
# https://www.imdb.com/title/tt7146812
# 7.4
# 139K
# 2020
# PG
# 1h 42m
# March 6, 2020 (United States)
# $175,000,000 (estimated)
# $141,940,042
# ERROR ON: tt0114048
# https://www.imdb.com/title/tt1623205
# 6.3
# 206K
# 2013
# PG
# 2h 10m
# March 8, 2013 (United States)
# $215,000,000 (estimated)
# $493,311,825
# https://www.imdb.com/title/tt0046183
# 7.3
# 136K
# 1953
# G
# 1h 17m
# February 5, 1953 (United States)
# $4,000,000 (estimated)
# $87,404,651
# https://www.imdb.com/title/tt0076538
# 6.3
# 24K
# 1977
# G
# 2h 8m
# November 3, 1977 (United States)
# $10,000,000 (estimated)
# $39,588,000
# https://www.imdb.com/title/tt2788732
# 6.7
# 58K
# 2016
# PG
# 1h 42m
# ERROR ON: tt0078158
# https://www.imdb.com/title/tt0280030
# 5.8
# 20K
# 2002
# G
# 1h 12m
# February 15, 2002 (United States)
# $20,000,000 (estimated)
# $115,121,981
# https://www.imdb.com/title/tt0089908
# 6.8
# 27K
# 1985
# PG
# 1h 53m
# June 21, 1985 (United States)
# $25,000,000 (estimated)
# $11,137,801
# ERROR ON: tt0095993
# ERROR ON: tt0075141
# https://www.imdb.com/title/tt1436562
# 6.9
# 222K
# 2011
# PG
# 1h 36m
# April 15, 2011 (United States)
# $90,000,000 (estimated)
# $483,866,518
# https://www.imdb.com/title/tt2357291
# 6.3
# 88K
# 2014
# G
# 1h 41m
# April 11, 2014 (United States)
# $103,000,000 (estimated)
# $498,781,117
# ERROR ON: tt0046246
# ERROR ON: tt0070608
# https://www.imdb.com/title/tt0358082
# 6.4
# 143K
# 2005
# PG
# 1h 31m
# March 11, 2005 (United States)
# $75,000,000 (estimated)
# $262,511,490
# ERROR ON: tt0120029
# https://www.imdb.com/title/tt3748528
# 7.8
# 601K
# 2016
# PG-13
# 2h 13m
# December 16, 2016 (United States)
# $200,000,000 (estimated)
# $1,056,057,720
# ERROR ON: tt2414212
# ERROR ON: tt0057473
# https://www.imdb.com/title/tt2140373
# 7.5
# 160K
# 2013
# PG-13
# 2h 5m
# December 20, 2013 (United States)
# $35,000,000 (estimated)
# $117,867,984
# ERROR ON: tt0067712
# https://www.imdb.com/title/tt1028576
# 7.2
# 28K
# 2010
# PG
# 2h 3m
# October 8, 2010 (United States)
# $35,000,000 (estimated)
# $60,321,861
# ERROR ON: tt0049733
# ERROR ON: tt2064925
# https://www.imdb.com/title/tt9376612
# 7.5
# 340K
# 2021
# PG-13
# 2h 12m
# September 3, 2021 (United States)
# $200,000,000 (estimated)
# $432,243,292
# https://www.imdb.com/title/tt0099816
# 6.6
# 2.8K
# 1990
# PG
# 1h 32m
# March 1, 1991 (United States)
# NOK 60,000,000 (estimated)
# $15,104,156
# https://www.imdb.com/title/tt0099816
# 6.6
# 2.8K
# 1990
# PG
# 1h 32m
# March 1, 1991 (United States)
# NOK 60,000,000 (estimated)
# $15,104,156
# https://www.imdb.com/title/tt0405325
# 6.3
# 85K
# 2005
# PG
# 1h 40m
# July 29, 2005 (United States)
# $35,000,000 (estimated)
# $86,369,815
# https://www.imdb.com/title/tt0053285
# 7.3
# 145K
# 1959
# G
# 1h 15m
# January 29, 1959 (United States)
# $6,000,000 (estimated)
# $51,600,000
# ERROR ON: tt0065003
# https://www.imdb.com/title/tt0281373
# 5.2
# 27K
# 2002
# PG
# 1h 39m
# January 18, 2002 (United States)
# $33,000,000 (estimated)
# $115,035,090
# https://www.imdb.com/title/tt0029583
# 7.6
# 194K
# 1937
# Approved
# 1h 23m
# February 4, 1938 (United States)
# $1,499,000 (estimated)
# $184,925,486
# ERROR ON: tt0069291
# ERROR ON: tt0041890
# https://www.imdb.com/title/tt3778644
# 6.9
# 328K
# 2018
# PG-13
# 2h 15m
# May 25, 2018 (United States)
# $275,000,000 (estimated)
# $392,924,807
# https://www.imdb.com/title/tt0086336
# 6.7
# 9.2K
# 1983
# PG
# 1h 35m
# April 29, 1983 (United States)
# $19,000,000 (estimated)
# $8,400,000
# ERROR ON: tt0057518
# ERROR ON: tt2948372
# ERROR ON: tt0069303
# https://www.imdb.com/title/tt5814534
# 6.8
# 46K
# 2019
# PG
# 1h 42m
# December 25, 2019 (United States)
# $100,000,000 (estimated)
# $171,616,764
# https://www.imdb.com/title/tt0111271
# 6.0
# 1.2K
# 1994
# PG
# 1h 42m
# October 28, 1994 (United States)
# $19,200,000 (estimated)
# $3,342,223
# ERROR ON: tt0057542
# ERROR ON: tt0070716
# https://www.imdb.com/title/tt0054357
# 7.1
# 16K
# 1960
# G
# 2h 6m
# December 21, 1960 (United States)
# $5,000,000 (estimated)
# $40,356,000
# https://www.imdb.com/title/tt0111359
# 5.9
# 3.8K
# 1995
# PG
# 1h 36m
# March 24, 1995 (United States)
# $32,000,000 (estimated)
# $11,047,627
# https://www.imdb.com/title/tt0398286
# 7.8
# 438K
# 2010
# PG
# 1h 40m
# November 24, 2010 (United States)
# $260,000,000 (estimated)
# $592,462,816
# https://www.imdb.com/title/tt0120855
# 7.3
# 219K
# 1999
# G
# 1h 28m
# June 18, 1999 (United States)
# $130,000,000 (estimated)
# $448,191,819
# ERROR ON: tt1705952
# https://www.imdb.com/title/tt0350194
# 5.8
# 1.8K
# 2004
# PG
# 1h 13m
# January 16, 2004 (United States)
# $10,000,000 (estimated)
# $6,491,969
# ERROR ON: tt0054372
# ERROR ON: tt0084783
# ERROR ON: tt0059793
# ERROR ON: tt0120317
# ERROR ON: tt0061333
# https://www.imdb.com/title/tt0106223
# 6.2
# 8.5K
# 1993
# PG
# 1h 48m
# April 2, 1993 (United States)
# $6,500,000 (estimated)
# $24,103,594
# https://www.imdb.com/title/tt2081266
# 5.8
# 336
# 2012
# PG
# 1h 39m
# December 20, 2012 (Germany)
# €6,500,000 (estimated)
# $1,217,451
# ERROR ON: tt0041094
# ERROR ON: tt0047803
# ERROR ON: tt0072653
# https://www.imdb.com/title/tt0078790
# 6.0
# 2.9K
# 1979
# G
# 1h 28m
# June 27, 1979 (United States)
# $5,450,000 (estimated)
# $20,931,111
# https://www.imdb.com/title/tt0065421
# 7.1
# 102K
# 1970
# G
# 1h 18m
# December 24, 1970 (United States)
# $4,000,000 (estimated)
# $35,459,543
# ERROR ON: tt0066811
# ERROR ON: tt0071199
# https://www.imdb.com/title/tt3691740
# 6.4
# 84K
# 2016
# PG
# 1h 57m
# July 1, 2016 (United States)
# $140,000,000 (estimated)
# $195,243,411
# https://www.imdb.com/title/tt0112499
# 5.5
# 10K
# 1995
# PG
# 1h 40m
# September 29, 1995 (United States)
# $12,000,000 (estimated)
# $17,736,619
# ERROR ON: tt0032254
# ERROR ON: tt0068276
# https://www.imdb.com/title/tt0088814
# 6.4
# 35K
# 1985
# PG
# 1h 20m
# July 24, 1985 (United States)
# $44,000,000 (estimated)
# $21,288,692
# https://www.imdb.com/title/tt0078869
# 5.9
# 25K
# 1979
# PG
# 1h 38m
# December 21, 1979 (United States)
# $20,000,000 (estimated)
# $35,841,901
# ERROR ON: tt0065482
# ERROR ON: tt1015971
# ERROR ON: tt0092695
# ERROR ON: tt0071288
# ERROR ON: tt0077305
# ERROR ON: tt0090840
# https://www.imdb.com/title/tt0499448
# 6.5
# 207K
# 2008
# PG
# 2h 30m
# May 16, 2008 (United States)
# $225,000,000 (estimated)
# $419,665,568
# ERROR ON: tt0065566
# https://www.imdb.com/title/tt0276033
# 4.2
# 5.5K
# 2002
# G
# 1h 28m
# July 26, 2002 (United States)
# $35,000,000 (estimated)
# $18,012,097
# ERROR ON: tt0902967
# ERROR ON: tt0082263
# ERROR ON: tt0196516
# https://www.imdb.com/title/tt0120917
# 7.4
# 197K
# 2000
# G
# 1h 18m
# December 15, 2000 (United States)
# $100,000,000 (estimated)
# $169,661,687
# ERROR ON: tt0060408
# ERROR ON: tt0058099
# https://www.imdb.com/title/tt2025690
# 6.7
# 66K
# 2016
# PG-13
# 1h 57m
# January 29, 2016 (United States)
# $80,000,000 (estimated)
# $52,099,090
# https://www.imdb.com/title/tt0082406
# 7.3
# 91K
# 1981
# G
# 1h 23m
# July 10, 1981 (United States)
# $12,000,000 (estimated)
# $63,456,988
# https://www.imdb.com/title/tt0492956
# 6.2
# 65K
# 2007
# PG
# 1h 50m
# September 28, 2007 (United States)
# $22,000,000 (estimated)
# $147,880,543
# ERROR ON: tt0061715
# https://www.imdb.com/title/tt1979388
# 6.7
# 112K
# 2015
# PG
# 1h 33m
# November 25, 2015 (United States)
# $200,000,000 (estimated)
# $332,207,671
# ERROR ON: tt0049279
# https://www.imdb.com/title/tt0091149
# 7.2
# 49K
# 1986
# G
# 1h 14m
# July 2, 1986 (United States)
# $14,000,000 (estimated)
# $38,625,550
# ERROR ON: tt0082474
# https://www.imdb.com/title/tt0388980
# 7.4
# 30K
# 2005
# PG
# 2h
# September 30, 2005 (United States)
# $26,000,000 (estimated)
# $15,431,177
# ERROR ON: tt0061749
# https://www.imdb.com/title/tt0338094
# 5.1
# 48K
# 2003
# PG
# 1h 28m
# November 26, 2003 (United States)
# $90,000,000 (estimated)
# $182,290,266
# ERROR ON: tt0063091
# https://www.imdb.com/title/tt0116583
# 7.0
# 153K
# 1996
# G
# 1h 31m
# June 21, 1996 (United States)
# $100,000,000 (estimated)
# $325,338,851
# ERROR ON: tt0057180
# https://www.imdb.com/title/tt0317705
# 8.1
# 703K
# 2004
# PG
# 1h 55m
# November 5, 2004 (United States)
# $92,000,000 (estimated)
# $631,607,053
# ERROR ON: tt0071671
# ERROR ON: tt0089385
# https://www.imdb.com/title/tt0283426
# 5.3
# 16K
# 2003
# G
# 1h 12m
# February 14, 2003 (United States)
# $20,000,000 (estimated)
# $186,303,759
# https://www.imdb.com/title/tt0219854
# 6.1
# 42K
# 2000
# PG
# 1h 44m
# July 7, 2000 (United States)
# $65,000,000 (estimated)
# $110,317,580
# https://www.imdb.com/title/tt0081031
# 5.7
# 1.4K
# 1980
# G
# 1h 37m
# June 25, 1980 (United States)
# $6,000,000 (estimated)
# $11,000,000
# ERROR ON: tt0056173
# ERROR ON: tt0051864
# https://www.imdb.com/title/tt0110357
# 8.5
# 1M
# 1994
# G
# 1h 28m
# June 24, 1994 (United States)
# $45,000,000 (estimated)
# $1,063,611,805
# https://www.imdb.com/title/tt6105098
# 6.9
# 236K
# 2019
# PG
# 1h 58m
# July 19, 2019 (United States)
# $260,000,000 (estimated)
# $1,662,899,439
# https://www.imdb.com/title/tt0097757
# 7.6
# 254K
# 1989
# G
# 1h 23m
# November 17, 1989 (United States)
# $40,000,000 (estimated)
# $211,343,479
# ERROR ON: tt0076320
# ERROR ON: tt0048304
# ERROR ON: tt0046008
# https://www.imdb.com/title/tt0306841
# 5.5
# 39K
# 2003
# PG
# 1h 34m
# May 2, 2003 (United States)
# $17,000,000 (estimated)
# $55,534,455
# https://www.imdb.com/title/tt1210819
# 6.4
# 231K
# 2013
# PG-13
# 2h 30m
# July 3, 2013 (United States)
# $215,000,000 (estimated)
# $260,502,115
# ERROR ON: tt0064603
# ERROR ON: tt0076363
# https://www.imdb.com/title/tt0104868
# 6.5
# 65K
# 1992
# PG
# 1h 44m
# October 2, 1992 (United States)
# $10,000,000 (estimated)
# $50,752,337
# ERROR ON: tt0066728
# ERROR ON: tt5372452
# ERROR ON: tt0058355
# ERROR ON: tt0059462
# ERROR ON: tt0058371
# https://www.imdb.com/title/tt0104940
# 7.7
# 57K
# 1992
# G
# 1h 25m
# December 11, 1992 (United States)
# $12,000,000 (estimated)
# $32,574,382
# https://www.imdb.com/title/tt1204342
# 7.1
# 91K
# 2011
# PG
# 1h 43m
# November 23, 2011 (United States)
# $45,000,000 (estimated)
# $165,184,237
# ERROR ON: tt0079639
# https://www.imdb.com/title/tt5523010
# 5.5
# 33K
# 2018
# PG
# 1h 39m
# November 2, 2018 (United States)
# $120,000,000 (estimated)
# $173,961,069
# https://www.imdb.com/title/tt1462769
# 6.6
# 47K
# 2012
# PG
# 1h 45m
# August 15, 2012 (United States)
# $25,000,000 (estimated)
# $56,012,642
# ERROR ON: tt0063389
# https://www.imdb.com/title/tt0250371
# 6.3
# 4.4K
# 2001
# PG
# 1h 53m
# April 12, 2002 (United States)
# $7,000,000 (estimated)
# $4,760,014
# https://www.imdb.com/title/tt0395699
# 5.6
# 93K
# 2005
# PG
# 1h 35m
# March 4, 2005 (United States)
# $56,000,000 (estimated)
# $198,636,868
# ERROR ON: tt0055277
# ERROR ON: tt0120783
# https://www.imdb.com/title/tt2452042
# 7.0
# 45K
# 2015
# G
# 1h 28m
# November 6, 2015 (United States)
# $99,000,000 (estimated)
# $246,233,113
# ERROR ON: tt1059955
# https://www.imdb.com/title/tt0780521
# 7.1
# 139K
# 2009
# G
# 1h 37m
# December 11, 2009 (United States)
# $105,000,000 (estimated)
# $267,045,765
# https://www.imdb.com/title/tt0247638
# 6.3
# 140K
# 2001
# G
# 1h 55m
# August 3, 2001 (United States)
# $26,000,000 (estimated)
# $165,335,153
# https://www.imdb.com/title/tt0368933
# 5.8
# 79K
# 2004
# G
# 1h 53m
# August 11, 2004 (United States)
# $40,000,000 (estimated)
# $134,734,481
# ERROR ON: tt0034091
# https://www.imdb.com/title/tt0076618
# 6.9
# 63K
# 1977
# G
# 1h 18m
# June 22, 1977 (United States)
# $7,500,000 (estimated)
# $71,215,869
# ERROR ON: tt1346308
# https://www.imdb.com/title/tt0100477
# 6.8
# 42K
# 1990
# G
# 1h 17m
# November 16, 1990 (United States)
# $30,000,000 (estimated)
# $27,931,461
# https://www.imdb.com/title/tt0102803
# 6.5
# 57K
# 1991
# PG
# 1h 48m
# June 21, 1991 (United States)
# $35,000,000 (estimated)
# $46,704,056
# https://www.imdb.com/title/tt0265662
# 6.9
# 34K
# 2002
# G
# 2h 7m
# March 29, 2002 (United States)
# $22,000,000 (estimated)
# $80,693,537
# https://www.imdb.com/title/tt0111070
# 6.5
# 113K
# 1994
# PG
# 1h 37m
# November 11, 1994 (United States)
# $22,000,000 (estimated)
# $190,539,357
# https://www.imdb.com/title/tt0304669
# 5.7
# 56K
# 2002
# G
# 1h 44m
# November 1, 2002 (United States)
# $65,000,000 (estimated)
# $172,855,065
# https://www.imdb.com/title/tt0452681
# 4.8
# 37K
# 2006
# G
# 1h 32m
# November 3, 2006 (United States)
# $12,000,000 (estimated)
# $110,768,122
# ERROR ON: tt0496386
# ERROR ON: tt0075200
# ERROR ON: tt0053271
# https://www.imdb.com/title/tt0393735
# 4.4
# 19K
# 2006
# PG
# 1h 38m
# March 10, 2006 (United States)
# $50,000,000 (estimated)
# $87,134,280
# ERROR ON: tt0054307
# https://www.imdb.com/title/tt0963966
# 6.1
# 160K
# 2010
# PG
# 1h 49m
# July 14, 2010 (United States)
# $150,000,000 (estimated)
# $215,283,742
# ERROR ON: tt0045197
# https://www.imdb.com/title/tt0166896
# 8.0
# 89K
# 1999
# G
# 1h 52m
# November 3, 1999 (France)
# $10,000,000 (estimated)
# $6,416,569
# ERROR ON: tt0073760
# ERROR ON: tt0046387
# ERROR ON: tt1686635
# https://www.imdb.com/title/tt0057546
# 7.2
# 96K
# 1963
# G
# 1h 19m
# June 21, 1964 (United States)
# $3,000,000 (estimated)
# $12,000,000
# ERROR ON: tt0038166
# ERROR ON: tt0057579
# https://www.imdb.com/title/tt0108333
# 6.4
# 54K
# 1993
# PG
# 1h 45m
# November 12, 1993 (United States)
# $30,000,000 (estimated)
# $53,898,845
# https://www.imdb.com/title/tt0220099
# 6.3
# 19K
# 2000
# G
# 1h 17m
# February 11, 2000 (United States)
# $30,000,000 (estimated)
# $96,159,800
# ERROR ON: tt0061135
# ERROR ON: tt0047642
# ERROR ON: tt0081738
# https://www.imdb.com/title/tt0405469
# 5.2
# 26K
# 2006
# G
# 1h 22m
# April 14, 2006 (United States)
# $80,000,000 (estimated)
# $102,338,515
# ERROR ON: tt0067985
# ERROR ON: tt0070928
# ERROR ON: tt0318850
# ERROR ON: tt0053352
# https://www.imdb.com/title/tt3501632
# 7.9
# 689K
# 2017
# PG-13
# 2h 10m
# November 3, 2017 (United States)
# $180,000,000 (estimated)
# $853,983,911
# ERROR ON: tt0059796
# ERROR ON: tt0054390
# ERROR ON: tt0112302
# https://www.imdb.com/title/tt1964418
# 6.4
# 180K
# 2015
# PG
# 2h 10m
# May 22, 2015 (United States)
# $190,000,000 (estimated)
# $209,035,668
# ERROR ON: tt0052300
# https://www.imdb.com/title/tt0114709
# 8.3
# 957K
# 1995
# G
# 1h 21m
# November 22, 1995 (United States)
# $30,000,000 (estimated)
# $394,436,586
# https://www.imdb.com/title/tt0120363
# 7.9
# 563K
# 1999
# G
# 1h 32m
# November 24, 1999 (United States)
# $90,000,000 (estimated)
# $497,375,381
# https://www.imdb.com/title/tt0435761
# 8.3
# 809K
# 2010
# G
# 1h 43m
# June 18, 2010 (United States)
# $200,000,000 (estimated)
# $1,066,970,811
# https://www.imdb.com/title/tt1979376
# 7.7
# 236K
# 2019
# G
# 1h 40m
# June 21, 2019 (United States)
# $200,000,000 (estimated)
# $1,073,394,593
# ERROR ON: tt1247700
# ERROR ON: tt0043067
# ERROR ON: tt0075347
# https://www.imdb.com/title/tt0133240
# 7.2
# 114K
# 2002
# PG
# 1h 35m
# November 27, 2002 (United States)
# $140,000,000 (estimated)
# $110,041,363
# https://www.imdb.com/title/tt0086476
# 5.3
# 503
# 1983
# PG
# 1h 31m
# March 11, 1983 (United States)
# $5,000,000 (estimated)
# $4,304,286
# https://www.imdb.com/title/tt0084827
# 6.8
# 119K
# 1982
# PG
# 1h 36m
# July 9, 1982 (United States)
# $17,000,000 (estimated)
# $33,000,525
# https://www.imdb.com/title/tt1104001
# 6.8
# 330K
# 2010
# PG
# 2h 5m
# December 17, 2010 (United States)
# $170,000,000 (estimated)
# $400,063,852
# ERROR ON: tt0081664
# https://www.imdb.com/title/tt0283084
# 6.6
# 24K
# 2002
# PG
# 1h 30m
# October 11, 2002 (United States)
# $15,000,000 (estimated)
# $19,344,615
# ERROR ON: tt8097030
# ERROR ON: tt0467110
# ERROR ON: tt0080062
# ERROR ON: tt0075376
# https://www.imdb.com/title/tt1049413
# 8.3
# 1M
# 2009
# PG
# 1h 36m
# May 29, 2009 (United States)
# $175,000,000 (estimated)
# $735,099,102
# https://www.imdb.com/title/tt0361089
# 5.5
# 23K
# 2005
# G
# 1h 16m
# August 19, 2005 (United States)
# $35,000,000 (estimated)
# $61,746,888
# ERROR ON: tt1159961
# https://www.imdb.com/title/tt0910970
# 8.4
# 1.1M
# 2008
# G
# 1h 38m
# June 27, 2008 (United States)
# $180,000,000 (estimated)
# $521,311,890
# ERROR ON: tt1223150
# ERROR ON: tt0049945
# ERROR ON: tt0072402
# ERROR ON: tt0192788
# ERROR ON: tt0185007
# https://www.imdb.com/title/tt0103247
# 6.7
# 21K
# 1991
# PG
# 1h 47m
# January 18, 1991 (United States)
# $14,000,000 (estimated)
# $34,793,160
# ERROR ON: tt0111701
# ERROR ON: tt0052389
# ERROR ON: tt0103262
# ERROR ON: tt1222816
# https://www.imdb.com/title/tt1449283
# 7.2
# 24K
# 2011
# G
# 1h 3m
# July 15, 2011 (United States)
# $30,000,000 (estimated)
# $49,871,429
# ERROR ON: tt0324572
# https://www.imdb.com/title/tt1772341
# 7.7
# 409K
# 2012
# PG
# 1h 41m
# November 2, 2012 (United States)
# $165,000,000 (estimated)
# $471,222,889
# ERROR ON: tt0206446
# ERROR ON: tt1605790
# https://www.imdb.com/title/tt2948356
# 8.0
# 478K
# 2016
# PG
# 1h 48m
# March 4, 2016 (United States)
# $150,000,000 (estimated)
# $1,024,121,104

# %%
# const = "tt1067106"
# found1 = imdb_scrape[imdb_scrape['tconst'].str.contains(const)]
# found2 = imdb_errors[imdb_errors['tconst'].str.contains(const)]
# summ = found1.count().sum() + found2.count().sum()
# print(summ)

# %%
imdb_scrape.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 0 to 239
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tconst      240 non-null    object
#  1   newurl      240 non-null    object
#  2   rating      240 non-null    object
#  3   votes       240 non-null    object
#  4   year        240 non-null    object
#  5   mpaarating  240 non-null    object
#  6   runtime     240 non-null    object
#  7   rlsdt       240 non-null    object
#  8   budget      240 non-null    object
#  9   worldwide   240 non-null    object
#  10  soup_text   240 non-null    object
# dtypes: object(11)
# memory usage: 22.5+ KB

# %%
imdb_errors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204 entries, 0 to 203
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tconst  204 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB

# %%
imdb_scrape.head()
# Out:
#       tconst                                newurl rating votes  year  \
# 0  tt0115433  https://www.imdb.com/title/tt0115433    5.7  110K  1996
# 1  tt0211181  https://www.imdb.com/title/tt0211181    4.8   37K  2000
# 2  tt0120623  https://www.imdb.com/title/tt0120623    7.2  285K  1998
# 3  tt1067106  https://www.imdb.com/title/tt1067106    6.8  113K  2009
# 4  tt0113198  https://www.imdb.com/title/tt0113198    6.9   52K  1995
#
#   mpaarating runtime                              rlsdt  \
# 0          G  1h 43m  November 27, 1996 (United States)
# 1          G  1h 40m  November 22, 2000 (United States)
# 2          G  1h 35m  November 25, 1998 (United States)
# 3         PG  1h 36m   November 6, 2009 (United States)
# 4          G  1h 18m      April 7, 1995 (United States)
#
#                      budget     worldwide  \
# 0   $75,000,000 (estimated)  $320,689,294
# 1   $85,000,000 (estimated)  $183,611,771
# 2  $120,000,000 (estimated)  $363,258,859
# 3  $200,000,000 (estimated)  $325,286,646
# 4   $18,000,000 (estimated)   $35,348,597
#
#                                            soup_text
# 0  [html, [[<meta content="width=device-width" na...
# 1  [html, [[<meta content="width=device-width" na...
# 2  [html, [[<meta content="width=device-width" na...
# 3  [html, [[<meta content="width=device-width" na...
# 4  [html, [[<meta content="width=device-width" na...

# %%
imdb_scrape.to_csv('imdb_scrape_2.csv')
imdb_errors.to_csv('imdb_errors_2.csv')

# %% [markdown]
# # THE NEXT MORNING..

# %%
imdb_scrape = pd.read_csv('imdb_scrape_2.csv')
imdb_errors = pd.read_csv('imdb_errors_2.csv')
imdb_errors_r2 = pd.DataFrame(columns=['tconst'])

# %%
imdb_scrape.drop(columns=['Unnamed: 0'], inplace=True)
imdb_scrape.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tconst      240 non-null    object
#  1   newurl      240 non-null    object
#  2   rating      240 non-null    float64
#  3   votes       240 non-null    object
#  4   year        240 non-null    int64
#  5   mpaarating  240 non-null    object
#  6   runtime     240 non-null    object
#  7   rlsdt       240 non-null    object
#  8   budget      240 non-null    object
#  9   worldwide   240 non-null    object
#  10  soup_text   240 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 20.8+ KB

# %%
imdb_errors.drop(columns=['Unnamed: 0'], inplace=True)
imdb_errors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tconst  204 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
imdb_errors_r2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tconst  0 non-null      object
# dtypes: object(1)
# memory usage: 0.0+ bytes

# %%
# Target web page:
url = "https://www.imdb.com/title/"
# Establishing the connection to the web page:
response = requests.get(url)
# response.text[:50]
soup = BeautifulSoup(response.text, 'lxml')

# %%
for const in imdb_errors['tconst']:
    
    # found1 = imdb_scrape[imdb_scrape['tconst'].str.contains(const)]
    # found2 = imdb_errors[imdb_errors['tconst'].str.contains(const)]
    # summ = found1.count().sum() + found2.count().sum()
    
    # if summ < 1:
    
        # const = "tt0115433"
        # const = "tt0029583"
        # const = "tt1067106"
        budget = ''
        worldwide = ''
        t= random.uniform(1, 5)
        time.sleep(t)
        newurl = url + const
        response = requests.get(newurl)
        soup = BeautifulSoup(response.text, 'lxml')
        print(newurl)
        rtspan = soup.find_all('span', {'class' : 'sc-7ab21ed2-1 jGRxWM'})
        rating = rtspan[0].get_text()

        vtdiv = soup.find_all('div', {'class' : 'sc-7ab21ed2-3 dPVcnq'})
        votes = vtdiv[0].text

        # mpaaspan = soup.find_all('span', {'class' : 'ipc-metadata-list-item__list-content-item'})
        # mpaarating = mpaaspan[2].get_text()
        try:

            metaul = soup.find_all('ul', {'data-testid' : 'hero-title-block__metadata'})
            year = metaul[0].find_all('li')[0].find_all('span')[0].get_text()
            mpaarating = metaul[0].find_all('li')[1].find_all('span')[0].get_text()
            runtime = metaul[0].find_all('li')[2].get_text()
            rlsdt = soup.find_all('li', {'data-testid' : 'title-details-releasedate'})[0].find_all('a')[1].get_text()
            try:
                budget = soup.find_all('li', {'data-testid' : 'title-boxoffice-budget'})[0].find_all('li')[0].get_text()
            except:
                pass
            try:    
                worldwide = soup.find_all('li', {'data-testid' : 'title-boxoffice-cumulativeworldwidegross'})[0].find_all('li')[0].get_text()
            except:
                pass   
            print(newurl)
            print(rating)
            print(votes) 
            print(year) 
            print(mpaarating) 
            print(runtime) 
            print(rlsdt) 
            print(budget) 
            print(worldwide) 
            imdb_scrape.loc[len(imdb_scrape.index)] = [const, newurl, rating, votes, year ,mpaarating ,runtime ,rlsdt ,budget ,worldwide, soup]

        except:
            imdb_errors_r2.loc[len(imdb_errors_r2.index)] = [const]
            print(f"ERROR ON: {const}")
# Out:
# https://www.imdb.com/title/tt0046672
# https://www.imdb.com/title/tt0046672
# 7.2
# 33K
# 1954
# G
# 2h 7m
# July 20, 1955 (United States)
# $9,000,000 (estimated)
#
# https://www.imdb.com/title/tt0106868
# https://www.imdb.com/title/tt0106868
# 6.5
# 3.6K
# 1993
# PG
# 1h 48m
# March 12, 1993 (United States)
#
# $12,890,752
# https://www.imdb.com/title/tt0058657
# https://www.imdb.com/title/tt0058657
# 6.3
# 349
# 1964
# Approved
# 1h 31m
# March 12, 1964 (United States)
#
#
# https://www.imdb.com/title/tt0043274
# https://www.imdb.com/title/tt0043274
# 7.4
# 138K
# 1951
# G
# 1h 15m
# July 28, 1951 (United States)
# $3,000,000 (estimated)
#
# https://www.imdb.com/title/tt0417415
# https://www.imdb.com/title/tt0417415
# 6.4
# 3K
# 2005
# G
# 1h 40m
# August 25, 2005 (Germany)
#
# $12,775,590
# https://www.imdb.com/title/tt0055740
# https://www.imdb.com/title/tt0055740
# 6.6
# 548
# 1962
# Not Rated
# 1h 33m
# December 21, 1962 (United States)
#
#
# https://www.imdb.com/title/tt0381006
# https://www.imdb.com/title/tt0381006
# 5.0
# 680
# 2004
# PG
# 1h 24m
# July 2, 2004 (United States)
#
# $314,402
# https://www.imdb.com/title/tt0082017
# https://www.imdb.com/title/tt0082017
# 6.6
# 469
# 1981
# G
# 1h 40m
# March 20, 1981 (United States)
#
#
# https://www.imdb.com/title/tt0043286
# https://www.imdb.com/title/tt0043286
# 7.1
# 2.4K
# 1951
# Approved
# 1h 39m
# October 19, 1951 (United States)
# $1,081,000 (estimated)
#
# https://www.imdb.com/title/tt3089630
# https://www.imdb.com/title/tt3089630
# 4.2
# 27K
# 2020
# PG
# 1h 35m
# June 12, 2020 (United States)
#
#
# https://www.imdb.com/title/tt0054649
# https://www.imdb.com/title/tt0054649
# 6.2
# 4.2K
# 1961
# Approved
# 1h 46m
# December 14, 1961 (United States)
#
#
# https://www.imdb.com/title/tt0168473
# https://www.imdb.com/title/tt0168473
# 4.9
# 564
# 1997
# G
# 1h 14m
# October 14, 1997 (United States)
#
#
# https://www.imdb.com/title/tt0034492
# https://www.imdb.com/title/tt0034492
# 7.3
# 140K
# 1942
# G
# 1h 10m
# August 21, 1942 (United States)
#
# $267,447,150
# https://www.imdb.com/title/tt0066817
# https://www.imdb.com/title/tt0066817
# 7.1
# 37K
# 1971
# G
# 1h 57m
# December 13, 1971 (United States)
# $20,000,000 (estimated)
#
# https://www.imdb.com/title/tt0092638
# https://www.imdb.com/title/tt0092638
# 6.2
# 3.1K
# 1987
# G
# 1h 28m
# June 19, 1987 (United States)
#
# $22,257,624
# https://www.imdb.com/title/tt0055793
# https://www.imdb.com/title/tt0055793
# 6.4
# 764
# 1962
# Not Rated
# 1h 29m
# June 6, 1962 (United States)
#
#
# https://www.imdb.com/title/tt0062737
# https://www.imdb.com/title/tt0062737
# 6.8
# 5.9K
# 1968
# Approved
# 1h 46m
# February 8, 1968 (United States)
#
#
#
# https://www.imdb.com/title/tt1015971
# https://www.imdb.com/title/tt1015971
# 7.7
# 1.1K
# 2009
# PG
# 1h 41m
# April 24, 2009 (United States)
#
# $55,513
# https://www.imdb.com/title/tt0092695
# https://www.imdb.com/title/tt0092695
# 7.3
# 25K
# 1987
# G
# 1h 30m
# July 10, 1987 (United States)
# $2,300,000 (estimated)
#
# https://www.imdb.com/title/tt0071288
# https://www.imdb.com/title/tt0071288
# 5.8
# 704
# 1974
# G
# 1h 31m
# August 1, 1974 (United States)
#
#
# https://www.imdb.com/title/tt0077305
# https://www.imdb.com/title/tt0077305
# 6.0
# 5.1K
# 1978
# G
# 1h 44m
# June 9, 1978 (United States)
# $4,000,000 (estimated)
#
# https://www.imdb.com/title/tt0090840
# https://www.imdb.com/title/tt0090840
# 6.3
# 631
# 1986
# TV-G
# 1h 34m
# December 14, 1986 (United States)
# $3,500,000 (estimated)
#
# https://www.imdb.com/title/tt0065566
# https://www.imdb.com/title/tt0065566
# 6.0
# 5.2K
# 1969
# G
# 1h 31m
# December 24, 1969 (United States)
#
#
# https://www.imdb.com/title/tt0902967
# https://www.imdb.com/title/tt0902967
# 7.3
# 1.3K
# 2008
# G
# 1h 18m
# September 25, 2009 (United Kingdom)
#
# $1,783,519
# https://www.imdb.com/title/tt0082263
# https://www.imdb.com/title/tt0082263
# 5.0
# 1.3K
# 1981
# PG
# 1h 36m
# March 6, 1981 (United States)
#
# $16,000,000
# https://www.imdb.com/title/tt0196516
# https://www.imdb.com/title/tt0196516
# 4.5
# 539
# 1999
# G
# 1h 28m
# December 17, 1999 (United States)
#
#
# https://www.imdb.com/title/tt0060408
# https://www.imdb.com/title/tt0060408
# 6.1
# 387
# 1966
# Not Rated
# 1h 50m
# October 1, 1966 (United States)
#
#
# https://www.imdb.com/title/tt0058099
# ERROR ON: tt0058099
# https://www.imdb.com/title/tt0061715
# https://www.imdb.com/title/tt0061715
# 6.5
# 2.2K
# 1967
# Approved
# 1h 24m
# July 19, 1967 (United States)
#
#
# https://www.imdb.com/title/tt0049279
# https://www.imdb.com/title/tt0049279
# 6.9
# 1.2K
# 1956
# Approved
# 1h 25m
# August 17, 1956 (United Kingdom)
# $2,500,000 (estimated)
#
# https://www.imdb.com/title/tt0082474
# https://www.imdb.com/title/tt0082474
# 7.1
# 15K
# 1981
# G
# 1h 37m
# June 26, 1981 (United States)
#
# $31,206,251
# https://www.imdb.com/title/tt0061749
# https://www.imdb.com/title/tt0061749
# 6.6
# 2.1K
# 1967
# Approved
# 2h 21m
# July 10, 1968 (United States)
#
#
# https://www.imdb.com/title/tt0063091
# https://www.imdb.com/title/tt0063091
# 6.3
# 1K
# 1968
# G
# 1h 53m
# June 19, 1970 (United States)
#
#
# https://www.imdb.com/title/tt0057180
# https://www.imdb.com/title/tt0057180
# 7.0
# 4.6K
# 1963
# G
# 1h 20m
# November 20, 1963 (United States)
#
#
# https://www.imdb.com/title/tt0071671
# https://www.imdb.com/title/tt0071671
# 3.4K
# 1974
# G
# 1h 37m
# June 21, 1974 (United States)
#
#
# https://www.imdb.com/title/tt0192788
# https://www.imdb.com/title/tt0192788
# 6.4
# 1.2K
# 2003
# PG
# 1h 26m
# May 3, 2003 (United States)
#
#
# https://www.imdb.com/title/tt0185007
# https://www.imdb.com/title/tt0185007
# 5.0
# 358
# 2000
# G
# 1h 12m
# March 10, 2000 (United States)
# $4,000,000 (estimated)
#
# https://www.imdb.com/title/tt0111701
# https://www.imdb.com/title/tt0111701
# 5.4
# 2.3K
# 1994
# PG
# 1h 46m
# April 15, 1994 (United States)
#
# $8,878,839
# https://www.imdb.com/title/tt0052389
# https://www.imdb.com/title/tt0052389
# 5.4
# 443
# 1958
# Approved
# 1h 12m
# August 12, 1958 (United States)
#
#
# https://www.imdb.com/title/tt0103262
# https://www.imdb.com/title/tt0103262
# 7.2
# 5.3K
# 1991
# G
# 1h 28m
# May 24, 1991 (United States)
#
# $7,294,835
# https://www.imdb.com/title/tt1222816
# https://www.imdb.com/title/tt1222816
# 7.4
# 605
# 2011
# G
# 1h 21m
# April 16, 2013 (United States)
#
# $192,467
# https://www.imdb.com/title/tt0324572
# https://www.imdb.com/title/tt0324572
# 6.6
# 2.5K
# 2002
# G
# 1h 5m
# November 12, 2002 (United States)
#
#
# https://www.imdb.com/title/tt0206446
# https://www.imdb.com/title/tt0206446
# 6.9
# 287
# 1963
# Not Rated
# 48m
# June 1, 1963 (United States)
#
#
# https://www.imdb.com/title/tt1605790
# https://www.imdb.com/title/tt1605790
# 4.1
# 402
# 2011
# PG
# 1h 49m
# April 22, 2011 (India)
#
# $3,000

# %%
imdb_scrape.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 440 entries, 0 to 439
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tconst      440 non-null    object
#  1   newurl      440 non-null    object
#  2   rating      440 non-null    object
#  3   votes       440 non-null    object
#  4   year        440 non-null    object
#  5   mpaarating  440 non-null    object
#  6   runtime     440 non-null    object
#  7   rlsdt       440 non-null    object
#  8   budget      440 non-null    object
#  9   worldwide   440 non-null    object
#  10  soup_text   440 non-null    object
# dtypes: object(11)
# memory usage: 41.2+ KB

# %%
imdb_errors_r2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tconst  4 non-null      object
# dtypes: object(1)
# memory usage: 64.0+ bytes

# %%
imdb_scrape.to_csv('imdb_scrape_rnd2.csv')
imdb_errors_r2.to_csv('imdb_errors_rnd2.csv')

# %% [markdown]
# # ROUND 3 - Hand Checking Errors

# %%
imdb_scrape = pd.read_csv('../Bens_Data/imdb_scrape_rnd2.csv')
imdb_errors_r2 = pd.read_csv('../Bens_Data/imdb_errors_rnd2.csv')

# %%
imdb_errors_r2.head()
# Out:
#    Unnamed: 0     tconst
# 0           0  tt0057312
# 1           1  tt2064925
# 2           2  tt0058099
# 3           3  tt1686635

# %%
for const in imdb_errors_r2['tconst']:
    
    # found1 = imdb_scrape[imdb_scrape['tconst'].str.contains(const)]
    # found2 = imdb_errors[imdb_errors['tconst'].str.contains(const)]
    # summ = found1.count().sum() + found2.count().sum()
    
    skip = ['tt0035462','tt7728220','tt1686635','tt1935157','tt0344910','tt2905856','tt14608798','tt0780134','tt0087993','tt0057312','tt1130090','tt9047432','tt0066250','tt2064925','tt0096866','tt0058099','tt0246786','tt0385277']
    
    if (const in skip) == False:
    
        # const = "tt0115433"
        # const = "tt0029583"
        # const = "tt1067106"
        budget = ''
        worldwide = ''
        t= random.uniform(1, 5)
        time.sleep(t)
        newurl = url + const
        response = requests.get(newurl)
        soup = BeautifulSoup(response.text, 'lxml')
        print(newurl)
        rtspan = soup.find_all('span', {'class' : 'sc-7ab21ed2-1 jGRxWM'})
        rating = rtspan[0].get_text()

        vtdiv = soup.find_all('div', {'class' : 'sc-7ab21ed2-3 dPVcnq'})
        votes = vtdiv[0].text

        # mpaaspan = soup.find_all('span', {'class' : 'ipc-metadata-list-item__list-content-item'})
        # mpaarating = mpaaspan[2].get_text()
        # try:

        metaul = soup.find_all('ul', {'data-testid' : 'hero-title-block__metadata'})
        year = metaul[0].find_all('li')[0].find_all('span')[0].get_text()
        mpaarating = metaul[0].find_all('li')[1].find_all('span')[0].get_text()
        runtime = metaul[0].find_all('li')[2].get_text()
        rlsdt = soup.find_all('li', {'data-testid' : 'title-details-releasedate'})[0].find_all('a')[1].get_text()

        budget = soup.find_all('li', {'data-testid' : 'title-boxoffice-budget'})[0].find_all('li')[0].get_text()


        worldwide = soup.find_all('li', {'data-testid' : 'title-boxoffice-cumulativeworldwidegross'})[0].find_all('li')[0].get_text()

        print(newurl)
        print(rating)
        print(votes) 
        print(year) 
        print(mpaarating) 
        print(runtime) 
        print(rlsdt) 
        print(budget) 
        print(worldwide) 
        imdb_scrape.loc[len(imdb_scrape.index)] = [const, newurl, rating, votes, year ,mpaarating ,runtime ,rlsdt ,budget ,worldwide, soup]

        # except:
        #     imdb_errors_r2.loc[len(imdb_errors_r2.index)] = [const]
        #     print(f"ERROR ON: {const}")

# %%
https://www.imdb.com/title/tt0057312 
        # Miracle of the White Stallions
        # Initial release: March 29, 1963
        # Director: Arthur Hiller
        # Box office $2,550,000 (US/ Canada)[1]
        # G  
        # Family, Live Action, Drama, Classics 
tt2064925 not a Disney Movie, should have been https://www.imdb.com/title/tt0049733/ 
tt0058099 not a Disney Movie, should have been https://www.imdb.com/title/tt2025690/
tt1686635 not a Disney Movie, should have been https://www.imdb.com/title/tt0046387/
# Out:
#   File "C:\Users\benro\AppData\Local\Temp/ipykernel_80520/3479813539.py", line 1
#     https://www.imdb.com/title/tt0057312
#           ^
# SyntaxError: invalid syntax

# %%
imdb_scrape.drop(columns=['Unnamed: 0'], inplace=True)

# %%
imdb_scrape.head()
# Out:
#       tconst                                newurl  rating votes  year  \
# 0  tt0115433  https://www.imdb.com/title/tt0115433     5.7  110K  1996
# 1  tt0211181  https://www.imdb.com/title/tt0211181     4.8   37K  2000
# 2  tt0120623  https://www.imdb.com/title/tt0120623     7.2  285K  1998
# 3  tt1067106  https://www.imdb.com/title/tt1067106     6.8  113K  2009
# 4  tt0113198  https://www.imdb.com/title/tt0113198     6.9   52K  1995
#
#   mpaarating runtime                              rlsdt  \
# 0          G  1h 43m  November 27, 1996 (United States)
# 1          G  1h 40m  November 22, 2000 (United States)
# 2          G  1h 35m  November 25, 1998 (United States)
# 3         PG  1h 36m   November 6, 2009 (United States)
# 4          G  1h 18m      April 7, 1995 (United States)
#
#                      budget     worldwide  \
# 0   $75,000,000 (estimated)  $320,689,294
# 1   $85,000,000 (estimated)  $183,611,771
# 2  $120,000,000 (estimated)  $363,258,859
# 3  $200,000,000 (estimated)  $325,286,646
# 4   $18,000,000 (estimated)   $35,348,597
#
#                                            soup_text
# 0  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...
# 1  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...
# 2  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...
# 3  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...
# 4  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...

# %%
imdb_scrape[imdb_scrape['tconst']=='tt0049733']
# Out:
#         tconst                                newurl  rating votes  year  \
# 337  tt0049733  https://www.imdb.com/title/tt0049733     7.4   272  1956
#
#     mpaarating runtime                             rlsdt budget worldwide  \
# 337     Passed  1h 10m  November 6, 1956 (United States)    NaN       NaN
#
#                                              soup_text
# 337  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...

# %%
imdb_scrape[imdb_scrape['tconst']=='tt2025690']
# Out:
#         tconst                                newurl  rating votes  year  \
# 179  tt2025690  https://www.imdb.com/title/tt2025690     6.7   66K  2016
#
#     mpaarating runtime                             rlsdt  \
# 179      PG-13  1h 57m  January 29, 2016 (United States)
#
#                       budget    worldwide  \
# 179  $80,000,000 (estimated)  $52,099,090
#
#                                              soup_text
# 179  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...

# %%
imdb_scrape[imdb_scrape['tconst']=='tt0046387']
# Out:
#         tconst                                newurl  rating votes  year  \
# 403  tt0046387  https://www.imdb.com/title/tt0046387     6.3   871  1953
#
#     mpaarating runtime                          rlsdt budget   worldwide  \
# 403   Approved  1h 32m  July 23, 1953 (United States)    NaN  $2,500,000
#
#                                              soup_text
# 403  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...

# %%
imdb_scrape = imdb_scrape.drop(imdb_scrape[(imdb_scrape['tconst']=='tt2064925')].index)
imdb_scrape = imdb_scrape.drop(imdb_scrape[(imdb_scrape['tconst']=='tt0058099')].index)
imdb_scrape = imdb_scrape.drop(imdb_scrape[(imdb_scrape['tconst']=='tt1686635')].index)

# %%
# https://www.imdb.com/title/tt0057312 
#         # Miracle of the White Stallions
#         # Initial release: March 29, 1963
#         # Director: Arthur Hiller
#         # Box office $2,550,000 (US/ Canada)[1]
#         # G  
#         # Family, Live Action, Drama, Classics 

# const = 'tt0057312'
# newurl ='https://www.imdb.com/title/tt0057312'
# rating ='6.5'
# votes ='698'
# year ='1963'
# mpaarating ='G'
# runtime ='1h 58m'
# rlsdt ='March 29, 1963 (United States)'
# budget =''
# worldwide ='$2,550,000'
# soup = ''


# imdb_scrape.loc[IMDB_Scrape['tconst']=='tt0057312'] = [const, newurl, rating, votes, year ,mpaarating ,runtime ,rlsdt ,budget ,worldwide, soup]

# %%
# Target web page:
url = "https://www.imdb.com/title/"

const = "tt0057312"
budget = ''
mpaarating ='G'
runtime ='1h 58m'
worldwide ='$2,550,000'

newurl = url + const
response = requests.get(newurl)
soup = BeautifulSoup(response.text, 'lxml')
print(newurl)
rtspan = soup.find_all('span', {'class' : 'sc-7ab21ed2-1 jGRxWM'})
rating = rtspan[0].get_text()

vtdiv = soup.find_all('div', {'class' : 'sc-7ab21ed2-3 dPVcnq'})
votes = vtdiv[0].text

        # mpaaspan = soup.find_all('span', {'class' : 'ipc-metadata-list-item__list-content-item'})
        # mpaarating = mpaaspan[2].get_text()
        # try:

metaul = soup.find_all('ul', {'data-testid' : 'hero-title-block__metadata'})
year = metaul[0].find_all('li')[0].find_all('span')[0].get_text()
# mpaarating = metaul[0].find_all('li')[1].find_all('span')[0].get_text()
# runtime = metaul[0].find_all('li')[2].get_text()
rlsdt = soup.find_all('li', {'data-testid' : 'title-details-releasedate'})[0].find_all('a')[1].get_text()

# budget = soup.find_all('li', {'data-testid' : 'title-boxoffice-budget'})[0].find_all('li')[0].get_text()


# worldwide = soup.find_all('li', {'data-testid' : 'title-boxoffice-cumulativeworldwidegross'})[0].find_all('li')[0].get_text()

print(newurl)
print(rating)
print(votes) 
print(year) 
print(mpaarating) 
print(runtime) 
print(rlsdt) 
print(budget) 
print(worldwide) 
imdb_scrape.loc[len(imdb_scrape.index)] = [const, newurl, rating, votes, year ,mpaarating ,runtime ,rlsdt ,budget ,worldwide, soup]
# Out:
# https://www.imdb.com/title/tt0057312
# https://www.imdb.com/title/tt0057312
# 6.5
# 701
# 1963
# G
# 1h 58m
# March 29, 1963 (United States)
#
# $2,550,000

# %%
imdb_disney_soup = imdb_scrape[['tconst', 'soup_text']]

# %%
imdb_disney_soup.head()
# Out:
#       tconst                                          soup_text
# 0  tt0115433  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...
# 1  tt0211181  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...
# 2  tt0120623  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...
# 3  tt1067106  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...
# 4  tt0113198  <!DOCTYPE html>\n<html lang="en-US" xmlns:fb="...

# %%
imdb_disney_soup.to_csv('../Bens_Data/imdb_disney_soup.csv')

# %%
imdb_scrape.drop(columns=['soup_text'], inplace=True)

# %%
imdb_scrape.head()
# Out:
#       tconst                                newurl  rating votes  year  \
# 0  tt0115433  https://www.imdb.com/title/tt0115433     5.7  110K  1996
# 1  tt0211181  https://www.imdb.com/title/tt0211181     4.8   37K  2000
# 2  tt0120623  https://www.imdb.com/title/tt0120623     7.2  285K  1998
# 3  tt1067106  https://www.imdb.com/title/tt1067106     6.8  113K  2009
# 4  tt0113198  https://www.imdb.com/title/tt0113198     6.9   52K  1995
#
#   mpaarating runtime                              rlsdt  \
# 0          G  1h 43m  November 27, 1996 (United States)
# 1          G  1h 40m  November 22, 2000 (United States)
# 2          G  1h 35m  November 25, 1998 (United States)
# 3         PG  1h 36m   November 6, 2009 (United States)
# 4          G  1h 18m      April 7, 1995 (United States)
#
#                      budget     worldwide
# 0   $75,000,000 (estimated)  $320,689,294
# 1   $85,000,000 (estimated)  $183,611,771
# 2  $120,000,000 (estimated)  $363,258,859
# 3  $200,000,000 (estimated)  $325,286,646
# 4   $18,000,000 (estimated)   $35,348,597

# %%
imdb_scrape.to_csv('../Bens_Data/imdb_scrape_final.csv')
